# %% [markdown]
# # Libraries

# %%
# Standard libraries
import json
import os

# Third-party libraries
import math, glob
import torch

# %% [markdown]
# # The goal is to take an original shard, process and save it

# %%
data = torch.load("/work/scratch-nopw2/mrakotomanga/eps/pancast-shard-processed-ds/t3/val_512/t3-shard-val-063_proc.pt")

# %%
inputs = data["inputs"]
targets = data["targets"]

# %%
targets.shape
# Out:
# torch.Size([1000, 512, 512])
