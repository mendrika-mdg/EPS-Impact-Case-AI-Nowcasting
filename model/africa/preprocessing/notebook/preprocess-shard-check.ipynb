# %% [markdown]
# # Libraries

# %%
# Standard libraries
import json
import os

# Third-party libraries
import math, glob
import torch

# %% [markdown]
# # The goal is to take an original shard, process and save it

# %%
a = torch.load("/work/scratch-nopw2/mrakotomanga/eps/pancast-shard/t1/train/shard-train-034.pt")

# %%
data = a["inputs"]
mask = data[:, :, 10] == 1
core = data[mask]

# %%
core[:, 9]
# Out:
# tensor([1161.,  513.,  297.,  ...,  360.,  198.,  324.])
