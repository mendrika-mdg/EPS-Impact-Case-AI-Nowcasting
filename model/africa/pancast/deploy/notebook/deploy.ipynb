# %%
import sys

# %%
import torch
import matplotlib.pyplot as plt
from t1_pancast10_transpose import t1Core2MapModel
from t3_pancast10_transpose import t3Core2MapModel
import numpy as np

# %% [markdown]
# # Import data

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Prediction

# %% [markdown]
# # Import model
