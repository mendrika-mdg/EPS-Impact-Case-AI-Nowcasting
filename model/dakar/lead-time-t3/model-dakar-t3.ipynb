# %% [markdown]
# # Lead Time : 3 h

# %%
lead_time = 3

# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd 
import xgboost as xgb
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve                  
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf                                                                 
from tensorflow.keras.initializers import he_normal                                      # type: ignore
from sklearn.model_selection import train_test_split         
from tensorflow.keras import regularizers                                                # type: ignore
from joblib import dump, load                                                           
from sklearn.preprocessing import StandardScaler
# Out:
# 2025-05-17 14:26:37.564951: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-17 14:26:37.574264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-17 14:26:37.583985: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-17 14:26:37.586906: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-17 14:26:37.595868: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-17 14:26:38.146586: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Import Data

# %%
train = pd.read_csv("../../../output/data/dakar/data-train-eps-dakar.csv")
test = pd.read_csv("../../../output/data/dakar/data-test-eps-dakar.csv")

# %%
train, validation = train_test_split(train, test_size=0.2, random_state=12)

# %% [markdown]
# # Selecting Header

# %%
def choose_header(n, location, lead_time):
    """
    Generate header names for n closest storms.

    Returns:
        tuple of two lists:
            - input headers: year, month, day, hour, minute, lat1..n, lon1..n, wp1..n, size1..n, d1..n, mask1..n
            - target header: Cb_{location}_t{lead_time}
    """
    input_headers = ['year', 'month', 'day', 'hour', 'minute']
    
    for prefix in ['lat', 'lon', 'wp', 'size', 'd', 'mask']:
        input_headers.extend([f'{prefix}{i}' for i in range(1, n + 1)])
    
    target_header = [f'Cb_{location}_t{lead_time}']
    
    return input_headers, target_header

# %%
input_headers, target_header = choose_header(3, "dakar", lead_time)

# %%
X_train = train[input_headers]
X_val = validation[input_headers]
X_test = test[input_headers]

y_train = train[target_header]
y_val = validation[target_header]
y_test = test[target_header]
y_persistence = test["Cb_dakar_t0"]

# %% [markdown]
# # Exploratory data analysis

# %%
# Dataset types
types = ['Train', 'Validation', 'Test']

# Replace with your actual labels: 0 = No Core, 1 = Core
no_core = [y_train.value_counts()[0], y_val.value_counts()[0], y_test.value_counts()[0]]
core     = [y_train.value_counts()[1], y_val.value_counts()[1], y_test.value_counts()[1]]

x = np.arange(len(types))
width = 0.35

palette = sns.color_palette("Set2", 2)

fig, ax = plt.subplots(figsize=(8, 5))

bars1 = ax.bar(x - width/2, no_core, width, label='No Core', color=palette[0], edgecolor='black')
bars2 = ax.bar(x + width/2, core, width, label='Core', color=palette[1], edgecolor='black')

# Annotate bars with counts
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        if height > 0:
            ax.text(bar.get_x() + bar.get_width() / 2, height * 1.1, f'{int(height)}',
                    ha='center', va='bottom', fontsize=9)

# Log scale for better visibility of small core counts
ax.set_yscale('log')
ax.set_ylabel("Number of Samples (log scale)", fontsize=11)
ax.set_xlabel("Dataset", fontsize=11)
ax.set_xticks(x)
ax.set_xticklabels(types)
ax.legend(title="Class")
sns.despine()
plt.tight_layout()
plt.show()

# %%
df = train

# Only include rows with at least one valid storm
real_mask = (df['mask1'] == 1) & (df['mask2'] == 1) & (df['mask3'] == 1)

features = ['wp', 'size', 'd']
storm_indices = [1, 2, 3]

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))
plt.subplots_adjust(hspace=0.4, wspace=0.3)

for row_idx, feature in enumerate(features):
    for col_idx, storm_idx in enumerate(storm_indices):
        ax = axes[row_idx, col_idx]
        feature_name = f'{feature}{storm_idx}'
        
        # Plot histogram
        sns.histplot(
            data=df[real_mask],
            x=feature_name,
            hue=f'Cb_dakar_t{lead_time}',
            kde=True,
            common_norm=False,
            ax=ax,
            element="step",
            bins= 100
        )

        # Apply log scale
        #ax.set_yscale('log')
        ax.set_title(f'{feature_name} distribution', fontsize=11)
        ax.set_xlabel(feature_name)
        ax.set_ylabel('Count (log scale)')

plt.tight_layout()
plt.show()

# %%
# Only positive cases with at least one valid storm
real_mask = ((df['mask1'] == 1) & (df['mask2'] == 1) & (df['mask3'] == 1)) & (df[f'Cb_dakar_t{lead_time}'] == 1)

features = ['wp', 'size', 'd']
storm_indices = [1, 2, 3]

# Use seaborn color palette
colors = sns.color_palette("crest", n_colors=3)

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))
plt.subplots_adjust(hspace=0.4, wspace=0.3)

for row_idx, feature in enumerate(features):
    for col_idx, storm_idx in enumerate(storm_indices):
        ax = axes[row_idx, col_idx]
        feature_name = f'{feature}{storm_idx}'
        sns.histplot(
            data=df[real_mask], 
            x=feature_name, 
            kde=True, 
            ax=ax, 
            element="step", 
            fill=True,
            color=colors[col_idx]  # one colour per storm index
        )
        ax.set_title(f'{feature_name} (positive only)', fontsize=11)
        ax.set_xlabel(feature_name)
        ax.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
positive_df = df[df['Cb_dakar_t1'] == 1]

time_features = ['year', 'month', 'hour']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 4))
plt.subplots_adjust(wspace=0.4)

for idx, feature in enumerate(time_features):
    ax = axes[idx]
    sns.histplot(data=positive_df, x=feature, kde=True, ax=ax, element="step")
    ax.set_title(f'{feature}')
    ax.set_xlabel(feature)
    ax.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Log transforming

# %%
for col in ['size1', 'size2', 'size3', 'wp1', 'wp2', 'wp3', 'd1', 'd2', 'd3']:
    X_train.loc[:, col] = np.log1p(X_train[col])
    X_val.loc[:, col] = np.log1p(X_val[col])
    X_test.loc[:, col] = np.log1p(X_test[col])

# %% [markdown]
# # Scaling

# %%
# Exclude mask columns from scaling
mask_cols = ['mask1', 'mask2', 'mask3']

# Final list of features to scale
cols_to_scale = [col for col in X_train.columns 
                 if col not in mask_cols]

scaler = StandardScaler()

X_train_scaled = X_train.copy()
X_train_scaled[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])

X_val_scaled = X_val.copy()
X_val_scaled[cols_to_scale] = scaler.transform(X_val[cols_to_scale])

X_test_scaled = X_test.copy()
X_test_scaled[cols_to_scale] = scaler.transform(X_test[cols_to_scale])

# %% [markdown]
# # Model design

# %%
l1_reg = regularizers.L1(0.00001)

model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu', kernel_initializer=he_normal(), kernel_regularizer=l1_reg),
    tf.keras.layers.Dropout(0.3), 
    tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=l1_reg),   
    tf.keras.layers.Dropout(0.3), 
    tf.keras.layers.Dense(8, activation='relu', kernel_regularizer=l1_reg),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

classification_threshold = 0.3

METRICS = [                      
    tf.keras.metrics.Recall(name='recall', thresholds=classification_threshold),
    tf.keras.metrics.Precision(name='precision', thresholds=classification_threshold),
    tf.keras.metrics.AUC(name='auc'),
    tf.keras.metrics.AUC(name='prc', curve='PR'), 
    tf.keras.metrics.F1Score(name='f1_score', threshold=classification_threshold),
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=METRICS
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,721 (10.63 KB)
#  Trainable params: 2,721 (10.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Model training

# %%
EPOCHS = 500
BATCH_SIZE = 1024

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_prc", 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)


# train the model
model_history = model.fit(X_train_scaled, 
                          y_train, 
                          epochs=EPOCHS, 
                          callbacks = [early_stopping],
                          batch_size = BATCH_SIZE,         
                          validation_data=(X_val_scaled, y_val),
                        )
# Out:
# Epoch 1/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - auc: 0.3774 - f1_score: 0.0101 - loss: 0.3347 - prc: 0.0080 - precision: 0.0053 - recall: 0.1380 - val_auc: 0.6543 - val_f1_score: 0.0000e+00 - val_loss: 0.0627 - val_prc: 0.0165 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5967 - f1_score: 0.0083 - loss: 0.0828 - prc: 0.0156 - precision: 0.0153 - recall: 0.0057 - val_auc: 0.8045 - val_f1_score: 0.0000e+00 - val_loss: 0.0569 - val_prc: 0.0390 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7500 - f1_score: 0.0241 - loss: 0.0676 - prc: 0.0298 - precision: 0.0521 - recall: 0.0157 - val_auc: 0.8197 - val_f1_score: 0.0000e+00 - val_loss: 0.0563 - val_prc: 0.0450 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7612 - f1_score: 0.0239 - loss: 0.0669 - prc: 0.0360 - precision: 0.0586 - recall: 0.0150 - val_auc: 0.8285 - val_f1_score: 0.0000e+00 - val_loss: 0.0560 - val_prc: 0.0481 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7766 - f1_score: 0.0103 - loss: 0.0649 - prc: 0.0372 - precision: 0.0322 - recall: 0.0061 - val_auc: 0.8334 - val_f1_score: 0.0000e+00 - val_loss: 0.0554 - val_prc: 0.0512 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7972 - f1_score: 0.0174 - loss: 0.0624 - prc: 0.0475 - precision: 0.0737 - recall: 0.0099 - val_auc: 0.8359 - val_f1_score: 0.0000e+00 - val_loss: 0.0551 - val_prc: 0.0528 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8033 - f1_score: 0.0223 - loss: 0.0617 - prc: 0.0449 - precision: 0.1099 - recall: 0.0124 - val_auc: 0.8385 - val_f1_score: 0.0000e+00 - val_loss: 0.0547 - val_prc: 0.0542 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8155 - f1_score: 0.0061 - loss: 0.0589 - prc: 0.0434 - precision: 0.0411 - recall: 0.0033 - val_auc: 0.8429 - val_f1_score: 0.0000e+00 - val_loss: 0.0547 - val_prc: 0.0576 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8279 - f1_score: 0.0133 - loss: 0.0602 - prc: 0.0540 - precision: 0.1120 - recall: 0.0070 - val_auc: 0.8485 - val_f1_score: 0.0000e+00 - val_loss: 0.0542 - val_prc: 0.0587 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8337 - f1_score: 0.0089 - loss: 0.0590 - prc: 0.0537 - precision: 0.0554 - recall: 0.0049 - val_auc: 0.8433 - val_f1_score: 0.0000e+00 - val_loss: 0.0539 - val_prc: 0.0585 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8378 - f1_score: 0.0017 - loss: 0.0558 - prc: 0.0546 - precision: 0.0155 - recall: 8.9272e-04 - val_auc: 0.8526 - val_f1_score: 0.0000e+00 - val_loss: 0.0541 - val_prc: 0.0590 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8531 - f1_score: 0.0080 - loss: 0.0551 - prc: 0.0564 - precision: 0.0826 - recall: 0.0042 - val_auc: 0.8534 - val_f1_score: 0.0000e+00 - val_loss: 0.0537 - val_prc: 0.0602 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8564 - f1_score: 0.0012 - loss: 0.0571 - prc: 0.0635 - precision: 0.0177 - recall: 6.3285e-04 - val_auc: 0.8565 - val_f1_score: 0.0000e+00 - val_loss: 0.0540 - val_prc: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8579 - f1_score: 0.0060 - loss: 0.0573 - prc: 0.0642 - precision: 0.1171 - recall: 0.0031 - val_auc: 0.8590 - val_f1_score: 0.0000e+00 - val_loss: 0.0537 - val_prc: 0.0646 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8599 - f1_score: 0.0000e+00 - loss: 0.0544 - prc: 0.0633 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8580 - val_f1_score: 0.0000e+00 - val_loss: 0.0533 - val_prc: 0.0661 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8562 - f1_score: 0.0039 - loss: 0.0533 - prc: 0.0682 - precision: 0.1068 - recall: 0.0020 - val_auc: 0.8608 - val_f1_score: 0.0000e+00 - val_loss: 0.0532 - val_prc: 0.0674 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8631 - f1_score: 0.0034 - loss: 0.0557 - prc: 0.0684 - precision: 0.0672 - recall: 0.0018 - val_auc: 0.8614 - val_f1_score: 0.0000e+00 - val_loss: 0.0534 - val_prc: 0.0658 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8713 - f1_score: 0.0046 - loss: 0.0532 - prc: 0.0763 - precision: 0.2344 - recall: 0.0023 - val_auc: 0.8691 - val_f1_score: 0.0000e+00 - val_loss: 0.0544 - val_prc: 0.0698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8726 - f1_score: 0.0000e+00 - loss: 0.0517 - prc: 0.0699 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8717 - val_f1_score: 0.0000e+00 - val_loss: 0.0547 - val_prc: 0.0727 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8752 - f1_score: 0.0000e+00 - loss: 0.0542 - prc: 0.0760 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8636 - val_f1_score: 0.0000e+00 - val_loss: 0.0533 - val_prc: 0.0659 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8674 - f1_score: 0.0000e+00 - loss: 0.0516 - prc: 0.0794 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8637 - val_f1_score: 0.0000e+00 - val_loss: 0.0529 - val_prc: 0.0711 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8849 - f1_score: 0.0000e+00 - loss: 0.0518 - prc: 0.0891 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8675 - val_f1_score: 0.0000e+00 - val_loss: 0.0533 - val_prc: 0.0735 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8739 - f1_score: 0.0000e+00 - loss: 0.0524 - prc: 0.0761 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8650 - val_f1_score: 0.0000e+00 - val_loss: 0.0524 - val_prc: 0.0696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8816 - f1_score: 0.0000e+00 - loss: 0.0514 - prc: 0.0826 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8666 - val_f1_score: 0.0000e+00 - val_loss: 0.0529 - val_prc: 0.0736 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8771 - f1_score: 0.0000e+00 - loss: 0.0535 - prc: 0.0926 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8658 - val_f1_score: 0.0000e+00 - val_loss: 0.0523 - val_prc: 0.0720 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8755 - f1_score: 0.0000e+00 - loss: 0.0531 - prc: 0.0886 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8681 - val_f1_score: 0.0000e+00 - val_loss: 0.0528 - val_prc: 0.0717 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8894 - f1_score: 0.0000e+00 - loss: 0.0520 - prc: 0.0971 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8675 - val_f1_score: 0.0000e+00 - val_loss: 0.0527 - val_prc: 0.0719 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8931 - f1_score: 0.0000e+00 - loss: 0.0523 - prc: 0.1037 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8705 - val_f1_score: 0.0000e+00 - val_loss: 0.0526 - val_prc: 0.0742 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8844 - f1_score: 0.0000e+00 - loss: 0.0507 - prc: 0.0956 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8753 - val_f1_score: 0.0000e+00 - val_loss: 0.0527 - val_prc: 0.0786 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8878 - f1_score: 0.0000e+00 - loss: 0.0507 - prc: 0.1044 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8687 - val_f1_score: 0.0000e+00 - val_loss: 0.0516 - val_prc: 0.0788 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8818 - f1_score: 0.0000e+00 - loss: 0.0518 - prc: 0.0938 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8704 - val_f1_score: 0.0000e+00 - val_loss: 0.0520 - val_prc: 0.0783 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8919 - f1_score: 0.0000e+00 - loss: 0.0518 - prc: 0.1213 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8700 - val_f1_score: 0.0000e+00 - val_loss: 0.0516 - val_prc: 0.0757 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8900 - f1_score: 0.0000e+00 - loss: 0.0495 - prc: 0.0993 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8686 - val_f1_score: 0.0000e+00 - val_loss: 0.0514 - val_prc: 0.0779 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8907 - f1_score: 0.0000e+00 - loss: 0.0516 - prc: 0.1102 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8728 - val_f1_score: 0.0000e+00 - val_loss: 0.0516 - val_prc: 0.0820 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8958 - f1_score: 0.0000e+00 - loss: 0.0513 - prc: 0.1198 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8774 - val_f1_score: 0.0000e+00 - val_loss: 0.0516 - val_prc: 0.0828 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8987 - f1_score: 0.0000e+00 - loss: 0.0494 - prc: 0.1225 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8782 - val_f1_score: 0.0000e+00 - val_loss: 0.0525 - val_prc: 0.0841 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8865 - f1_score: 0.0000e+00 - loss: 0.0526 - prc: 0.1173 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8731 - val_f1_score: 0.0000e+00 - val_loss: 0.0512 - val_prc: 0.0793 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9005 - f1_score: 0.0000e+00 - loss: 0.0500 - prc: 0.1236 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8767 - val_f1_score: 0.0000e+00 - val_loss: 0.0510 - val_prc: 0.0812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8902 - f1_score: 0.0000e+00 - loss: 0.0490 - prc: 0.1005 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8798 - val_f1_score: 0.0000e+00 - val_loss: 0.0512 - val_prc: 0.0844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.8906 - f1_score: 0.0000e+00 - loss: 0.0493 - prc: 0.1270 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_auc: 0.8704 - val_f1_score: 0.0000e+00 - val_loss: 0.0507 - val_prc: 0.0836 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8982 - f1_score: 0.0011 - loss: 0.0493 - prc: 0.1277 - precision: 0.2753 - recall: 5.7011e-04 - val_auc: 0.8801 - val_f1_score: 0.0000e+00 - val_loss: 0.0512 - val_prc: 0.0873 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8854 - f1_score: 2.1014e-04 - loss: 0.0489 - prc: 0.1101 - precision: 0.0337 - recall: 1.0540e-04 - val_auc: 0.8790 - val_f1_score: 0.0000e+00 - val_loss: 0.0510 - val_prc: 0.0856 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.8900 - f1_score: 0.0030 - loss: 0.0500 - prc: 0.1115 - precision: 0.2955 - recall: 0.0015 - val_auc: 0.8709 - val_f1_score: 0.0000e+00 - val_loss: 0.0501 - val_prc: 0.0848 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8957 - f1_score: 0.0159 - loss: 0.0484 - prc: 0.1289 - precision: 0.7745 - recall: 0.0081 - val_auc: 0.8784 - val_f1_score: 0.0000e+00 - val_loss: 0.0503 - val_prc: 0.0855 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8953 - f1_score: 0.0030 - loss: 0.0486 - prc: 0.1329 - precision: 0.4713 - recall: 0.0015 - val_auc: 0.8828 - val_f1_score: 0.0000e+00 - val_loss: 0.0507 - val_prc: 0.0892 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9011 - f1_score: 0.0038 - loss: 0.0495 - prc: 0.1313 - precision: 0.2281 - recall: 0.0019 - val_auc: 0.8787 - val_f1_score: 0.0000e+00 - val_loss: 0.0500 - val_prc: 0.0907 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.8974 - f1_score: 0.0167 - loss: 0.0491 - prc: 0.1298 - precision: 0.4154 - recall: 0.0085 - val_auc: 0.8820 - val_f1_score: 0.0000e+00 - val_loss: 0.0503 - val_prc: 0.0934 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.9038 - f1_score: 0.0322 - loss: 0.0476 - prc: 0.1420 - precision: 0.6341 - recall: 0.0165 - val_auc: 0.8830 - val_f1_score: 0.0000e+00 - val_loss: 0.0502 - val_prc: 0.0943 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.9055 - f1_score: 0.0062 - loss: 0.0479 - prc: 0.1265 - precision: 0.3775 - recall: 0.0031 - val_auc: 0.8775 - val_f1_score: 0.0000e+00 - val_loss: 0.0500 - val_prc: 0.0947 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.8999 - f1_score: 0.0041 - loss: 0.0479 - prc: 0.1129 - precision: 0.3951 - recall: 0.0020 - val_auc: 0.8809 - val_f1_score: 0.0000e+00 - val_loss: 0.0501 - val_prc: 0.0938 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 51/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.9057 - f1_score: 0.0262 - loss: 0.0478 - prc: 0.1429 - precision: 0.3979 - recall: 0.0136 - val_auc: 0.8790 - val_f1_score: 0.0000e+00 - val_loss: 0.0497 - val_prc: 0.0937 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 52/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.9007 - f1_score: 0.0272 - loss: 0.0487 - prc: 0.1433 - precision: 0.5124 - recall: 0.0141 - val_auc: 0.8796 - val_f1_score: 0.0000e+00 - val_loss: 0.0496 - val_prc: 0.0971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 53/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.9080 - f1_score: 0.0182 - loss: 0.0477 - prc: 0.1374 - precision: 0.4309 - recall: 0.0093 - val_auc: 0.8795 - val_f1_score: 0.0000e+00 - val_loss: 0.0496 - val_prc: 0.0962 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 54/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8963 - f1_score: 0.0211 - loss: 0.0484 - prc: 0.1417 - precision: 0.3894 - recall: 0.0109 - val_auc: 0.8767 - val_f1_score: 0.0000e+00 - val_loss: 0.0493 - val_prc: 0.0993 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 55/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9039 - f1_score: 0.0176 - loss: 0.0459 - prc: 0.1377 - precision: 0.3612 - recall: 0.0090 - val_auc: 0.8855 - val_f1_score: 0.0000e+00 - val_loss: 0.0497 - val_prc: 0.1005 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 56/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9078 - f1_score: 0.0307 - loss: 0.0481 - prc: 0.1398 - precision: 0.4276 - recall: 0.0160 - val_auc: 0.8786 - val_f1_score: 0.0000e+00 - val_loss: 0.0492 - val_prc: 0.0984 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 57/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9009 - f1_score: 0.0513 - loss: 0.0496 - prc: 0.1502 - precision: 0.4678 - recall: 0.0272 - val_auc: 0.8849 - val_f1_score: 0.0000e+00 - val_loss: 0.0494 - val_prc: 0.1014 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 58/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9074 - f1_score: 0.0340 - loss: 0.0492 - prc: 0.1492 - precision: 0.3006 - recall: 0.0181 - val_auc: 0.8831 - val_f1_score: 0.0000e+00 - val_loss: 0.0491 - val_prc: 0.1005 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 59/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9099 - f1_score: 0.0207 - loss: 0.0474 - prc: 0.1383 - precision: 0.3169 - recall: 0.0107 - val_auc: 0.8839 - val_f1_score: 0.0000e+00 - val_loss: 0.0489 - val_prc: 0.1001 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 60/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9075 - f1_score: 0.0292 - loss: 0.0478 - prc: 0.1353 - precision: 0.2887 - recall: 0.0154 - val_auc: 0.8829 - val_f1_score: 0.0000e+00 - val_loss: 0.0488 - val_prc: 0.1001 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 61/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9030 - f1_score: 0.0460 - loss: 0.0483 - prc: 0.1456 - precision: 0.3659 - recall: 0.0246 - val_auc: 0.8757 - val_f1_score: 0.0000e+00 - val_loss: 0.0486 - val_prc: 0.1050 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 62/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9035 - f1_score: 0.0699 - loss: 0.0476 - prc: 0.1513 - precision: 0.4610 - recall: 0.0379 - val_auc: 0.8801 - val_f1_score: 0.0000e+00 - val_loss: 0.0489 - val_prc: 0.1040 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 63/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9045 - f1_score: 0.0918 - loss: 0.0477 - prc: 0.1654 - precision: 0.4617 - recall: 0.0511 - val_auc: 0.8785 - val_f1_score: 0.0000e+00 - val_loss: 0.0486 - val_prc: 0.1055 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 64/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9074 - f1_score: 0.0680 - loss: 0.0473 - prc: 0.1503 - precision: 0.3797 - recall: 0.0374 - val_auc: 0.8853 - val_f1_score: 0.0000e+00 - val_loss: 0.0488 - val_prc: 0.1078 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 65/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9148 - f1_score: 0.0424 - loss: 0.0467 - prc: 0.1500 - precision: 0.3916 - recall: 0.0225 - val_auc: 0.8854 - val_f1_score: 0.0000e+00 - val_loss: 0.0485 - val_prc: 0.1097 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 66/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9154 - f1_score: 0.0763 - loss: 0.0468 - prc: 0.1614 - precision: 0.3501 - recall: 0.0430 - val_auc: 0.8835 - val_f1_score: 0.0000e+00 - val_loss: 0.0482 - val_prc: 0.1095 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 67/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9083 - f1_score: 0.0342 - loss: 0.0462 - prc: 0.1410 - precision: 0.3258 - recall: 0.0182 - val_auc: 0.8850 - val_f1_score: 0.0000e+00 - val_loss: 0.0484 - val_prc: 0.1053 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 68/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9050 - f1_score: 0.0677 - loss: 0.0476 - prc: 0.1456 - precision: 0.3704 - recall: 0.0376 - val_auc: 0.8868 - val_f1_score: 0.0000e+00 - val_loss: 0.0482 - val_prc: 0.1097 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 69/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9045 - f1_score: 0.0507 - loss: 0.0471 - prc: 0.1379 - precision: 0.3374 - recall: 0.0275 - val_auc: 0.8852 - val_f1_score: 0.0000e+00 - val_loss: 0.0481 - val_prc: 0.1097 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 70/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9063 - f1_score: 0.0600 - loss: 0.0447 - prc: 0.1358 - precision: 0.3777 - recall: 0.0327 - val_auc: 0.8867 - val_f1_score: 0.0244 - val_loss: 0.0480 - val_prc: 0.1101 - val_precision: 0.3750 - val_recall: 0.0126
# Epoch 71/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9104 - f1_score: 0.0975 - loss: 0.0469 - prc: 0.1627 - precision: 0.4033 - recall: 0.0558 - val_auc: 0.8870 - val_f1_score: 0.0000e+00 - val_loss: 0.0479 - val_prc: 0.1126 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 72/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9112 - f1_score: 0.0711 - loss: 0.0458 - prc: 0.1493 - precision: 0.3987 - recall: 0.0392 - val_auc: 0.8851 - val_f1_score: 0.0165 - val_loss: 0.0478 - val_prc: 0.1132 - val_precision: 0.5000 - val_recall: 0.0084
# Epoch 73/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9037 - f1_score: 0.0695 - loss: 0.0477 - prc: 0.1635 - precision: 0.3563 - recall: 0.0386 - val_auc: 0.8870 - val_f1_score: 0.0000e+00 - val_loss: 0.0476 - val_prc: 0.1149 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 74/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9049 - f1_score: 0.0618 - loss: 0.0445 - prc: 0.1606 - precision: 0.4113 - recall: 0.0335 - val_auc: 0.8926 - val_f1_score: 0.0082 - val_loss: 0.0479 - val_prc: 0.1152 - val_precision: 0.2000 - val_recall: 0.0042
# Epoch 75/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9062 - f1_score: 0.0628 - loss: 0.0447 - prc: 0.1443 - precision: 0.3159 - recall: 0.0350 - val_auc: 0.8906 - val_f1_score: 0.0164 - val_loss: 0.0477 - val_prc: 0.1158 - val_precision: 0.3333 - val_recall: 0.0084
# Epoch 76/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9161 - f1_score: 0.0968 - loss: 0.0464 - prc: 0.1726 - precision: 0.3695 - recall: 0.0559 - val_auc: 0.8963 - val_f1_score: 0.0165 - val_loss: 0.0478 - val_prc: 0.1180 - val_precision: 0.4000 - val_recall: 0.0084
# Epoch 77/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9054 - f1_score: 0.1193 - loss: 0.0461 - prc: 0.1819 - precision: 0.4420 - recall: 0.0691 - val_auc: 0.8909 - val_f1_score: 0.0083 - val_loss: 0.0473 - val_prc: 0.1163 - val_precision: 0.2500 - val_recall: 0.0042
# Epoch 78/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9150 - f1_score: 0.0802 - loss: 0.0462 - prc: 0.1593 - precision: 0.3627 - recall: 0.0453 - val_auc: 0.8919 - val_f1_score: 0.0000e+00 - val_loss: 0.0472 - val_prc: 0.1189 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 79/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9133 - f1_score: 0.0794 - loss: 0.0473 - prc: 0.1696 - precision: 0.4024 - recall: 0.0445 - val_auc: 0.8851 - val_f1_score: 0.0000e+00 - val_loss: 0.0474 - val_prc: 0.1155 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 80/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9085 - f1_score: 0.0666 - loss: 0.0469 - prc: 0.1629 - precision: 0.3790 - recall: 0.0366 - val_auc: 0.8950 - val_f1_score: 0.0242 - val_loss: 0.0471 - val_prc: 0.1181 - val_precision: 0.3000 - val_recall: 0.0126
# Epoch 81/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9202 - f1_score: 0.0864 - loss: 0.0467 - prc: 0.1717 - precision: 0.4223 - recall: 0.0482 - val_auc: 0.8964 - val_f1_score: 0.0164 - val_loss: 0.0469 - val_prc: 0.1209 - val_precision: 0.3333 - val_recall: 0.0084
# Epoch 82/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9157 - f1_score: 0.1033 - loss: 0.0462 - prc: 0.1737 - precision: 0.3546 - recall: 0.0606 - val_auc: 0.8910 - val_f1_score: 0.0083 - val_loss: 0.0471 - val_prc: 0.1217 - val_precision: 0.2500 - val_recall: 0.0042
# Epoch 83/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9142 - f1_score: 0.0791 - loss: 0.0445 - prc: 0.1639 - precision: 0.4528 - recall: 0.0441 - val_auc: 0.9040 - val_f1_score: 0.0317 - val_loss: 0.0472 - val_prc: 0.1229 - val_precision: 0.2857 - val_recall: 0.0168
# Epoch 84/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9149 - f1_score: 0.1025 - loss: 0.0457 - prc: 0.1553 - precision: 0.3599 - recall: 0.0598 - val_auc: 0.9023 - val_f1_score: 0.0245 - val_loss: 0.0471 - val_prc: 0.1210 - val_precision: 0.4286 - val_recall: 0.0126
# Epoch 85/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9197 - f1_score: 0.0999 - loss: 0.0431 - prc: 0.1847 - precision: 0.3860 - recall: 0.0576 - val_auc: 0.9002 - val_f1_score: 0.0245 - val_loss: 0.0470 - val_prc: 0.1194 - val_precision: 0.4286 - val_recall: 0.0126
# Epoch 86/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9157 - f1_score: 0.0906 - loss: 0.0456 - prc: 0.1732 - precision: 0.3801 - recall: 0.0515 - val_auc: 0.9007 - val_f1_score: 0.0241 - val_loss: 0.0467 - val_prc: 0.1283 - val_precision: 0.2727 - val_recall: 0.0126
# Epoch 87/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9201 - f1_score: 0.1169 - loss: 0.0448 - prc: 0.1948 - precision: 0.3642 - recall: 0.0700 - val_auc: 0.9025 - val_f1_score: 0.0314 - val_loss: 0.0473 - val_prc: 0.1271 - val_precision: 0.2353 - val_recall: 0.0168
# Epoch 88/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9209 - f1_score: 0.0928 - loss: 0.0447 - prc: 0.1843 - precision: 0.3401 - recall: 0.0539 - val_auc: 0.9028 - val_f1_score: 0.0237 - val_loss: 0.0467 - val_prc: 0.1212 - val_precision: 0.2000 - val_recall: 0.0126
# Epoch 89/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9271 - f1_score: 0.1256 - loss: 0.0456 - prc: 0.1879 - precision: 0.4077 - recall: 0.0743 - val_auc: 0.9034 - val_f1_score: 0.0314 - val_loss: 0.0467 - val_prc: 0.1266 - val_precision: 0.2353 - val_recall: 0.0168
# Epoch 90/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9205 - f1_score: 0.1436 - loss: 0.0453 - prc: 0.2053 - precision: 0.4696 - recall: 0.0849 - val_auc: 0.8981 - val_f1_score: 0.0244 - val_loss: 0.0467 - val_prc: 0.1293 - val_precision: 0.3750 - val_recall: 0.0126
# Epoch 91/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9174 - f1_score: 0.1129 - loss: 0.0442 - prc: 0.1913 - precision: 0.4247 - recall: 0.0653 - val_auc: 0.8983 - val_f1_score: 0.0451 - val_loss: 0.0464 - val_prc: 0.1288 - val_precision: 0.2143 - val_recall: 0.0252
# Epoch 92/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9239 - f1_score: 0.1463 - loss: 0.0444 - prc: 0.1951 - precision: 0.4487 - recall: 0.0875 - val_auc: 0.9020 - val_f1_score: 0.0237 - val_loss: 0.0464 - val_prc: 0.1271 - val_precision: 0.2000 - val_recall: 0.0126
# Epoch 93/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9210 - f1_score: 0.1061 - loss: 0.0435 - prc: 0.1712 - precision: 0.3676 - recall: 0.0621 - val_auc: 0.9034 - val_f1_score: 0.0725 - val_loss: 0.0466 - val_prc: 0.1254 - val_precision: 0.2632 - val_recall: 0.0420
# Epoch 94/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9163 - f1_score: 0.1281 - loss: 0.0464 - prc: 0.1884 - precision: 0.3812 - recall: 0.0771 - val_auc: 0.9012 - val_f1_score: 0.0650 - val_loss: 0.0464 - val_prc: 0.1305 - val_precision: 0.2308 - val_recall: 0.0378
# Epoch 95/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9138 - f1_score: 0.0957 - loss: 0.0444 - prc: 0.1504 - precision: 0.3024 - recall: 0.0568 - val_auc: 0.8963 - val_f1_score: 0.0316 - val_loss: 0.0461 - val_prc: 0.1338 - val_precision: 0.2667 - val_recall: 0.0168
# Epoch 96/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9195 - f1_score: 0.0967 - loss: 0.0446 - prc: 0.1845 - precision: 0.3400 - recall: 0.0565 - val_auc: 0.9020 - val_f1_score: 0.0469 - val_loss: 0.0462 - val_prc: 0.1345 - val_precision: 0.3333 - val_recall: 0.0252
# Epoch 97/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9129 - f1_score: 0.1253 - loss: 0.0456 - prc: 0.1767 - precision: 0.3696 - recall: 0.0756 - val_auc: 0.9040 - val_f1_score: 0.0595 - val_loss: 0.0465 - val_prc: 0.1264 - val_precision: 0.2581 - val_recall: 0.0336
# Epoch 98/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9164 - f1_score: 0.1125 - loss: 0.0442 - prc: 0.1673 - precision: 0.3075 - recall: 0.0692 - val_auc: 0.9076 - val_f1_score: 0.0463 - val_loss: 0.0462 - val_prc: 0.1285 - val_precision: 0.2857 - val_recall: 0.0252
# Epoch 99/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9262 - f1_score: 0.1255 - loss: 0.0423 - prc: 0.1909 - precision: 0.4246 - recall: 0.0739 - val_auc: 0.9025 - val_f1_score: 0.0682 - val_loss: 0.0461 - val_prc: 0.1370 - val_precision: 0.3462 - val_recall: 0.0378
# Epoch 100/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9222 - f1_score: 0.1250 - loss: 0.0439 - prc: 0.1990 - precision: 0.4075 - recall: 0.0740 - val_auc: 0.9065 - val_f1_score: 0.0806 - val_loss: 0.0462 - val_prc: 0.1287 - val_precision: 0.3143 - val_recall: 0.0462
# Epoch 101/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9224 - f1_score: 0.1639 - loss: 0.0438 - prc: 0.2331 - precision: 0.4516 - recall: 0.1017 - val_auc: 0.9061 - val_f1_score: 0.0684 - val_loss: 0.0459 - val_prc: 0.1322 - val_precision: 0.3600 - val_recall: 0.0378
# Epoch 102/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9212 - f1_score: 0.1393 - loss: 0.0461 - prc: 0.1934 - precision: 0.3792 - recall: 0.0855 - val_auc: 0.8989 - val_f1_score: 0.0611 - val_loss: 0.0460 - val_prc: 0.1346 - val_precision: 0.3333 - val_recall: 0.0336
# Epoch 103/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9184 - f1_score: 0.1290 - loss: 0.0463 - prc: 0.1790 - precision: 0.3612 - recall: 0.0788 - val_auc: 0.9022 - val_f1_score: 0.0986 - val_loss: 0.0462 - val_prc: 0.1271 - val_precision: 0.3043 - val_recall: 0.0588
# Epoch 104/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9258 - f1_score: 0.1208 - loss: 0.0438 - prc: 0.1864 - precision: 0.3385 - recall: 0.0746 - val_auc: 0.9015 - val_f1_score: 0.0743 - val_loss: 0.0459 - val_prc: 0.1332 - val_precision: 0.3226 - val_recall: 0.0420
# Epoch 105/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9258 - f1_score: 0.1501 - loss: 0.0447 - prc: 0.2103 - precision: 0.4068 - recall: 0.0922 - val_auc: 0.9014 - val_f1_score: 0.0471 - val_loss: 0.0459 - val_prc: 0.1350 - val_precision: 0.3529 - val_recall: 0.0252
# Epoch 106/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9174 - f1_score: 0.1397 - loss: 0.0427 - prc: 0.2075 - precision: 0.4168 - recall: 0.0844 - val_auc: 0.9066 - val_f1_score: 0.0809 - val_loss: 0.0460 - val_prc: 0.1293 - val_precision: 0.3235 - val_recall: 0.0462
# Epoch 107/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9274 - f1_score: 0.1360 - loss: 0.0436 - prc: 0.1842 - precision: 0.3303 - recall: 0.0859 - val_auc: 0.9041 - val_f1_score: 0.0690 - val_loss: 0.0458 - val_prc: 0.1404 - val_precision: 0.3913 - val_recall: 0.0378
# Epoch 108/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9210 - f1_score: 0.1586 - loss: 0.0444 - prc: 0.2059 - precision: 0.4376 - recall: 0.0974 - val_auc: 0.9094 - val_f1_score: 0.0667 - val_loss: 0.0458 - val_prc: 0.1377 - val_precision: 0.2812 - val_recall: 0.0378
# Epoch 109/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9288 - f1_score: 0.1890 - loss: 0.0427 - prc: 0.2162 - precision: 0.4617 - recall: 0.1190 - val_auc: 0.9029 - val_f1_score: 0.0809 - val_loss: 0.0456 - val_prc: 0.1382 - val_precision: 0.3235 - val_recall: 0.0462
# Epoch 110/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9211 - f1_score: 0.1262 - loss: 0.0424 - prc: 0.1708 - precision: 0.3186 - recall: 0.0790 - val_auc: 0.9104 - val_f1_score: 0.0848 - val_loss: 0.0457 - val_prc: 0.1375 - val_precision: 0.2667 - val_recall: 0.0504
# Epoch 111/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9237 - f1_score: 0.1808 - loss: 0.0426 - prc: 0.1988 - precision: 0.4128 - recall: 0.1170 - val_auc: 0.8938 - val_f1_score: 0.0606 - val_loss: 0.0458 - val_prc: 0.1335 - val_precision: 0.3077 - val_recall: 0.0336
# Epoch 112/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9136 - f1_score: 0.1220 - loss: 0.0433 - prc: 0.1829 - precision: 0.3958 - recall: 0.0724 - val_auc: 0.9067 - val_f1_score: 0.0478 - val_loss: 0.0456 - val_prc: 0.1478 - val_precision: 0.4615 - val_recall: 0.0252
# Epoch 113/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9286 - f1_score: 0.1297 - loss: 0.0432 - prc: 0.2031 - precision: 0.4090 - recall: 0.0772 - val_auc: 0.9050 - val_f1_score: 0.1000 - val_loss: 0.0456 - val_prc: 0.1351 - val_precision: 0.3333 - val_recall: 0.0588
# Epoch 114/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9276 - f1_score: 0.1797 - loss: 0.0456 - prc: 0.2091 - precision: 0.4133 - recall: 0.1150 - val_auc: 0.9032 - val_f1_score: 0.0618 - val_loss: 0.0457 - val_prc: 0.1335 - val_precision: 0.3810 - val_recall: 0.0336
# Epoch 115/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9271 - f1_score: 0.1356 - loss: 0.0440 - prc: 0.1969 - precision: 0.3969 - recall: 0.0821 - val_auc: 0.9050 - val_f1_score: 0.1045 - val_loss: 0.0459 - val_prc: 0.1360 - val_precision: 0.3061 - val_recall: 0.0630
# Epoch 116/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9278 - f1_score: 0.1449 - loss: 0.0439 - prc: 0.1935 - precision: 0.3502 - recall: 0.0914 - val_auc: 0.8993 - val_f1_score: 0.0935 - val_loss: 0.0458 - val_prc: 0.1318 - val_precision: 0.3250 - val_recall: 0.0546
# Epoch 117/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9257 - f1_score: 0.1401 - loss: 0.0445 - prc: 0.1826 - precision: 0.3346 - recall: 0.0888 - val_auc: 0.9028 - val_f1_score: 0.0679 - val_loss: 0.0458 - val_prc: 0.1347 - val_precision: 0.3333 - val_recall: 0.0378
# Epoch 118/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9218 - f1_score: 0.1449 - loss: 0.0436 - prc: 0.1983 - precision: 0.3960 - recall: 0.0889 - val_auc: 0.9055 - val_f1_score: 0.0733 - val_loss: 0.0456 - val_prc: 0.1387 - val_precision: 0.2857 - val_recall: 0.0420
# Epoch 119/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9162 - f1_score: 0.1811 - loss: 0.0460 - prc: 0.2139 - precision: 0.4517 - recall: 0.1139 - val_auc: 0.8999 - val_f1_score: 0.0735 - val_loss: 0.0456 - val_prc: 0.1362 - val_precision: 0.2941 - val_recall: 0.0420
# Epoch 120/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9215 - f1_score: 0.2114 - loss: 0.0444 - prc: 0.2177 - precision: 0.4578 - recall: 0.1379 - val_auc: 0.9028 - val_f1_score: 0.0755 - val_loss: 0.0456 - val_prc: 0.1409 - val_precision: 0.3704 - val_recall: 0.0420
# Epoch 121/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9195 - f1_score: 0.1455 - loss: 0.0424 - prc: 0.1950 - precision: 0.3873 - recall: 0.0902 - val_auc: 0.9046 - val_f1_score: 0.1049 - val_loss: 0.0457 - val_prc: 0.1376 - val_precision: 0.3125 - val_recall: 0.0630
# Epoch 122/500
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9302 - f1_score: 0.1274 - loss: 0.0427 - prc: 0.1926 - precision: 0.3205 - recall: 0.0798 - val_auc: 0.9039 - val_f1_score: 0.0743 - val_loss: 0.0454 - val_prc: 0.1370 - val_precision: 0.3226 - val_recall: 0.0420
# Epoch 122: early stopping
# Restoring model weights from the end of the best epoch: 112.

# %% [markdown]
# # Model evaluation

# %%
def cutoff_youdens_j(fpr, tpr, thresholds):
    """
    Computes the optimal classification threshold using Youden's J statistic (sensitivity + specificity - 1).

    Parameters:
        fpr (array-like): False positive rates.
        tpr (array-like): True positive rates.
        thresholds (array-like): Thresholds corresponding to fpr and tpr.

    Returns:
        float: Threshold that maximises Youden's J statistic.
    """
    fpr = np.asarray(fpr)
    tpr = np.asarray(tpr)
    thresholds = np.asarray(thresholds)

    j_scores = tpr - fpr
    max_index = np.argmax(j_scores)
    return thresholds[max_index]


def plot_cm(y_true, y_pred_proba, threshold=0.5, labels=None, normalize=False):
    """
    Plots a confusion matrix using seaborn heatmap.

    Parameters:
        y_true (array-like): Ground truth binary labels.
        y_pred_proba (array-like): Predicted probabilities.
        threshold (float): Classification threshold to convert probabilities to binary predictions.
        labels (list): Optional list of class labels (e.g. ['Negative', 'Positive']).
        normalize (bool): Whether to normalize the confusion matrix.
    """
    y_pred = (y_pred_proba >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1, keepdims=True)
        fmt = '.2f'
    else:
        fmt = 'g'

    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, fmt=fmt, cmap='Blues_r', linewidths=0.5,
                xticklabels=labels or ['No core', 'Core'],
                yticklabels=labels or ['No core', 'Core'])
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.title(f'Confusion Matrix (threshold = {threshold:.4f})')
    plt.tight_layout()
    plt.show()

# %%
# Validation
y_val_pred = model.predict(X_val_scaled).flatten()
fpr, tpr, thresholds = roc_curve(y_val, y_val_pred)
classification_threshold_val = cutoff_youdens_j(fpr, tpr, thresholds)
print(f"Optimal threshold from validation: {classification_threshold_val:.3f}")
plot_cm(y_val, y_val_pred, threshold=classification_threshold_val)
# Out:
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# Optimal threshold from validation: 0.014

# %%
y_test_pred = model.predict(X_test_scaled).flatten()
plot_cm(y_test, y_test_pred, threshold=classification_threshold_val)
# Out:
# 695/695 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step

# %%
def reliability_curve(y_true, y_pred, bin_size=0.1, min_predictions_per_bin=100):
    """
    Computes the reliability curve (calibration curve) for a binary classifier.
    
    Parameters:
        y_true (array-like): Ground truth binary labels (0 or 1).
        y_pred (array-like): Predicted probabilities (between 0 and 1).
        bin_size (float): Width of the bins to divide probability space.
        min_predictions_per_bin (int): Minimum number of predictions in a bin to be included.
        
    Returns:
        bin_centers (list): Midpoints of the bins used.
        bin_positive_rates (list): Observed frequency of positive class in each bin.
        bin_counts (list): Number of predictions in each bin.
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    
    bins = np.arange(0, 1 + bin_size, bin_size)
    bin_centers = (bins[:-1] + bins[1:]) / 2
    
    bin_positive_rates = []
    bin_centers_output = []
    bin_counts = []

    for lower, upper, center in zip(bins[:-1], bins[1:], bin_centers):
        in_bin = (y_pred >= lower) & (y_pred < upper)
        count_in_bin = np.sum(in_bin)
        
        if count_in_bin >= min_predictions_per_bin:
            observed_rate = np.mean(y_true[in_bin])
            bin_positive_rates.append(round(observed_rate, 3))
            bin_centers_output.append(round(center, 3))
            bin_counts.append(count_in_bin)

    return bin_centers_output, bin_positive_rates, bin_counts

# %%
prob_pred, prob_true, no_pred_per_bin = reliability_curve(y_test, y_test_pred, min_predictions_per_bin=10)

plt.figure(figsize=(7,7))
plt.plot(prob_pred, prob_true, label=f"NN0{lead_time} Dakar")    
    
plt.xlabel("Predicted probability")
plt.ylabel("Obs. proportion of core")

no_pred_per_bin = [i/(1.1*np.max(no_pred_per_bin)) for i in no_pred_per_bin]
plt.plot(np.arange(0,1.2,0.2), np.arange(0,1.2,0.2))
plt.bar(prob_pred, no_pred_per_bin, width=0.1, linestyle="--", fill=False, edgecolor="green")

plt.xlim(0,1)
plt.ylim(0,1)

plt.legend(loc='upper center')
plt.show()

# %%
y_train_pred = model.predict(X_train_scaled)
auc_train = roc_auc_score(y_train, y_train_pred)
auc_val   = roc_auc_score(y_val, y_val_pred)
auc_test  = roc_auc_score(y_test, y_test_pred)
auc_persistence = roc_auc_score(y_test, y_persistence)
# Out:
# 2805/2805 ━━━━━━━━━━━━━━━━━━━━ 2s 651us/step

# %%
def plot_roc(name, y_true, y_pred_proba, **kwargs):
    """
    Plots the ROC curve with hit rate vs false alarm rate (% scale).
    
    Parameters:
        name (str): Label for the curve (e.g., model name).
        y_true (array-like): Ground truth binary labels (0 or 1).
        y_pred_proba (array-like): Predicted probabilities (from model).
        **kwargs: Additional plotting keyword arguments (e.g. linestyle, color).
    """
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    
    plt.plot(100 * fpr, 100 * tpr, label=name, linewidth=1.5, **kwargs)
    plt.xlabel('False Alarm Rate [%]')
    plt.ylabel('Hit Rate [%]')
    plt.xlim([-1, 100])
    plt.ylim([0, 105])
    plt.grid(True, linestyle=':', linewidth=0.5)
    plt.legend(loc='lower right')

# %%
plt.figure(figsize=(7,7))
plot_roc(f"Training set   (AUC={auc_train:.3f})", y_train, y_train_pred, color="red")
plot_roc(f"Testing set    (AUC={auc_test:.3f})", y_test, y_test_pred, color='green')
plot_roc(f"Persistence   (AUC={auc_persistence:.3f})", y_test, y_persistence, color='black', linestyle='-')
plt.plot(range(0,100), range(0,100), label='Random fcst (AUC=0.500)', linestyle='--', linewidth=1.5)
plt.title(f"NN0{lead_time} Dakar")
plt.legend(loc='lower right');

# %% [markdown]
# # Saving the model

# %%
# dump(scaler, f'./model-dakar-t{lead_time}.pkl')
# model.save(f'./model-dakar-t{lead_time}.keras')
