# %% [markdown]
# ### To check if the model initially designed for Dakar can be used for other locations

# %%
import pandas as pd                                                                     # type: ignore
import matplotlib.pyplot as plt                                                         # type: ignore
import seaborn as sns                                                                   # type: ignore
import numpy as np                                                                      # type: ignore
from  sklearn import metrics                                                            # type: ignore
from sklearn.preprocessing import StandardScaler                                        # type: ignore
from sklearn.metrics import roc_auc_score, roc_curve, brier_score_loss                  # type: ignore
from sklearn.metrics import average_precision_score                  # type: ignore
import tensorflow as tf                                                                 # type: ignore
from tensorflow.keras.initializers import he_normal # type: ignore
from sklearn.model_selection import train_test_split                                    # type: ignore
import matplotlib as mpl                                                                # type: ignore
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
mpl.rcParams['figure.figsize'] = (9, 7)
from joblib import dump, load                                                           # type: ignore
import sys
sys.path.insert(1, "/home/mendrika/mendrika-phd/codes/nflics")
import nflics

# %% [markdown]
# ### Importing dataset

# %%
data = pd.read_csv("train-data-Dakar.csv", index_col=False)
test_data = pd.read_csv("test-data-Dakar.csv", index_col=False)

# %% [markdown]
# ### Check if the data have outliers

# %%
variable = "lon"
for i in range(5):
    print(np.min(data[f"{variable}{i+1}"]), np.max(data[f"{variable}{i+1}"]))
# Out:
# -17.97 -8.04
# -17.97 -8.04
# -17.97 -2.4676860000000005
# -17.97 -2.4676860000000005
# -17.97 -2.4676860000000005

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def select(df):
    selection_index_lat = df["lat5"] < 30
    selection_index_lon = df["lon5"] < 30
    selection_index = selection_index_lat * selection_index_lon
    return selection_index

index_train = select(data)
index_test = select(test_data)

data = data[index_train]
test_data = test_data[index_test]

# %%
data = data.dropna()
test_data = test_data.dropna()

# %% [markdown]
# #### Choosing field to include in the data

# %%
lead_time = 3

# %%
# Presence or absence of storms in Dakar at time t+1
target_index = f"Cb_Dakar_t{lead_time}"

# Input at time t
t0 = "year,month,day,hour,minute,"
location = ""
wavelet_power = ""
storm_size = ""
distance = ""
for i in range(1,6):
    location += f"lat{i},lon{i},"
    wavelet_power += f"wp{i},"
    distance += f"ds{i},"
    storm_size += f"size{i},"
features = t0 + location + wavelet_power + storm_size + distance
field =  features + target_index
field = field.split(',')
data = data[field]
test_data = test_data[field]

# %% [markdown]
# ### Transforming latitude and longitude to relative latitude and relative longitude

# %%
Dakar_lon = -17.467686
Dakar_lat = 14.716677

# %%
Dakar_y, Dakar_x = nflics.X0(Dakar_lat, Dakar_lon)
Out_y, Out_x = nflics.X0(Dakar_lat, Dakar_lon+15)
round(np.sqrt((Dakar_y - Out_y)**2+ (Dakar_x - Out_x)**2))
# Out:
# 520

# %% [markdown]
# ### Correcting padding

# %%
"""for i in range(5):
    data.loc[data[f'size{i+1}'] == 0, [f'lat{i+1}', f'lon{i+1}', f'ds{i+1}']] = [Dakar_lat, Dakar_lon + 15, 520]
    test_data.loc[test_data[f'size{i+1}'] == 0, [f'lat{i+1}', f'lon{i+1}', f'ds{i+1}']] = [Dakar_lat, Dakar_lon + 15, 520]"""
# Out:
# "for i in range(5):\n    data.loc[data[f'size{i+1}'] == 0, [f'lat{i+1}', f'lon{i+1}', f'ds{i+1}']] = [Dakar_lat, Dakar_lon + 15, 520]\n    test_data.loc[test_data[f'size{i+1}'] == 0, [f'lat{i+1}', f'lon{i+1}', f'ds{i+1}']] = [Dakar_lat, Dakar_lon + 15, 520]"

# %% [markdown]
# ### Transforming to relative latitude and longitudes

# %%
for i in range(5):
    data[f"lat{i+1}"] = data[f"lat{i+1}"] - Dakar_lat
    data[f"lon{i+1}"] = data[f"lon{i+1}"] - Dakar_lon
    test_data[f"lat{i+1}"] = test_data[f"lat{i+1}"] - Dakar_lat
    test_data[f"lon{i+1}"] = test_data[f"lon{i+1}"] - Dakar_lon

# %%
data["loc_lat"] = np.cos(Dakar_lat * np.pi/180)
data["loc_lon"] = np.cos(Dakar_lon * np.pi/180)

# %%
test_data["loc_lat"] = np.cos(Dakar_lat * np.pi/180)
test_data["loc_lon"] = np.cos(Dakar_lon * np.pi/180)

# %% [markdown]
# ### Exploratory data analysis

# %%
def log_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i > 0:
                transformed.append(np.log(i))
            else:
                transformed.append(np.log(i+1e-8))    
        df_copy[key] = transformed
    return df_copy

# %%
def sqrt_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i >= 0:
                transformed.append(np.sqrt(i)) 
        df_copy[key] = transformed
    return df_copy

# %%
to_scale = wavelet_power + storm_size + distance

# %%
transform = True
if transform:
    data = log_transform(data, to_scale.split(',')[:-1])    
    data = sqrt_transform(data, t0.split(',')[:-1])
    test_data = log_transform(test_data, to_scale.split(',')[:-1])    
    test_data = sqrt_transform(test_data, t0.split(',')[:-1])

# %% [markdown]
# ### Splitting the data  into training and testing before oversampling the training set

# %%
train, validation = train_test_split(data, test_size=0.2, random_state=12)

# %%
neg, pos = train[target_index].value_counts()
total = neg + pos
print(f"Negative: {neg} and Positive: {pos}. That is {pos/total:.2f} of the total.")
# Out:
# Negative: 76886 and Positive: 6215. That is 0.07 of the total.

# %%
x_train = train.drop([target_index], axis=1).to_numpy()
y_train = train[target_index]

x_val = validation.drop([target_index], axis=1).to_numpy()
y_val = validation[target_index]

x_test = test_data.drop([target_index], axis=1).to_numpy()
y_test = test_data[target_index]

# %%
type = ('Train', 'Validation', 'Test')

storm_counts = {
    'No Storm': np.array([y_train.value_counts()[0], y_val.value_counts()[0], y_test.value_counts()[0]]),
    'Storm': np.array([y_train.value_counts()[1], y_val.value_counts()[1] , y_test.value_counts()[1]]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(7,5))
bottom = np.zeros(3)

for mode, count in storm_counts.items():
    p = ax.bar(type, count, width, label=mode, bottom=bottom)
    bottom += count

    ax.bar_label(p, label_type='center')

ax.legend()

plt.show()

# %% [markdown]
# ### Normalising the features

# %%
# normalise data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# %%
dump(scaler, f'Global-with-location-t{lead_time}.bin', compress=True)
# Out:
# ['Global-with-location-t3.bin']

# %% [markdown]
# ### Creating the model

# %%
initial_bias = np.log(pos/neg)
output_bias = tf.keras.initializers.Constant(value=initial_bias)

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(32,)),
  tf.keras.layers.Dense(16, activation='relu', kernel_initializer=he_normal()),
  tf.keras.layers.Dropout(0.2),    
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid', bias_initializer=output_bias)
])

l1_reg = tf.keras.regularizers.L1(0.1)
for layer in model.layers[:]:
  layer.kernel_regularizer = l1_reg

# t1: 0.35
# t3: 0.275

cl_thresholds = 0.275

METRICS = [
      tf.keras.metrics.MeanSquaredError(name='bs'),
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.TrueNegatives(name='tn'),                        
      tf.keras.metrics.Recall(name='recall', thresholds = cl_thresholds),
      tf.keras.metrics.Precision(name='precision', thresholds = cl_thresholds),
      tf.keras.metrics.AUC(name='auc'),
      tf.keras.metrics.AUC(name='prc', curve='PR'), 
      tf.keras.metrics.F1Score(name = 'f1_score',  threshold = cl_thresholds),
]


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=METRICS)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 673 (2.63 KB)
#  Trainable params: 673 (2.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
EPOCHS = 500
BATCH_SIZE = 1024

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_prc", 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)


# train the model
model_history = model.fit(x_train, 
                          y_train, 
                          epochs=EPOCHS, 
                          callbacks = [early_stopping],
                          batch_size = BATCH_SIZE,         
                          validation_data=(x_val, y_val),
                        )
# Out:
# Epoch 1/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - auc: 0.6238 - bs: 0.0749 - f1_score: 0.1835 - loss: 0.2805 - prc: 0.1377 - precision: 0.1819 - recall: 0.1926 - tn: 39322.4805 - tp: 183.7470 - val_auc: 0.7879 - val_bs: 0.0639 - val_f1_score: 0.2213 - val_loss: 0.2311 - val_prc: 0.2504 - val_precision: 0.3604 - val_recall: 0.1597 - val_tn: 19109.0000 - val_tp: 45.0000
# Epoch 2/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.7848 - bs: 0.0632 - f1_score: 0.2422 - loss: 0.2290 - prc: 0.2359 - precision: 0.3249 - recall: 0.1931 - tn: 39516.9141 - tp: 154.3855 - val_auc: 0.8270 - val_bs: 0.0623 - val_f1_score: 0.2283 - val_loss: 0.2196 - val_prc: 0.2701 - val_precision: 0.3536 - val_recall: 0.1686 - val_tn: 19143.0000 - val_tp: 30.0000
# Epoch 3/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8224 - bs: 0.0620 - f1_score: 0.2546 - loss: 0.2183 - prc: 0.2563 - precision: 0.3216 - recall: 0.2108 - tn: 39524.6875 - tp: 133.4699 - val_auc: 0.8385 - val_bs: 0.0618 - val_f1_score: 0.2027 - val_loss: 0.2157 - val_prc: 0.2761 - val_precision: 0.3578 - val_recall: 0.1414 - val_tn: 19173.0000 - val_tp: 9.0000
# Epoch 4/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8281 - bs: 0.0612 - f1_score: 0.2621 - loss: 0.2150 - prc: 0.2599 - precision: 0.3354 - recall: 0.2154 - tn: 39584.8320 - tp: 93.4337 - val_auc: 0.8431 - val_bs: 0.0613 - val_f1_score: 0.2191 - val_loss: 0.2127 - val_prc: 0.2807 - val_precision: 0.3490 - val_recall: 0.1597 - val_tn: 19176.0000 - val_tp: 10.0000
# Epoch 5/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8388 - bs: 0.0615 - f1_score: 0.2861 - loss: 0.2133 - prc: 0.2736 - precision: 0.3304 - recall: 0.2523 - tn: 39549.3867 - tp: 113.0723 - val_auc: 0.8464 - val_bs: 0.0611 - val_f1_score: 0.2115 - val_loss: 0.2114 - val_prc: 0.2848 - val_precision: 0.3568 - val_recall: 0.1503 - val_tn: 19178.0000 - val_tp: 7.0000
# Epoch 6/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8461 - bs: 0.0610 - f1_score: 0.2968 - loss: 0.2107 - prc: 0.2873 - precision: 0.3451 - recall: 0.2605 - tn: 39584.1680 - tp: 91.7470 - val_auc: 0.8492 - val_bs: 0.0608 - val_f1_score: 0.2226 - val_loss: 0.2098 - val_prc: 0.2889 - val_precision: 0.3672 - val_recall: 0.1597 - val_tn: 19182.0000 - val_tp: 5.0000
# Epoch 7/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8471 - bs: 0.0595 - f1_score: 0.2876 - loss: 0.2059 - prc: 0.2773 - precision: 0.3381 - recall: 0.2503 - tn: 39654.6875 - tp: 73.4096 - val_auc: 0.8510 - val_bs: 0.0607 - val_f1_score: 0.1995 - val_loss: 0.2094 - val_prc: 0.2934 - val_precision: 0.3765 - val_recall: 0.1357 - val_tn: 19186.0000 - val_tp: 3.0000
# Epoch 8/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8498 - bs: 0.0597 - f1_score: 0.3028 - loss: 0.2062 - prc: 0.2829 - precision: 0.3455 - recall: 0.2698 - tn: 39632.2891 - tp: 80.0241 - val_auc: 0.8526 - val_bs: 0.0605 - val_f1_score: 0.2099 - val_loss: 0.2083 - val_prc: 0.2965 - val_precision: 0.3783 - val_recall: 0.1452 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 9/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.8483 - bs: 0.0591 - f1_score: 0.3060 - loss: 0.2048 - prc: 0.2847 - precision: 0.3430 - recall: 0.2764 - tn: 39688.7344 - tp: 68.9157 - val_auc: 0.8541 - val_bs: 0.0606 - val_f1_score: 0.1844 - val_loss: 0.2084 - val_prc: 0.3017 - val_precision: 0.3983 - val_recall: 0.1199 - val_tn: 19188.0000 - val_tp: 1.0000
# Epoch 10/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8541 - bs: 0.0593 - f1_score: 0.3134 - loss: 0.2042 - prc: 0.2937 - precision: 0.3445 - recall: 0.2884 - tn: 39654.4453 - tp: 81.7590 - val_auc: 0.8549 - val_bs: 0.0603 - val_f1_score: 0.2236 - val_loss: 0.2072 - val_prc: 0.3027 - val_precision: 0.4080 - val_recall: 0.1540 - val_tn: 19187.0000 - val_tp: 3.0000
# Epoch 11/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8511 - bs: 0.0597 - f1_score: 0.3131 - loss: 0.2058 - prc: 0.2888 - precision: 0.3422 - recall: 0.2889 - tn: 39639.2422 - tp: 72.3614 - val_auc: 0.8559 - val_bs: 0.0602 - val_f1_score: 0.2085 - val_loss: 0.2070 - val_prc: 0.3048 - val_precision: 0.4018 - val_recall: 0.1408 - val_tn: 19188.0000 - val_tp: 3.0000
# Epoch 12/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8499 - bs: 0.0595 - f1_score: 0.3013 - loss: 0.2052 - prc: 0.2863 - precision: 0.3447 - recall: 0.2679 - tn: 39670.9258 - tp: 61.4940 - val_auc: 0.8569 - val_bs: 0.0600 - val_f1_score: 0.2357 - val_loss: 0.2062 - val_prc: 0.3071 - val_precision: 0.4059 - val_recall: 0.1660 - val_tn: 19188.0000 - val_tp: 3.0000
# Epoch 13/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8533 - bs: 0.0584 - f1_score: 0.3093 - loss: 0.2012 - prc: 0.2864 - precision: 0.3496 - recall: 0.2778 - tn: 39733.9023 - tp: 53.9518 - val_auc: 0.8581 - val_bs: 0.0597 - val_f1_score: 0.2743 - val_loss: 0.2048 - val_prc: 0.3077 - val_precision: 0.3945 - val_recall: 0.2102 - val_tn: 19185.0000 - val_tp: 4.0000
# Epoch 14/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8553 - bs: 0.0589 - f1_score: 0.3309 - loss: 0.2025 - prc: 0.2935 - precision: 0.3442 - recall: 0.3188 - tn: 39664.1797 - tp: 74.2892 - val_auc: 0.8591 - val_bs: 0.0596 - val_f1_score: 0.2748 - val_loss: 0.2043 - val_prc: 0.3088 - val_precision: 0.3964 - val_recall: 0.2102 - val_tn: 19185.0000 - val_tp: 4.0000
# Epoch 15/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8536 - bs: 0.0591 - f1_score: 0.3137 - loss: 0.2030 - prc: 0.2886 - precision: 0.3353 - recall: 0.2951 - tn: 39676.2539 - tp: 57.9639 - val_auc: 0.8597 - val_bs: 0.0596 - val_f1_score: 0.2656 - val_loss: 0.2042 - val_prc: 0.3101 - val_precision: 0.3921 - val_recall: 0.2008 - val_tn: 19184.0000 - val_tp: 4.0000
# Epoch 16/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8576 - bs: 0.0594 - f1_score: 0.3296 - loss: 0.2032 - prc: 0.2987 - precision: 0.3543 - recall: 0.3083 - tn: 39633.2773 - tp: 67.5904 - val_auc: 0.8608 - val_bs: 0.0598 - val_f1_score: 0.2295 - val_loss: 0.2047 - val_prc: 0.3133 - val_precision: 0.4163 - val_recall: 0.1585 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 17/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8543 - bs: 0.0588 - f1_score: 0.3179 - loss: 0.2026 - prc: 0.2995 - precision: 0.3534 - recall: 0.2892 - tn: 39686.9648 - tp: 61.6988 - val_auc: 0.8618 - val_bs: 0.0596 - val_f1_score: 0.2499 - val_loss: 0.2036 - val_prc: 0.3156 - val_precision: 0.4089 - val_recall: 0.1799 - val_tn: 19187.0000 - val_tp: 2.0000
# Epoch 18/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8573 - bs: 0.0582 - f1_score: 0.3258 - loss: 0.2000 - prc: 0.2971 - precision: 0.3490 - recall: 0.3056 - tn: 39705.6016 - tp: 57.5181 - val_auc: 0.8624 - val_bs: 0.0592 - val_f1_score: 0.2951 - val_loss: 0.2024 - val_prc: 0.3150 - val_precision: 0.3951 - val_recall: 0.2355 - val_tn: 19183.0000 - val_tp: 5.0000
# Epoch 19/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.
500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8657 - bs: 0.0572 - f1_score: 0.3537 - loss: 0.1957 - prc: 0.3164 - precision: 0.3581 - recall: 0.3496 - tn: 39703.4570 - tp: 58.5783 - val_auc: 0.8709 - val_bs: 0.0582 - val_f1_score: 0.3383 - val_loss: 0.1978 - val_prc: 0.3330 - val_precision: 0.4003 - val_recall: 0.2929 - val_tn: 19190.0000 - val_tp: 2.0000
# Epoch 42/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8680 - bs: 0.0574 - f1_score: 0.3583 - loss: 0.1957 - prc: 0.3253 - precision: 0.3609 - recall: 0.3558 - tn: 39708.2031 - tp: 68.2530 - val_auc: 0.8708 - val_bs: 0.0584 - val_f1_score: 0.3258 - val_loss: 0.1982 - val_prc: 0.3344 - val_precision: 0.4104 - val_recall: 0.2702 - val_tn: 19190.0000 - val_tp: 1.0000
# Epoch 43/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8736 - bs: 0.0571 - f1_score: 0.3755 - loss: 0.1936 - prc: 0.3398 - precision: 0.3719 - recall: 0.3795 - tn: 39665.4219 - tp: 94.6867 - val_auc: 0.8718 - val_bs: 0.0583 - val_f1_score: 0.3312 - val_loss: 0.1979 - val_prc: 0.3350 - val_precision: 0.4128 - val_recall: 0.2765 - val_tn: 19190.0000 - val_tp: 1.0000
# Epoch 44/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8681 - bs: 0.0573 - f1_score: 0.3620 - loss: 0.1955 - prc: 0.3262 - precision: 0.3609 - recall: 0.3632 - tn: 39703.9414 - tp: 75.5783 - val_auc: 0.8719 - val_bs: 0.0583 - val_f1_score: 0.3294 - val_loss: 0.1977 - val_prc: 0.3379 - val_precision: 0.4172 - val_recall: 0.2721 - val_tn: 19190.0000 - val_tp: 0.0000e+00
# Epoch 45/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8706 - bs: 0.0574 - f1_score: 0.3690 - loss: 0.1954 - prc: 0.3355 - precision: 0.3740 - recall: 0.3646 - tn: 39665.9258 - tp: 87.1325 - val_auc: 0.8722 - val_bs: 0.0580 - val_f1_score: 0.3504 - val_loss: 0.1969 - val_prc: 0.3367 - val_precision: 0.4040 - val_recall: 0.3093 - val_tn: 19189.0000 - val_tp: 2.0000
# Epoch 46/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8735 - bs: 0.0567 - f1_score: 0.3783 - loss: 0.1927 - prc: 0.3363 - precision: 0.3655 - recall: 0.3922 - tn: 39689.9141 - tp: 99.6024 - val_auc: 0.8728 - val_bs: 0.0581 - val_f1_score: 0.3371 - val_loss: 0.1971 - val_prc: 0.3387 - val_precision: 0.4214 - val_recall: 0.2809 - val_tn: 19190.0000 - val_tp: 0.0000e+00
# Epoch 47/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8667 - bs: 0.0575 - f1_score: 0.3542 - loss: 0.1962 - prc: 0.3261 - precision: 0.3567 - recall: 0.3521 - tn: 39677.1914 - tp: 88.6145 - val_auc: 0.8729 - val_bs: 0.0581 - val_f1_score: 0.3309 - val_loss: 0.1972 - val_prc: 0.3401 - val_precision: 0.4148 - val_recall: 0.2753 - val_tn: 19191.0000 - val_tp: 0.0000e+00
# Epoch 48/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8708 - bs: 0.0563 - f1_score: 0.3610 - loss: 0.1921 - prc: 0.3308 - precision: 0.3644 - recall: 0.3582 - tn: 39724.2891 - tp: 83.9157 - val_auc: 0.8732 - val_bs: 0.0580 - val_f1_score: 0.3385 - val_loss: 0.1967 - val_prc: 0.3398 - val_precision: 0.4056 - val_recall: 0.2904 - val_tn: 19190.0000 - val_tp: 2.0000
# Epoch 49/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8724 - bs: 0.0569 - f1_score: 0.3731 - loss: 0.1936 - prc: 0.3340 - precision: 0.3681 - recall: 0.3783 - tn: 39678.6523 - tp: 88.6506 - val_auc: 0.8732 - val_bs: 0.0582 - val_f1_score: 0.3322 - val_loss: 0.1971 - val_prc: 0.3412 - val_precision: 0.4263 - val_recall: 0.2721 - val_tn: 19190.0000 - val_tp: 0.0000e+00
# Epoch 50/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8698 - bs: 0.0569 - f1_score: 0.3663 - loss: 0.1939 - prc: 0.3270 - precision: 0.3628 - recall: 0.3699 - tn: 39720.5078 - tp: 64.3976 - val_auc: 0.8734 - val_bs: 0.0579 - val_f1_score: 0.3526 - val_loss: 0.1963 - val_prc: 0.3418 - val_precision: 0.4044 - val_recall: 0.3125 - val_tn: 19190.0000 - val_tp: 3.0000
# Epoch 51/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8698 - bs: 0.0571 - f1_score: 0.3793 - loss: 0.1949 - prc: 0.3351 - precision: 0.3697 - recall: 0.3895 - tn: 39675.3750 - tp: 104.6627 - val_auc: 0.8738 - val_bs: 0.0578 - val_f1_score: 0.3516 - val_loss: 0.1962 - val_prc: 0.3418 - val_precision: 0.3968 - val_recall: 0.3157 - val_tn: 19188.0000 - val_tp: 5.0000
# Epoch 52/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8724 - bs: 0.0569 - f1_score: 0.3795 - loss: 0.1936 - prc: 0.3369 - precision: 0.3607 - recall: 0.4006 - tn: 39656.5430 - tp: 128.9398 - val_auc: 0.8742 - val_bs: 0.0579 - val_f1_score: 0.3486 - val_loss: 0.1961 - val_prc: 0.3430 - val_precision: 0.4150 - val_recall: 0.3005 - val_tn: 19189.0000 - val_tp: 1.0000
# Epoch 53/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8765 - bs: 0.0567 - f1_score: 0.3843 - loss: 0.1922 - prc: 0.3530 - precision: 0.3787 - recall: 0.3900 - tn: 39661.8672 - tp: 103.7108 - val_auc: 0.8747 - val_bs: 0.0577 - val_f1_score: 0.3616 - val_loss: 0.1954 - val_prc: 0.3408 - val_precision: 0.3925 - val_recall: 0.3352 - val_tn: 19186.0000 - val_tp: 6.0000
# Epoch 54/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.8698 - bs: 0.0571 - f1_score: 0.3693 - loss: 0.1943 - prc: 0.3269 - precision: 0.3562 - recall: 0.3834 - tn: 39664.4922 - tp: 102.0241 - val_auc: 0.8748 - val_bs: 0.0583 - val_f1_score: 0.3113 - val_loss: 0.1971 - val_prc: 0.3430 - val_precision: 0.4410 - val_recall: 0.2405 - val_tn: 19191.0000 - val_tp: 0.0000e+00
# Epoch 55/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8726 - bs: 0.0568 - f1_score: 0.3705 - loss: 0.1930 - prc: 0.3346 - precision: 0.3712 - recall: 0.3707 - tn: 39697.6016 - tp: 85.0000 - val_auc: 0.8756 - val_bs: 0.0576 - val_f1_score: 0.3641 - val_loss: 0.1952 - val_prc: 0.3445 - val_precision: 0.4038 - val_recall: 0.3314 - val_tn: 19185.0000 - val_tp: 6.0000
# Epoch 56/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8728 - bs: 0.0572 - f1_score: 0.3799 - loss: 0.1943 - prc: 0.3360 - precision: 0.3672 - recall: 0.3938 - tn: 39660.2539 - tp: 122.1325 - val_auc: 0.8755 - val_bs: 0.0576 - val_f1_score: 0.3639 - val_loss: 0.1950 - val_prc: 0.3446 - val_precision: 0.4006 - val_recall: 0.3333 - val_tn: 19181.0000 - val_tp: 8.0000
# Epoch 57/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8752 - bs: 0.0570 - f1_score: 0.3846 - loss: 0.1934 - prc: 0.3449 - precision: 0.3689 - recall: 0.4021 - tn: 39627.1094 - tp: 124.3133 - val_auc: 0.8755 - val_bs: 0.0579 - val_f1_score: 0.3444 - val_loss: 0.1957 - val_prc: 0.3429 - val_precision: 0.4190 - val_recall: 0.2923 - val_tn: 19189.0000 - val_tp: 0.0000e+00
# Epoch 58/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8750 - bs: 0.0569 - f1_score: 0.3833 - loss: 0.1932 - prc: 0.3398 - precision: 0.3743 - recall: 0.3929 - tn: 39672.4805 - tp: 84.8795 - val_auc: 0.8757 - val_bs: 0.0578 - val_f1_score: 0.3462 - val_loss: 0.1955 - val_prc: 0.3436 - val_precision: 0.4107 - val_recall: 0.2992 - val_tn: 19189.0000 - val_tp: 0.0000e+00
# Epoch 59/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8741 - bs: 0.0570 - f1_score: 0.3816 - loss: 0.1940 - prc: 0.3498 - precision: 0.3710 - recall: 0.3929 - tn: 39654.3125 - tp: 104.6506 - val_auc: 0.8758 - val_bs: 0.0578 - val_f1_score: 0.3479 - val_loss: 0.1954 - val_prc: 0.3434 - val_precision: 0.4154 - val_recall: 0.2992 - val_tn: 19188.0000 - val_tp: 1.0000
# Epoch 60/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8726 - bs: 0.0563 - f1_score: 0.3694 - loss: 0.1920 - prc: 0.3387 - precision: 0.3671 - recall: 0.3720 - tn: 39716.6758 - tp: 86.9759 - val_auc: 0.8761 - val_bs: 0.0576 - val_f1_score: 0.3543 - val_loss: 0.1949 - val_prc: 0.3435 - val_precision: 0.3967 - val_recall: 0.3201 - val_tn: 19186.0000 - val_tp: 4.0000
# Epoch 61/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8744 - bs: 0.0564 - f1_score: 0.3810 - loss: 0.1916 - prc: 0.3362 - precision: 0.3687 - recall: 0.3943 - tn: 39689.3008 - tp: 107.2289 - val_auc: 0.8760 - val_bs: 0.0577 - val_f1_score: 0.3535 - val_loss: 0.1951 - val_prc: 0.3459 - val_precision: 0.4134 - val_recall: 0.3087 - val_tn: 19189.0000 - val_tp: 1.0000
# Epoch 62/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8759 - bs: 0.0563 - f1_score: 0.3809 - loss: 0.1909 - prc: 0.3412 - precision: 0.3677 - recall: 0.3953 - tn: 39684.6250 - tp: 102.2530 - val_auc: 0.8765 - val_bs: 0.0577 - val_f1_score: 0.3510 - val_loss: 0.1948 - val_prc: 0.3446 - val_precision: 0.4056 - val_recall: 0.3093 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 63/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.
500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8762 - bs: 0.0572 - f1_score: 0.3810 - loss: 0.1930 - prc: 0.3441 - precision: 0.3672 - recall: 0.3962 - tn: 39644.1328 - tp: 132.0482 - val_auc: 0.8768 - val_bs: 0.0576 - val_f1_score: 0.3580 - val_loss: 0.1944 - val_prc: 0.3457 - val_precision: 0.3954 - val_recall: 0.3270 - val_tn: 19186.0000 - val_tp: 5.0000
# Epoch 72/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8781 - bs: 0.0563 - f1_score: 0.3835 - loss: 0.1904 - prc: 0.3463 - precision: 0.3615 - recall: 0.4087 - tn: 39661.1797 - tp: 118.1687 - val_auc: 0.8775 - val_bs: 0.0577 - val_f1_score: 0.3428 - val_loss: 0.1947 - val_prc: 0.3491 - val_precision: 0.4168 - val_recall: 0.2910 - val_tn: 19191.0000 - val_tp: 1.0000
# Epoch 73/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8760 - bs: 0.0562 - f1_score: 0.3777 - loss: 0.1910 - prc: 0.3478 - precision: 0.3717 - recall: 0.3842 - tn: 39683.8672 - tp: 116.9277 - val_auc: 0.8770 - val_bs: 0.0577 - val_f1_score: 0.3445 - val_loss: 0.1946 - val_prc: 0.3448 - val_precision: 0.4002 - val_recall: 0.3024 - val_tn: 19188.0000 - val_tp: 5.0000
# Epoch 74/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8764 - bs: 0.0577 - f1_score: 0.3992 - loss: 0.1949 - prc: 0.3549 - precision: 0.3792 - recall: 0.4216 - tn: 39613.6641 - tp: 128.1205 - val_auc: 0.8776 - val_bs: 0.0576 - val_f1_score: 0.3541 - val_loss: 0.1944 - val_prc: 0.3451 - val_precision: 0.4002 - val_recall: 0.3176 - val_tn: 19185.0000 - val_tp: 5.0000
# Epoch 75/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.8783 - bs: 0.0562 - f1_score: 0.3847 - loss: 0.1900 - prc: 0.3407 - precision: 0.3682 - recall: 0.4028 - tn: 39691.0000 - tp: 112.2651 - val_auc: 0.8777 - val_bs: 0.0575 - val_f1_score: 0.3573 - val_loss: 0.1940 - val_prc: 0.3458 - val_precision: 0.3965 - val_recall: 0.3251 - val_tn: 19185.0000 - val_tp: 7.0000
# Epoch 76/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8763 - bs: 0.0560 - f1_score: 0.3859 - loss: 0.1901 - prc: 0.3417 - precision: 0.3630 - recall: 0.4127 - tn: 39673.1562 - tp: 129.2771 - val_auc: 0.8777 - val_bs: 0.0576 - val_f1_score: 0.3522 - val_loss: 0.1944 - val_prc: 0.3476 - val_precision: 0.4099 - val_recall: 0.3087 - val_tn: 19186.0000 - val_tp: 4.0000
# Epoch 77/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8752 - bs: 0.0553 - f1_score: 0.3748 - loss: 0.1881 - prc: 0.3355 - precision: 0.3631 - recall: 0.3875 - tn: 39727.8906 - tp: 103.7831 - val_auc: 0.8777 - val_bs: 0.0573 - val_f1_score: 0.3857 - val_loss: 0.1935 - val_prc: 0.3458 - val_precision: 0.3902 - val_recall: 0.3813 - val_tn: 19171.0000 - val_tp: 17.0000
# Epoch 78/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8760 - bs: 0.0570 - f1_score: 0.3881 - loss: 0.1927 - prc: 0.3399 - precision: 0.3658 - recall: 0.4135 - tn: 39654.2422 - tp: 110.6988 - val_auc: 0.8775 - val_bs: 0.0577 - val_f1_score: 0.3500 - val_loss: 0.1947 - val_prc: 0.3485 - val_precision: 0.4190 - val_recall: 0.3005 - val_tn: 19189.0000 - val_tp: 4.0000
# Epoch 79/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8766 - bs: 0.0564 - f1_score: 0.4012 - loss: 0.1917 - prc: 0.3514 - precision: 0.3825 - recall: 0.4219 - tn: 39603.8086 - tp: 151.0843 - val_auc: 0.8780 - val_bs: 0.0577 - val_f1_score: 0.3492 - val_loss: 0.1945 - val_prc: 0.3508 - val_precision: 0.4204 - val_recall: 0.2986 - val_tn: 19189.0000 - val_tp: 5.0000
# Epoch 80/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8756 - bs: 0.0570 - f1_score: 0.3873 - loss: 0.1930 - prc: 0.3421 - precision: 0.3732 - recall: 0.4026 - tn: 39636.4219 - tp: 129.0361 - val_auc: 0.8780 - val_bs: 0.0575 - val_f1_score: 0.3581 - val_loss: 0.1940 - val_prc: 0.3484 - val_precision: 0.4062 - val_recall: 0.3201 - val_tn: 19185.0000 - val_tp: 5.0000
# Epoch 81/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8754 - bs: 0.0561 - f1_score: 0.3771 - loss: 0.1904 - prc: 0.3385 - precision: 0.3580 - recall: 0.3983 - tn: 39674.0352 - tp: 118.8795 - val_auc: 0.8781 - val_bs: 0.0573 - val_f1_score: 0.3704 - val_loss: 0.1935 - val_prc: 0.3496 - val_precision: 0.3928 - val_recall: 0.3504 - val_tn: 19183.0000 - val_tp: 10.0000
# Epoch 82/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8803 - bs: 0.0559 - f1_score: 0.4001 - loss: 0.1891 - prc: 0.3525 - precision: 0.3835 - recall: 0.4186 - tn: 39624.9141 - tp: 157.4096 - val_auc: 0.8781 - val_bs: 0.0576 - val_f1_score: 0.3503 - val_loss: 0.1942 - val_prc: 0.3479 - val_precision: 0.4081 - val_recall: 0.3068 - val_tn: 19188.0000 - val_tp: 3.0000
# Epoch 83/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8765 - bs: 0.0567 - f1_score: 0.3888 - loss: 0.1920 - prc: 0.3482 - precision: 0.3726 - recall: 0.4065 - tn: 39672.5547 - tp: 122.3614 - val_auc: 0.8778 - val_bs: 0.0574 - val_f1_score: 0.3651 - val_loss: 0.1938 - val_prc: 0.3493 - val_precision: 0.3972 - val_recall: 0.3378 - val_tn: 19184.0000 - val_tp: 8.0000
# Epoch 84/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8804 - bs: 0.0565 - f1_score: 0.3997 - loss: 0.1907 - prc: 0.3538 - precision: 0.3748 - recall: 0.4284 - tn: 39629.3008 - tp: 142.0843 - val_auc: 0.8778 - val_bs: 0.0577 - val_f1_score: 0.3420 - val_loss: 0.1944 - val_prc: 0.3482 - val_precision: 0.4097 - val_recall: 0.2936 - val_tn: 19188.0000 - val_tp: 3.0000
# Epoch 85/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8802 - bs: 0.0566 - f1_score: 0.3897 - loss: 0.1908 - prc: 0.3514 - precision: 0.3799 - recall: 0.4002 - tn: 39652.9531 - tp: 125.7108 - val_auc: 0.8774 - val_bs: 0.0576 - val_f1_score: 0.3583 - val_loss: 0.1941 - val_prc: 0.3448 - val_precision: 0.3989 - val_recall: 0.3251 - val_tn: 19184.0000 - val_tp: 7.0000
# Epoch 86/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8790 - bs: 0.0565 - f1_score: 0.3972 - loss: 0.1912 - prc: 0.3582 - precision: 0.3800 - recall: 0.4160 - tn: 39624.0469 - tp: 146.3615 - val_auc: 0.8777 - val_bs: 0.0578 - val_f1_score: 0.3426 - val_loss: 0.1945 - val_prc: 0.3470 - val_precision: 0.4102 - val_recall: 0.2942 - val_tn: 19187.0000 - val_tp: 5.0000
# Epoch 87/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8804 - bs: 0.0565 - f1_score: 0.4018 - loss: 0.1910 - prc: 0.3591 - precision: 0.3762 - recall: 0.4314 - tn: 39595.0352 - tp: 162.8795 - val_auc: 0.8779 - val_bs: 0.0576 - val_f1_score: 0.3504 - val_loss: 0.1942 - val_prc: 0.3494 - val_precision: 0.4118 - val_recall: 0.3049 - val_tn: 19187.0000 - val_tp: 5.0000
# Epoch 88/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8776 - bs: 0.0560 - f1_score: 0.3834 - loss: 0.1898 - prc: 0.3455 - precision: 0.3721 - recall: 0.3955 - tn: 39668.0117 - tp: 119.0120 - val_auc: 0.8775 - val_bs: 0.0576 - val_f1_score: 0.3591 - val_loss: 0.1941 - val_prc: 0.3467 - val_precision: 0.3946 - val_recall: 0.3295 - val_tn: 19184.0000 - val_tp: 7.0000
# Epoch 89/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8765 - bs: 0.0564 - f1_score: 0.3872 - loss: 0.1913 - prc: 0.3477 - precision: 0.3729 - recall: 0.4027 - tn: 39672.8906 - tp: 120.6867 - val_auc: 0.8783 - val_bs: 0.0573 - val_f1_score: 0.3808 - val_loss: 0.1932 - val_prc: 0.3476 - val_precision: 0.3888 - val_recall: 0.3731 - val_tn: 19167.0000 - val_tp: 21.0000
# Epoch 89: early stopping
# Restoring model weights from the end of the best epoch: 79.

# %%
def class_prediction(x, y):
    y_hat = model.predict(x)      
    bs = brier_score_loss(y, y_hat)    
    auc = roc_auc_score(y, y_hat)
    return y_hat, auc, bs

# %%
def plot_cm(y, y_hat, classification_threshold):
    # compute the contingency table    
    y_hat_class = y_hat >= classification_threshold
    cm = metrics.confusion_matrix(y, y_hat_class)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, linewidths=.5, square = True, cmap = 'Blues_r', cbar=None, fmt='g')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def plot_metrics(history):
  metrics = ['loss', 'bs', 'recall', 'precision']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color="red", label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.5,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %% [markdown]
# ### Performance on training data

# %%
plot_metrics(model_history)

# %% [markdown]
# ### Performance on testing data

# %%
def cutoff_youdens_j(fpr, tpr, thresholds):
    j_scores = tpr-fpr
    j_ordered = sorted(zip(j_scores, thresholds))
    return j_ordered[-1][1]

# %%
y_hat_val, auc_val, bs_val = class_prediction(x_val, y_val)
classification_threshold_val = cutoff_youdens_j(*roc_curve(y_val, y_hat_val))
print(classification_threshold_val)
plot_cm(y_val, y_hat_val, classification_threshold=classification_threshold_val)
# Out:
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 0.06920294

# %%
average_precision_score(y_val, y_hat_val)
# Out:
# 0.35149430982181423

# %%
y_hat_test, auc_test, bs_test = class_prediction(x_test, y_test)
classification_threshold = cutoff_youdens_j(*roc_curve(y_test, y_hat_test))
plot_cm(y_test, y_hat_test, classification_threshold=classification_threshold_val)
# Out:
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
average_precision_score(y_test, y_hat_test)
# Out:
# 0.34589110225845915

# %%
def reliability_curve(y, y_pred, bin_size=0.1, count_pred_per_bin=100):
  y = np.array(y)
  y_pred = np.array(y_pred)
  bins = np.arange(0, 1+bin_size, bin_size)
  bin_centers = [(b1 + b2) / 2 for b1, b2 in zip(bins[:-1], bins[1:])]
  prop_positive = []
  bin_center_ax = []
  no_pred_per_bin = []
  for b1, b2, bc in zip(bins[:-1], bins[1:], bin_centers):
    in_bin = np.logical_and(y_pred >= b1, y_pred < b2)
    no_predictions_per_bin = np.sum(in_bin)
    no_positive_per_bin = np.sum(y[in_bin])    
    if no_predictions_per_bin > count_pred_per_bin:
      prop_pos = round(no_positive_per_bin/no_predictions_per_bin, 3)
      prop_positive.append(prop_pos)
      bin_center_ax.append(round(bc, 3))
      no_pred_per_bin.append(no_predictions_per_bin)
    else:
      continue
  return bin_center_ax, prop_positive, no_pred_per_bin

# %%
prob_pred, prob_true, no_pred_per_bin = reliability_curve(y_test, y_hat_test.flatten())
plt.figure(figsize=(5,4))
plt.plot(prob_pred, prob_true, label=f"NN0{lead_time} Dakar")    
    
plt.xlabel("Predicted probability")
plt.ylabel("Obs. proportion of positive case")

no_pred_per_bin = [i/(1.1*np.max(no_pred_per_bin)) for i in no_pred_per_bin]
plt.plot(np.arange(0,1.2,0.2), np.arange(0,1.2,0.2))
plt.bar(prob_pred, no_pred_per_bin, width=0.1, linestyle="--", fill=False, edgecolor="green")

plt.xlim(0,1)
plt.ylim(0,1)
plt.legend(loc='upper center')
plt.show()

# %%
model.save(f'/home/mendrika/mendrika-phd/codes/nflics/model-ML-Dakar/Global-with-location-t{lead_time}.keras')

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = metrics.roc_curve(labels, predictions)
  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False alarm [%]')
  plt.ylabel('Hit [%]')
  plt.xlim([0,100])
  plt.ylim([0,100])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
y_hat_train, auc_train, bs_train = class_prediction(x_train, y_train)
plot_roc(f"Training set (AUC={auc_train:.3f})", y_train, y_hat_train, color="red")
plot_roc(f"Testing set  (AUC={auc_test:.3f})", y_test, y_hat_test, color=colors[0], linestyle='--')
plt.title(f"NN0{lead_time} Dakar")
plt.legend(loc='lower right');
# Out:
# 2597/2597 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
