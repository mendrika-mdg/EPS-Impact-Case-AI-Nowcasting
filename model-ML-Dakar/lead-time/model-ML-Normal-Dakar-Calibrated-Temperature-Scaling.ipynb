# %% [markdown]
# ### Specific data for specific city

# %%
import pandas as pd                                                                     # type: ignore
import matplotlib.pyplot as plt                                                         # type: ignore
import seaborn as sns                                                                   # type: ignore
import numpy as np                                                                      # type: ignore
from  sklearn import metrics                                                            # type: ignore
from sklearn.linear_model import LogisticRegression                                     # type: ignore
from sklearn.preprocessing import StandardScaler                                        # type: ignore
from sklearn.metrics import roc_auc_score, roc_curve, brier_score_loss                  # type: ignore
from sklearn.metrics import average_precision_score                                     # type: ignore
import tensorflow as tf                                                                 # type: ignore
from tensorflow.keras.initializers import he_normal # type: ignore
from sklearn.model_selection import train_test_split                                    # type: ignore
import matplotlib as mpl                                                                # type: ignore
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
mpl.rcParams['figure.figsize'] = (9, 7)
from joblib import dump, load                                                           # type: ignore
import sys
sys.path.insert(1, "/home/mendrika/mendrika-phd/codes/nflics")
import nflics

# %% [markdown]
# ### Importing dataset

# %%
city = "Dakar"

# %%
lead_time = 1

# %%
data = pd.read_csv(f"train-data-{city}.csv", index_col=False)
test_data = pd.read_csv(f"test-data-{city}.csv", index_col=False)

# %% [markdown]
# ### Check if the data have outliers

# %%
variable = "lon"
for i in range(5):
    print(np.min(data[f"{variable}{i+1}"]), np.max(data[f"{variable}{i+1}"]))
# Out:
# -17.97 -8.04
# -17.97 -8.04
# -17.97 -2.4676860000000005
# -17.97 -2.4676860000000005
# -17.97 -2.4676860000000005

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def select(df):
    selection_index_lat = df["lat5"] < 30
    selection_index_lon = df["lon5"] < 30
    selection_index = selection_index_lat * selection_index_lon
    return selection_index

index_train = select(data)
index_test = select(test_data)

data = data[index_train]
test_data = test_data[index_test]

# %%
data = data.dropna()
test_data = test_data.dropna()

# %% [markdown]
# #### Choosing field to include in the data

# %%
# Presence or absence of storms in Dakar at time t+1
target_index = f"Cb_{city}_t{lead_time}"

# Input at time t
t0 = "year,month,day,hour,minute,"
location = ""
wavelet_power = ""
storm_size = ""
distance = ""
for i in range(1,6):
    location += f"lat{i},lon{i},"
    wavelet_power += f"wp{i},"
    distance += f"ds{i},"
    storm_size += f"size{i},"
features = t0 + location + wavelet_power + storm_size + distance
field =  features + target_index
field = field.split(',')
data = data[field]
test_data = test_data[field]

# %% [markdown]
# ### Exploratory data analysis

# %%
def log_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i > 0:
                transformed.append(np.log(i))
            else:
                transformed.append(np.log(i+1e-8))    
        df_copy[key] = transformed
    return df_copy

# %%
def sqrt_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i >= 0:
                transformed.append(np.sqrt(i)) 
        df_copy[key] = transformed
    return df_copy

# %%
to_scale = wavelet_power + storm_size + distance

# %%
transform = True
if transform:
    data = log_transform(data, to_scale.split(',')[:-1])    
    data = sqrt_transform(data, t0.split(',')[:-1])
    test_data = log_transform(test_data, to_scale.split(',')[:-1])    
    test_data = sqrt_transform(test_data, t0.split(',')[:-1])

# %% [markdown]
# ### Splitting the data  into training and testing before oversampling the training set

# %%
train, validation = train_test_split(data, test_size=0.2, random_state=12)

# %%
neg, pos = train[target_index].value_counts()
total = neg + pos
print(f"Negative: {neg} and Positive: {pos}. That is {pos/total:.2f} of the total.")
# Out:
# Negative: 76479 and Positive: 6622. That is 0.08 of the total.

# %%
x_train = train.drop([target_index], axis=1).to_numpy()
y_train = train[target_index]

x_val = validation.drop([target_index], axis=1).to_numpy()
y_val = validation[target_index]

x_test = test_data.drop([target_index], axis=1).to_numpy()
y_test = test_data[target_index]

# %%
type = ('Train', 'Validation', 'Test')

storm_counts = {
    'No Storm': np.array([y_train.value_counts()[0], y_val.value_counts()[0], y_test.value_counts()[0]]),
    'Storm': np.array([y_train.value_counts()[1], y_val.value_counts()[1] , y_test.value_counts()[1]]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(7,5))
bottom = np.zeros(3)

for mode, count in storm_counts.items():
    p = ax.bar(type, count, width, label=mode, bottom=bottom)
    bottom += count

    ax.bar_label(p, label_type='center')

ax.legend()

plt.show()

# %% [markdown]
# ### Normalising the features

# %%
# normalise data
scaler = StandardScaler()
std_x_train = scaler.fit_transform(x_train)
std_x_val = scaler.transform(x_val)
std_x_test = scaler.transform(x_test)

# %%
#dump(scaler, f'Normal-{city}-t{lead_time}.bin', compress=True)

# %% [markdown]
# ### Creating the model

# %%
initial_bias = np.log(pos/neg)
output_bias = tf.keras.initializers.Constant(value=initial_bias)

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(30,)),
  tf.keras.layers.Dense(16, activation='relu', kernel_initializer=he_normal()),
  tf.keras.layers.Dropout(0.2),    
  tf.keras.layers.Dense(8, activation='relu', kernel_initializer=he_normal()),
  tf.keras.layers.Dense(1, kernel_initializer=he_normal())
])

l1_reg = tf.keras.regularizers.L1(0.1)
for layer in model.layers[:]:
  layer.kernel_regularizer = l1_reg
 
cl_thresholds = 0.05

METRICS = [
      tf.keras.metrics.MeanSquaredError(name='bs'),
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.TrueNegatives(name='tn'),                        
      tf.keras.metrics.Recall(name='recall', thresholds = cl_thresholds),
      tf.keras.metrics.Precision(name='precision', thresholds = cl_thresholds),
      tf.keras.metrics.AUC(name='auc'),
      tf.keras.metrics.AUC(name='prc', curve='PR'), 
      tf.keras.metrics.F1Score(name = 'f1_score',  threshold = cl_thresholds),
]


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=METRICS)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 641 (2.50 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
EPOCHS = 500
BATCH_SIZE = 1024

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_prc", 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)


# train the model
model_history = model.fit(std_x_train, 
                          y_train, 
                          epochs=EPOCHS, 
                          callbacks = [early_stopping],
                          batch_size = BATCH_SIZE,         
                          validation_data=(std_x_val, y_val),
                        )
# Out:
# Epoch 1/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - auc: 0.6429 - bs: 3.5482 - f1_score: 0.2113 - loss: 0.7843 - prc: 0.1290 - precision: 0.1297 - recall: 0.6016 - tn: 31095.1328 - tp: 1443.4458 - val_auc: 0.6085 - val_bs: 7.9385 - val_f1_score: 0.2922 - val_loss: 0.2729 - val_prc: 0.1903 - val_precision: 0.3586 - val_recall: 0.2466 - val_tn: 18758.0000 - val_tp: 217.0000
# Epoch 2/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6137 - bs: 11.4012 - f1_score: 0.2934 - loss: 0.2800 - prc: 0.1802 - precision: 0.3284 - recall: 0.2659 - tn: 38657.0469 - tp: 498.0844 - val_auc: 0.6425 - val_bs: 16.7946 - val_f1_score: 0.3869 - val_loss: 0.1848 - val_prc: 0.2926 - val_precision: 0.6302 - val_recall: 0.2791 - val_tn: 18976.0000 - val_tp: 218.0000
# Epoch 3/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6508 - bs: 20.2423 - f1_score: 0.3867 - loss: 0.2049 - prc: 0.2687 - precision: 0.5291 - recall: 0.3048 - tn: 39175.7812 - tp: 468.8072 - val_auc: 0.6745 - val_bs: 23.6835 - val_f1_score: 0.4588 - val_loss: 0.1631 - val_prc: 0.3534 - val_precision: 0.6830 - val_recall: 0.3454 - val_tn: 18988.0000 - val_tp: 248.0000
# Epoch 4/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6799 - bs: 26.8856 - f1_score: 0.4550 - loss: 0.1822 - prc: 0.3345 - precision: 0.6160 - recall: 0.3607 - tn: 39237.4219 - tp: 523.1446 - val_auc: 0.6926 - val_bs: 28.6825 - val_f1_score: 0.4930 - val_loss: 0.1541 - val_prc: 0.3859 - val_precision: 0.7113 - val_recall: 0.3773 - val_tn: 19002.0000 - val_tp: 260.0000
# Epoch 5/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7040 - bs: 31.5943 - f1_score: 0.4994 - loss: 0.1674 - prc: 0.3844 - precision: 0.6557 - recall: 0.4034 - tn: 39342.2891 - tp: 572.2169 - val_auc: 0.7033 - val_bs: 31.8234 - val_f1_score: 0.5195 - val_loss: 0.1488 - val_prc: 0.4068 - val_precision: 0.7315 - val_recall: 0.4027 - val_tn: 19005.0000 - val_tp: 272.0000
# Epoch 6/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7154 - bs: 33.7226 - f1_score: 0.5212 - loss: 0.1627 - prc: 0.4093 - precision: 0.6690 - recall: 0.4269 - tn: 39324.5430 - tp: 609.5422 - val_auc: 0.7291 - val_bs: 33.4059 - val_f1_score: 0.5547 - val_loss: 0.1450 - val_prc: 0.4428 - val_precision: 0.7274 - val_recall: 0.4483 - val_tn: 18986.0000 - val_tp: 328.0000
# Epoch 7/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7247 - bs: 35.1246 - f1_score: 0.5380 - loss: 0.1583 - prc: 0.4242 - precision: 0.6751 - recall: 0.4473 - tn: 39339.7578 - tp: 714.9036 - val_auc: 0.7345 - val_bs: 34.4520 - val_f1_score: 0.5663 - val_loss: 0.1416 - val_prc: 0.4538 - val_precision: 0.7349 - val_recall: 0.4607 - val_tn: 18974.0000 - val_tp: 373.0000
# Epoch 8/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7391 - bs: 36.4860 - f1_score: 0.5631 - loss: 0.1543 - prc: 0.4450 - precision: 0.6892 - recall: 0.4761 - tn: 39259.7109 - tp: 859.2892 - val_auc: 0.7446 - val_bs: 34.9890 - val_f1_score: 0.5821 - val_loss: 0.1392 - val_prc: 0.4712 - val_precision: 0.7418 - val_recall: 0.4790 - val_tn: 18976.0000 - val_tp: 405.0000
# Epoch 9/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7401 - bs: 36.4535 - f1_score: 0.5670 - loss: 0.1500 - prc: 0.4618 - precision: 0.6919 - recall: 0.4803 - tn: 39277.4570 - tp: 915.9398 - val_auc: 0.7548 - val_bs: 35.4595 - val_f1_score: 0.5964 - val_loss: 0.1369 - val_prc: 0.4884 - val_precision: 0.7421 - val_recall: 0.4985 - val_tn: 18965.0000 - val_tp: 442.0000
# Epoch 10/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7551 - bs: 36.8275 - f1_score: 0.5925 - loss: 0.1437 - prc: 0.4817 - precision: 0.7013 - recall: 0.5129 - tn: 39295.0977 - tp: 1013.0602 - val_auc: 0.7728 - val_bs: 35.0107 - val_f1_score: 0.6246 - val_loss: 0.1349 - val_prc: 0.5106 - val_precision: 0.7331 - val_recall: 0.5441 - val_tn: 18927.0000 - val_tp: 556.0000
# Epoch 11/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7661 - bs: 36.9590 - f1_score: 0.6026 - loss: 0.1422 - prc: 0.4950 - precision: 0.6902 - recall: 0.5350 - tn: 39160.4688 - tp: 1184.8916 - val_auc: 0.7505 - val_bs: 35.9321 - val_f1_score: 0.6011 - val_loss: 0.1341 - val_prc: 0.4905 - val_precision: 0.7516 - val_recall: 0.5009 - val_tn: 18966.0000 - val_tp: 503.0000
# Epoch 12/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7624 - bs: 37.2055 - f1_score: 0.5974 - loss: 0.1404 - prc: 0.4937 - precision: 0.6973 - recall: 0.5226 - tn: 39203.0234 - tp: 1164.3615 - val_auc: 0.7711 - val_bs: 35.6722 - val_f1_score: 0.6253 - val_loss: 0.1324 - val_prc: 0.5188 - val_precision: 0.7429 - val_recall: 0.5399 - val_tn: 18936.0000 - val_tp: 568.0000
# Epoch 13/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7630 - bs: 36.9212 - f1_score: 0.6071 - loss: 0.1407 - prc: 0.5062 - precision: 0.7065 - recall: 0.5322 - tn: 39202.0977 - tp: 1223.5421 - val_auc: 0.7721 - val_bs: 35.5648 - val_f1_score: 0.6278 - val_loss: 0.1312 - val_prc: 0.5217 - val_precision: 0.7475 - val_recall: 0.5411 - val_tn: 18933.0000 - val_tp: 580.0000
# Epoch 14/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7760 - bs: 37.0311 - f1_score: 0.6238 - loss: 0.1385 - prc: 0.5212 - precision: 0.7157 - recall: 0.5529 - tn: 39187.4219 - tp: 1295.2289 - val_auc: 0.7714 - val_bs: 35.6513 - val_f1_score: 0.6284 - val_loss: 0.1304 - val_prc: 0.5223 - val_precision: 0.7504 - val_recall: 0.5405 - val_tn: 18933.0000 - val_tp: 600.0000
# Epoch 15/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7746 - bs: 37.3770 - f1_score: 0.6183 - loss: 0.1372 - prc: 0.5173 - precision: 0.7081 - recall: 0.5487 - tn: 39161.6016 - tp: 1303.5542 - val_auc: 0.7743 - val_bs: 36.1516 - val_f1_score: 0.6289 - val_loss: 0.1294 - val_prc: 0.5290 - val_precision: 0.7496 - val_recall: 0.5417 - val_tn: 18918.0000 - val_tp: 626.0000
# Epoch 16/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7728 - bs: 37.3056 - f1_score: 0.6189 - loss: 0.1371 - prc: 0.5106 - precision: 0.7158 - recall: 0.5452 - tn: 39162.2031 - tp: 1332.6989 - val_auc: 0.7914 - val_bs: 35.2986 - val_f1_score: 0.6574 - val_loss: 0.1282 - val_prc: 0.5516 - val_precision: 0.7448 - val_recall: 0.5884 - val_tn: 18894.0000 - val_tp: 691.0000
# Epoch 17/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7843 - bs: 37.2204 - f1_score: 0.6339 - loss: 0.1343 - prc: 0.5332 - precision: 0.7100 - recall: 0.5726 - tn: 39116.0742 - tp: 1429.4458 - val_auc: 0.7703 - val_bs: 36.3902 - val_f1_score: 0.6329 - val_loss: 0.1281 - val_prc: 0.5276 - val_precision: 0.7587 - val_recall: 0.5429 - val_tn: 18923.0000 - val_tp: 634.0000
# Epoch 18/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7755 - bs: 36.7311 - f1_score: 0.6260 - loss: 0.1325 - prc: 0.5167 - precision: 0.7191 - recall: 0.5544 - tn: 39159.9141 - tp: 1404.4698 - val_auc: 0.7891 - val_bs: 34.9111 - val_f1_score: 0.6498 - val_loss: 0.1269 - val_prc: 0.5517 - val_precision: 0.7443 - val_recall: 0.5766 - val_tn: 18896.0000 - val_tp: 695.0000
# Epoch 19/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7822 - bs: 36.4851 - f1_score: 0.6375 - loss: 0.1311 - prc: 0.5329 - precision: 0.7218 - recall: 0.5709 - tn: 39104.1445 - tp: 1454.0240 - val_auc: 0.7773 - val_bs: 36.2770 - val_f1_score: 0.6421 - val_loss: 0.1266 - val_prc: 0.5393 - val_precision: 0.7589 - val_recall: 0.5565 - val_tn: 18914.0000 - val_tp: 665.0000
# Epoch 20/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7815 - bs: 36.7471 - f1_score: 0.6371 - loss: 0.1334 - prc: 0.5401 - precision: 0.7335 - recall: 0.5633 - tn: 39159.7227 - tp: 1428.8916 - val_auc: 0.7808 - val_bs: 36.1179 - val_f1_score: 0.6460 - val_loss: 0.1263 - val_prc: 0.5419 - val_precision: 0.7600 - val_recall: 0.5618 - val_tn: 18904.0000 - val_tp: 688.0000
# Epoch 21/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7915 - bs: 37.0136 - f1_score: 0.6498 - loss: 0.1292 - prc: 0.5496 - precision: 0.7276 - recall: 0.5871 - tn: 39103.7109 - tp: 1519.3494 - val_auc: 0.7864 - val_bs: 35.6713 - val_f1_score: 0.6499 - val_loss: 0.1256 - val_prc: 0.5478 - val_precision: 0.7506 - val_recall: 0.5730 - val_tn: 18889.0000 - val_tp: 714.0000
# Epoch 22/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7867 - bs: 37.1777 - f1_score: 0.6413 - loss: 0.1301 - prc: 0.5464 - precision: 0.7178 - recall: 0.5795 - tn: 39130.6758 - tp: 1504.0602 - val_auc: 0.7875 - val_bs: 35.8950 - val_f1_score: 0.6521 - val_loss: 0.1252 - val_prc: 0.5512 - val_precision: 0.7535 - val_recall: 0.5748 - val_tn: 18883.0000 - val_tp: 729.0000
# Epoch 23/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7955 - bs: 37.5484 - f1_score: 0.6580 - loss: 0.1264 - prc: 0.5523 - precision: 0.7380 - recall: 0.5938 - tn: 39142.4688 - tp: 1520.2892 - val_auc: 0.7813 - val_bs: 34.9350 - val_f1_score: 0.6448 - val_loss: 0.1250 - val_prc: 0.5461 - val_precision: 0.7534 - val_recall: 0.5636 - val_tn: 18904.0000 - val_tp: 703.0000
# Epoch 24/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.7923 - bs: 36.3468 - f1_score: 0.6484 - loss: 0.1284 - prc: 0.5515 - precision: 0.7228 - recall: 0.5879 - tn: 39109.2188 - tp: 1554.6145 - val_auc: 0.7828 - val_bs: 35.8646 - val_f1_score: 0.6496 - val_loss: 0.1245 - val_prc: 0.5494 - val_precision: 0.7559 - val_recall: 0.5695 - val_tn: 18896.0000 - val_tp: 721.0000
# Epoch 25/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7915 - bs: 37.2315 - f1_score: 0.6489 - loss: 0.1270 - prc: 0.5511 - precision: 0.7242 - recall: 0.5878 - tn: 39136.4336 - tp: 1565.0240 - val_auc: 0.7886 - val_bs: 35.4795 - val_f1_score: 0.6529 - val_loss: 0.1241 - val_prc: 0.5547 - val_precision: 0.7466 - val_recall: 0.5801 - val_tn: 18882.0000 - val_tp: 763.0000
# Epoch 26/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7946 - bs: 37.0344 - f1_score: 0.6537 - loss: 0.1262 - prc: 0.5486 - precision: 0.7252 - recall: 0.5951 - tn: 39138.6367 - tp: 1544.6506 - val_auc: 0.7716 - val_bs: 36.5060 - val_f1_score: 0.6352 - val_loss: 0.1247 - val_prc: 0.5379 - val_precision: 0.7618 - val_recall: 0.5446 - val_tn: 18920.0000 - val_tp: 680.0000
# Epoch 27/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7858 - bs: 37.7906 - f1_score: 0.6479 - loss: 0.1271 - prc: 0.5498 - precision: 0.7379 - recall: 0.5776 - tn: 39120.3125 - tp: 1539.4458 - val_auc: 0.7747 - val_bs: 36.5791 - val_f1_score: 0.6397 - val_loss: 0.1242 - val_prc: 0.5430 - val_precision: 0.7610 - val_recall: 0.5517 - val_tn: 18914.0000 - val_tp: 700.0000
# Epoch 28/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7903 - bs: 37.9152 - f1_score: 0.6533 - loss: 0.1259 - prc: 0.5574 - precision: 0.7396 - recall: 0.5850 - tn: 39121.5430 - tp: 1571.6747 - val_auc: 0.7773 - val_bs: 36.4586 - val_f1_score: 0.6407 - val_loss: 0.1240 - val_prc: 0.5465 - val_precision: 0.7573 - val_recall: 0.5553 - val_tn: 18916.0000 - val_tp: 709.0000
# Epoch 29/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7938 - bs: 36.9272 - f1_score: 0.6570 - loss: 0.1292 - prc: 0.5579 - precision: 0.7350 - recall: 0.5942 - tn: 39091.5781 - tp: 1583.0482 - val_auc: 0.7790 - val_bs: 36.6976 - val_f1_score: 0.6429 - val_loss: 0.1236 - val_prc: 0.5481 - val_precision: 0.7536 - val_recall: 0.5606 - val_tn: 18911.0000 - val_tp: 729.0000
# Epoch 30/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7989 - bs: 38.2150 - f1_score: 0.6578 - loss: 0.1252 - prc: 0.5650 - precision: 0.7296 - recall: 0.5990 - tn: 39088.2188 - tp: 1622.0000 - val_auc: 0.7756 - val_bs: 36.4470 - val_f1_score: 0.6389 - val_loss: 0.1236 - val_prc: 0.5444 - val_precision: 0.7575 - val_recall: 0.5523 - val_tn: 18927.0000 - val_tp: 700.0000
# Epoch 31/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.7926 - bs: 37.4715 - f1_score: 0.6536 - loss: 0.1271 - prc: 0.5608 - precision: 0.7358 - recall: 0.5880 - tn: 39104.5547 - tp: 1586.3735 - val_auc: 0.7798 - val_bs: 36.2493 - val_f1_score: 0.6435 - val_loss: 0.1232 - val_prc: 0.5504 - val_precision: 0.7508 - val_recall: 0.5630 - val_tn: 18911.0000 - val_tp: 739.0000
# Epoch 32/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7972 - bs: 37.8890 - f1_score: 0.6628 - loss: 0.1251 - prc: 0.5593 - precision: 0.7372 - recall: 0.6022 - tn: 39119.7461 - tp: 1606.8073 - val_auc: 0.7883 - val_bs: 35.6888 - val_f1_score: 0.6513 - val_loss: 0.1225 - val_prc: 0.5626 - val_precision: 0.7464 - val_recall: 0.5778 - val_tn: 18898.0000 - val_tp: 778.0000
# Epoch 33/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7982 - bs: 37.4398 - f1_score: 0.6584 - loss: 0.1259 - prc: 0.5665 - precision: 0.7280 - recall: 0.6013 - tn: 39095.5078 - tp: 1644.7229 - val_auc: 0.7871 - val_bs: 35.9120 - val_f1_score: 0.6497 - val_loss: 0.1225 - val_prc: 0.5623 - val_precision: 0.7490 - val_recall: 0.5736 - val_tn: 18904.0000 - val_tp: 763.0000
# Epoch 34/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8015 - bs: 37.0138 - f1_score: 0.6626 - loss: 0.1245 - prc: 0.5705 - precision: 0.7288 - recall: 0.6076 - tn: 39091.0234 - tp: 1636.4698 - val_auc: 0.7772 - val_bs: 36.2947 - val_f1_score: 0.6417 - val_loss: 0.1228 - val_prc: 0.5503 - val_precision: 0.7576 - val_recall: 0.5565 - val_tn: 18924.0000 - val_tp: 720.0000
# Epoch 35/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7878 - bs: 37.2873 - f1_score: 0.6459 - loss: 0.1277 - prc: 0.5519 - precision: 0.7340 - recall: 0.5769 - tn: 39100.0234 - tp: 1601.3494 - val_auc: 0.7800 - val_bs: 36.2234 - val_f1_score: 0.6464 - val_loss: 0.1224 - val_prc: 0.5536 - val_precision: 0.7555 - val_recall: 0.5648 - val_tn: 18916.0000 - val_tp: 741.0000
# Epoch 36/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7988 - bs: 37.8110 - f1_score: 0.6653 - loss: 0.1242 - prc: 0.5722 - precision: 0.7422 - recall: 0.6029 - tn: 39119.7461 - tp: 1603.0723 - val_auc: 0.7814 - val_bs: 36.0047 - val_f1_score: 0.6464 - val_loss: 0.1221 - val_prc: 0.5553 - val_precision: 0.7535 - val_recall: 0.5659 - val_tn: 18916.0000 - val_tp: 750.0000
# Epoch 37/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7958 - bs: 36.8285 - f1_score: 0.6579 - loss: 0.1254 - prc: 0.5665 - precision: 0.7381 - recall: 0.5936 - tn: 39126.0000 - tp: 1624.8313 - val_auc: 0.7804 - val_bs: 35.4317 - val_f1_score: 0.6482 - val_loss: 0.1221 - val_prc: 0.5576 - val_precision: 0.7573 - val_recall: 0.5665 - val_tn: 18938.0000 - val_tp: 730.0000
# Epoch 38/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7952 - bs: 36.6677 - f1_score: 0.6597 - loss: 0.1275 - prc: 0.5658 - precision: 0.7385 - recall: 0.5962 - tn: 39081.7227 - tp: 1620.9518 - val_auc: 0.7818 - val_bs: 36.7253 - val_f1_score: 0.6498 - val_loss: 0.1219 - val_prc: 0.5580 - val_precision: 0.7575 - val_recall: 0.5689 - val_tn: 18924.0000 - val_tp: 745.0000
# Epoch 39/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7915 - bs: 38.2774 - f1_score: 0.6564 - loss: 0.1248 - prc: 0.5630 - precision: 0.7441 - recall: 0.5876 - tn: 39119.6641 - tp: 1620.8193 - val_auc: 0.7709 - val_bs: 36.1880 - val_f1_score: 0.6367 - val_loss: 0.1222 - val_prc: 0.5449 - val_precision: 0.7673 - val_recall: 0.5441 - val_tn: 18942.0000 - val_tp: 713.0000
# Epoch 40/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7972 - bs: 36.4696 - f1_score: 0.6653 - loss: 0.1234 - prc: 0.5659 - precision: 0.7501 - recall: 0.5979 - tn: 39116.6641 - tp: 1627.1445 - val_auc: 0.7811 - val_bs: 35.5972 - val_f1_score: 0.6481 - val_loss: 0.1214 - val_prc: 0.5582 - val_precision: 0.7593 - val_recall: 0.5653 - val_tn: 18930.0000 - val_tp: 751.0000
# Epoch 41/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7996 - bs: 37.4545 - f1_score: 0.6655 - loss: 0.1219 - prc: 0.5772 - precision: 0.7402 - recall: 0.6046 - tn: 39115.8555 - tp: 1640.9760 - val_auc: 0.7719 - val_bs: 36.0001 - val_f1_score: 0.6405 - val_loss: 0.1221 - val_prc: 0.5484 - val_precision: 0.7750 - val_recall: 0.5458 - val_tn: 18954.0000 - val_tp: 697.0000
# Epoch 42/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7898 - bs: 37.6515 - f1_score: 0.6528 - loss: 0.1231 - prc: 0.5612 - precision: 0.7396 - recall: 0.5843 - tn: 39177.1680 - tp: 1580.0240 - val_auc: 0.7796 - val_bs: 35.6816 - val_f1_score: 0.6471 - val_loss: 0.1214 - val_prc: 0.5603 - val_precision: 0.7651 - val_recall: 0.5606 - val_tn: 18936.0000 - val_tp: 736.0000
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %%
def plot_cm(y, y_hat, classification_threshold):
    # compute the contingency table    
    y_hat_class = y_hat >= classification_threshold
    cm = metrics.confusion_matrix(y, y_hat_class)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, linewidths=.5, square = True, cmap = 'Blues_r', cbar=None, fmt='g')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def plot_metrics(history):
  metrics = ['loss', 'bs', 'recall', 'precision']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color="red", label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.5,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %% [markdown]
# ### Performance on training data

# %%
plot_metrics(model_history)

# %% [markdown]
# ### Performance on testing data

# %%
def cutoff_youdens_j(fpr, tpr, thresholds):
    j_scores = tpr-fpr
    j_ordered = sorted(zip(j_scores, thresholds))
    return j_ordered[-1][1]

# %%
model.trainable = False

# Define the temperature-scaled model class
class TemperatureScaledModel(tf.keras.Model):
    def __init__(self, base_model, temperature=1.0):
        super(TemperatureScaledModel, self).__init__()
        self.base_model = base_model
        self.temperature = tf.Variable(temperature, dtype=tf.float32, trainable=True)

    def call(self, inputs):
        logits = self.base_model(inputs, training=False)
        scaled_logits = logits / self.temperature
        return scaled_logits
    
# Instantiate the temperature-scaled model
temp_model = TemperatureScaledModel(model)

# Define the loss function (binary cross-entropy with logits)
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Optimize temperature
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

def optimize_temperature(temp_model, X_val, y_val, epochs=100):
    for epoch in range(epochs):
        with tf.GradientTape() as tape:
            logits = temp_model(X_val, training=False)
            loss = loss_fn(y_val, logits)
        grads = tape.gradient(loss, [temp_model.temperature])
        optimizer.apply_gradients(zip(grads, [temp_model.temperature]))
        if epoch % 10 == 0:
            print(f"Epoch {epoch}: Temperature = {temp_model.temperature.numpy()}, Loss = {loss.numpy()}")

optimize_temperature(temp_model, std_x_val, y_val)
# Out:
# Epoch 0: Temperature = 0.990011990070343, Loss = 0.12254049628973007
# Epoch 10: Temperature = 0.9886707663536072, Loss = 0.1225183829665184
# Epoch 20: Temperature = 0.9781186580657959, Loss = 0.12251774966716766
# Epoch 30: Temperature = 0.9815348982810974, Loss = 0.12251625210046768
# Epoch 40: Temperature = 0.9833858013153076, Loss = 0.12251633405685425
# Epoch 50: Temperature = 0.9816123247146606, Loss = 0.1225162222981453
# Epoch 60: Temperature = 0.9811895489692688, Loss = 0.1225162222981453
# Epoch 70: Temperature = 0.9816232919692993, Loss = 0.1225161924958229
# Epoch 80: Temperature = 0.9818844199180603, Loss = 0.1225161924958229
# Epoch 90: Temperature = 0.9819063544273376, Loss = 0.1225161924958229

# %%
# Step 1: Save the base model to a path in the Jupyter Notebook's directory
model.save(f'/home/mendrika/mendrika-phd/codes/nflics/model-ML-Dakar/Normal-{city}-t{lead_time}-temp-calibrated.keras')

# Step 2: Save the temperature parameter separately
np.save(f"/home/mendrika/mendrika-phd/codes/nflics/model-ML-Dakar/Normal-{city}-t{lead_time}-temperature.npy", temp_model.temperature.numpy())

# %%
# Make predictions with temperature-scaled probabilities
logits = temp_model(std_x_test)
calibrated_probs = tf.sigmoid(logits)  # Convert scaled logits to probabilities

# Display temperature-scaled probabilities for verification
print("Calibrated probabilities:", calibrated_probs[:5].numpy())
# Out:
# Calibrated probabilities: [[4.2450707e-04]
#  [7.4509466e-05]
#  [6.7840541e-05]
#  [1.2018254e-04]
#  [1.0076915e-04]]

# %%
def class_prediction(x, y):
    logits = temp_model(x)
    y_hat = tf.sigmoid(logits)
    bs = brier_score_loss(y, y_hat)    
    auc = roc_auc_score(y, y_hat)
    return y_hat, auc, bs

# %%
y_hat_val, auc_val, bs_val = class_prediction(std_x_val, y_val)
classification_threshold_val = cutoff_youdens_j(*roc_curve(y_val, y_hat_val))
print(classification_threshold_val)
plot_cm(y_val, y_hat_val, classification_threshold=classification_threshold_val)
# Out:
# 0.11035364

# %%
average_precision_score(y_val, y_hat_val)
# Out:
# 0.7364213626951458

# %%
y_hat_test, auc_test, bs_test = class_prediction(std_x_test, y_test)
classification_threshold = cutoff_youdens_j(*roc_curve(y_test, y_hat_test))
plot_cm(y_test, y_hat_test, classification_threshold=classification_threshold_val)

# %%
average_precision_score(y_test, y_hat_test)
# Out:
# 0.7574189828379259

# %%
def reliability_curve(y, y_pred, bin_size=0.1, count_pred_per_bin=100):
  y = np.array(y)
  y_pred = np.array(y_pred)
  bins = np.arange(0, 1+bin_size, bin_size)
  bin_centers = [(b1 + b2) / 2 for b1, b2 in zip(bins[:-1], bins[1:])]
  prop_positive = []
  bin_center_ax = []
  no_pred_per_bin = []
  for b1, b2, bc in zip(bins[:-1], bins[1:], bin_centers):
    in_bin = np.logical_and(y_pred >= b1, y_pred < b2)
    no_predictions_per_bin = np.sum(in_bin)
    no_positive_per_bin = np.sum(y[in_bin])    
    if no_predictions_per_bin > count_pred_per_bin:
      prop_pos = round(no_positive_per_bin/no_predictions_per_bin, 3)
      prop_positive.append(prop_pos)
      bin_center_ax.append(round(bc, 3))
      no_pred_per_bin.append(no_predictions_per_bin)
    else:
      continue
  return bin_center_ax, prop_positive, no_pred_per_bin

# %%
prob_pred, prob_true, no_pred_per_bin = reliability_curve(y_test, y_hat_test.numpy().flatten())
plt.figure(figsize=(5,4))
plt.plot(prob_pred, prob_true, label=f"NN0{lead_time} {city}")    
    
plt.xlabel("Predicted probability")
plt.ylabel("Obs. proportion of positive case")

no_pred_per_bin = [i/(1.1*np.max(no_pred_per_bin)) for i in no_pred_per_bin]
plt.plot(np.arange(0,1.2,0.2), np.arange(0,1.2,0.2))
plt.bar(prob_pred, no_pred_per_bin, width=0.1, linestyle="--", fill=False, edgecolor="green")

plt.xlim(0,1)
plt.ylim(0,1)
plt.legend(loc='upper center')
plt.show()

# %%
#temp_model.save(f'/home/mendrika/mendrika-phd/codes/nflics/model-ML-Dakar/Normal-{city}-t{lead_time}-temp-calibrated.keras')

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = metrics.roc_curve(labels, predictions)
  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False alarm [%]')
  plt.ylabel('Hit [%]')
  plt.xlim([0,100])
  plt.ylim([0,100])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
y_hat_train, auc_train, bs_train = class_prediction(std_x_train, y_train)
plot_roc(f"Training set (AUC={auc_train:.3f})", y_train, y_hat_train, color="red")
plot_roc(f"Testing set  (AUC={auc_test:.3f})", y_test, y_hat_test, color=colors[0], linestyle='--')
plt.title(f"NN0{lead_time} {city}")
plt.legend(loc='lower right');
