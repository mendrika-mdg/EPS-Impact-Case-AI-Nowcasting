# %% [markdown]
# ### To check if the model initially designed for a chosen city can be used for other locations

# %%
import pandas as pd                                                                     # type: ignore
import matplotlib.pyplot as plt                                                         # type: ignore
import seaborn as sns                                                                   # type: ignore
import numpy as np                                                                      # type: ignore
from  sklearn import metrics                                                            # type: ignore
from sklearn.preprocessing import StandardScaler                                        # type: ignore
from sklearn.metrics import roc_auc_score, roc_curve, brier_score_loss                  # type: ignore
from sklearn.metrics import average_precision_score                  # type: ignore
import tensorflow as tf                                                                 # type: ignore
from tensorflow.keras.initializers import he_normal # type: ignore
from sklearn.model_selection import train_test_split                                    # type: ignore
import matplotlib as mpl                                                                # type: ignore
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
mpl.rcParams['figure.figsize'] = (9, 7)
from joblib import dump, load                                                           # type: ignore
import sys
sys.path.insert(1, "/home/mendrika/mendrika-phd/codes/nflics")
import nflics
# Out:
# 2024-11-26 16:43:16.572044: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-26 16:43:16.576011: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-26 16:43:16.637212: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 16:43:17.958901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Importing dataset

# %%
city = "Selibaby"

# %%
city_lat, city_lon = 15.1506, -12.1804

# %%
lead_time = 1

# %%
data = pd.read_csv(f"train-data-{city}.csv", index_col=False)
test_data = pd.read_csv(f"test-data-{city}.csv", index_col=False)

# %% [markdown]
# ### Check if the data have outliers

# %%
variable = "lon"
for i in range(5):
    print(np.min(data[f"{variable}{i+1}"]), np.max(data[f"{variable}{i+1}"]))
# Out:
# -12.98 -3.01
# -12.98 -3.01
# -12.98 2.8195999999999994
# -12.98 2.8195999999999994
# -12.98 2.8195999999999994

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def select(df):
    selection_index_lat = df["lat5"] < 30
    selection_index_lon = df["lon5"] < 30
    selection_index = selection_index_lat * selection_index_lon
    return selection_index

index_train = select(data)
index_test = select(test_data)

data = data[index_train]
test_data = test_data[index_test]

# %%
data = data.dropna()
test_data = test_data.dropna()

# %% [markdown]
# #### Choosing field to include in the data

# %%
# Presence or absence of storms in Dakar at time t+1
target_index = f"Cb_{city}_t{lead_time}"

# Input at time t
t0 = "year,month,day,hour,minute,"
location = ""
wavelet_power = ""
storm_size = ""
distance = ""
for i in range(1,6):
    location += f"lat{i},lon{i},"
    wavelet_power += f"wp{i},"
    distance += f"ds{i},"
    storm_size += f"size{i},"
features = t0 + location + wavelet_power + storm_size + distance
field =  features + target_index
field = field.split(',')
data = data[field]
test_data = test_data[field]

# %% [markdown]
# ### Transforming latitude and longitude to relative latitude and relative longitude

# %% [markdown]
# ### Transforming to relative latitude and longitudes

# %%
for i in range(5):
    data[f"lat{i+1}"] = data[f"lat{i+1}"] - city_lat
    data[f"lon{i+1}"] = data[f"lon{i+1}"] - city_lon
    test_data[f"lat{i+1}"] = test_data[f"lat{i+1}"] - city_lat
    test_data[f"lon{i+1}"] = test_data[f"lon{i+1}"] - city_lon

# %%
data.head(10)
# Out:
#    year  month  day  hour  minute    lat1    lon1    lat2    lon2    lat3  \
# 0  2004      6    1    16      30 -2.4806  7.2404 -2.2106  7.9104  0.0000
# 1  2004      6    1    16      45 -3.7806  6.7404 -2.2606  8.1804 -2.4806
# 2  2004      6    1    17       0 -3.7406  6.7404 -2.2106  8.2204 -3.0706
# 3  2004      6    1    17      15 -3.6906  6.7904 -2.1706  8.2204 -3.1106
# 4  2004      6    1    17      30 -3.1506  8.0904 -3.6506  6.8304 -2.1706
# 5  2004      6    1    17      45 -3.0706  3.9604 -3.6506  6.8304 -2.3506
# 6  2004      6    1    18       0 -3.0206  4.0004 -3.2906  7.5504 -2.3506
# 7  2004      6    1    18      15 -2.9806  4.0004 -3.7406  6.3804 -2.3906
# 8  2004      6    1    18      30 -3.1506  3.2404 -3.0206  3.9104 -3.7406
# 9  2004      6    1    18      45 -3.1106  3.3304 -3.3306  8.4904 -3.6906
#
#    ...  size2  size3    size4    size5     ds1     ds2     ds3     ds4  \
# 0  ...   1950      0      0.0      0.0  265.00  285.04  520.00  520.00
# 1  ...   4200   4325      0.0      0.0  263.11  266.43  295.22  520.00
# 2  ...   9400   9350   4675.0   2100.0  228.32  261.52  265.94  295.67
# 3  ...   6575   9750   4600.0   7350.0  228.18  266.72  267.22  295.42
# 4  ...   7175   3525  11100.0      0.0  255.83  266.65  297.11  301.40
# 5  ...  35875   9075   8300.0   2425.0  170.07  222.80  253.93  266.65
# 6  ...  29150   2400   9475.0   7175.0  170.41  220.29  249.19  266.65
# 7  ...  47675    925   8975.0  25525.0  169.81  218.01  238.54  254.68
# 8  ...   6325  13800   7800.0  31850.0  153.46  168.05  212.36  252.96
# 9  ...  13500   6650  34250.0   2875.0  154.87  207.29  253.66  270.70
#
#       ds5  Cb_Selibaby_t1
# 0  520.00             0.0
# 1  520.00             0.0
# 2  310.30             0.0
# 3  306.30             0.0
# 4  520.00             0.0
# 5  298.80             0.0
# 6  284.81             0.0
# 7  281.66             0.0
# 8  274.52             0.0
# 9  316.62             0.0
#
# [10 rows x 31 columns]

# %%
data["lon5"]
# Out:
# 0        15.0000
# 1        15.0000
# 2         4.4504
# 3         4.3204
# 4        15.0000
#           ...
# 98536    15.0000
# 98537    15.0000
# 98538    15.0000
# 98539    15.0000
# 98540    15.0000
# Name: lon5, Length: 98541, dtype: float64

# %% [markdown]
# ### Exploratory data analysis

# %%
def log_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i > 0:
                transformed.append(np.log(i))
            else:
                transformed.append(np.log(i+1e-8))    
        df_copy[key] = transformed
    return df_copy

# %%
def sqrt_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i >= 0:
                transformed.append(np.sqrt(i)) 
        df_copy[key] = transformed
    return df_copy

# %%
to_scale = wavelet_power + storm_size + distance

# %%
transform = True
if transform:
    data = log_transform(data, to_scale.split(',')[:-1])    
    data = sqrt_transform(data, t0.split(',')[:-1])
    test_data = log_transform(test_data, to_scale.split(',')[:-1])    
    test_data = sqrt_transform(test_data, t0.split(',')[:-1])

# %% [markdown]
# ### Splitting the data  into training and testing before oversampling the training set

# %%
train, validation = train_test_split(data, test_size=0.2, random_state=12)

# %%
neg, pos = train[target_index].value_counts()
total = neg + pos
print(f"Negative: {neg} and Positive: {pos}. That is {pos/total:.2f} of the total.")
# Out:
# Negative: 71025 and Positive: 7807. That is 0.10 of the total.

# %%
x_train = train.drop([target_index], axis=1).to_numpy()
y_train = train[target_index]

x_val = validation.drop([target_index], axis=1).to_numpy()
y_val = validation[target_index]

x_test = test_data.drop([target_index], axis=1).to_numpy()
y_test = test_data[target_index]

# %%
type = ('Train', 'Validation', 'Test')

storm_counts = {
    'No Storm': np.array([y_train.value_counts()[0], y_val.value_counts()[0], y_test.value_counts()[0]]),
    'Storm': np.array([y_train.value_counts()[1], y_val.value_counts()[1] , y_test.value_counts()[1]]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(7,5))
bottom = np.zeros(3)

for mode, count in storm_counts.items():
    p = ax.bar(type, count, width, label=mode, bottom=bottom)
    bottom += count

    ax.bar_label(p, label_type='center')

ax.legend()

plt.show()

# %% [markdown]
# ### Normalising the features

# %%
# normalise data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# %%
dump(scaler, f'Global-from-{city}-t{lead_time}.bin', compress=True)
# Out:
# ['Global-from-Selibaby-t1.bin']

# %% [markdown]
# ### Creating the model

# %%
initial_bias = np.log(pos/neg)
output_bias = tf.keras.initializers.Constant(value=initial_bias)

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(30,)),
  tf.keras.layers.Dense(16, activation='relu', kernel_initializer=he_normal()),
  tf.keras.layers.Dropout(0.2),    
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid', bias_initializer=output_bias)
])

l1_reg = tf.keras.regularizers.L1(0.1)
for layer in model.layers[:]:
  layer.kernel_regularizer = l1_reg
 
cl_thresholds = 0.4

METRICS = [
      tf.keras.metrics.MeanSquaredError(name='bs'),
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.TrueNegatives(name='tn'),                        
      tf.keras.metrics.Recall(name='recall', thresholds = cl_thresholds),
      tf.keras.metrics.Precision(name='precision', thresholds = cl_thresholds),
      tf.keras.metrics.AUC(name='auc'),
      tf.keras.metrics.AUC(name='prc', curve='PR'), 
      tf.keras.metrics.F1Score(name = 'f1_score',  threshold = cl_thresholds),
]


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=METRICS)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 641 (2.50 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
EPOCHS = 500
BATCH_SIZE = 1024

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_prc", 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)


# train the model
model_history = model.fit(x_train, 
                          y_train, 
                          epochs=EPOCHS, 
                          callbacks = [early_stopping],
                          batch_size = BATCH_SIZE,         
                          validation_data=(x_val, y_val),
                        )
# Out:
# Epoch 1/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - auc: 0.6360 - bs: 0.0854 - f1_score: 0.0739 - loss: 0.3172 - prc: 0.2220 - precision: 0.4399 - recall: 0.0432 - tn: 36338.8477 - tp: 156.3462 - val_auc: 0.9159 - val_bs: 0.0580 - val_f1_score: 0.5447 - val_loss: 0.1997 - val_prc: 0.5909 - val_precision: 0.6806 - val_recall: 0.4540 - val_tn: 17581.0000 - val_tp: 594.0000
# Epoch 2/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8890 - bs: 0.0616 - f1_score: 0.5096 - loss: 0.2132 - prc: 0.5371 - precision: 0.6123 - recall: 0.4365 - tn: 35800.3320 - tp: 1370.1923 - val_auc: 0.9363 - val_bs: 0.0510 - val_f1_score: 0.6068 - val_loss: 0.1739 - val_prc: 0.6679 - val_precision: 0.6954 - val_recall: 0.5383 - val_tn: 17499.0000 - val_tp: 821.0000
# Epoch 3/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9147 - bs: 0.0567 - f1_score: 0.5667 - loss: 0.1939 - prc: 0.6027 - precision: 0.6400 - recall: 0.5086 - tn: 35686.6406 - tp: 1653.2821 - val_auc: 0.9443 - val_bs: 0.0479 - val_f1_score: 0.6392 - val_loss: 0.1626 - val_prc: 0.6934 - val_precision: 0.6856 - val_recall: 0.5988 - val_tn: 17444.0000 - val_tp: 951.0000
# Epoch 4/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9305 - bs: 0.0526 - f1_score: 0.6070 - loss: 0.1783 - prc: 0.6410 - precision: 0.6503 - recall: 0.5693 - tn: 35636.5117 - tp: 1864.3975 - val_auc: 0.9496 - val_bs: 0.0461 - val_f1_score: 0.6559 - val_loss: 0.1557 - val_prc: 0.7129 - val_precision: 0.6950 - val_recall: 0.6210 - val_tn: 17433.0000 - val_tp: 1002.0000
# Epoch 5/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9376 - bs: 0.0499 - f1_score: 0.6244 - loss: 0.1696 - prc: 0.6641 - precision: 0.6739 - recall: 0.5819 - tn: 35705.1914 - tp: 1928.0000 - val_auc: 0.9538 - val_bs: 0.0446 - val_f1_score: 0.6725 - val_loss: 0.1502 - val_prc: 0.7269 - val_precision: 0.6938 - val_recall: 0.6525 - val_tn: 17409.0000 - val_tp: 1065.0000
# Epoch 6/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9408 - bs: 0.0497 - f1_score: 0.6406 - loss: 0.1679 - prc: 0.6688 - precision: 0.6731 - recall: 0.6111 - tn: 35592.5117 - tp: 2095.4871 - val_auc: 0.9563 - val_bs: 0.0438 - val_f1_score: 0.6813 - val_loss: 0.1469 - val_prc: 0.7380 - val_precision: 0.7085 - val_recall: 0.6562 - val_tn: 17435.0000 - val_tp: 1057.0000
# Epoch 7/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9470 - bs: 0.0479 - f1_score: 0.6580 - loss: 0.1609 - prc: 0.6988 - precision: 0.6789 - recall: 0.6385 - tn: 35573.3828 - tp: 2156.6667 - val_auc: 0.9581 - val_bs: 0.0430 - val_f1_score: 0.6900 - val_loss: 0.1439 - val_prc: 0.7444 - val_precision: 0.7076 - val_recall: 0.6732 - val_tn: 17402.0000 - val_tp: 1101.0000
# Epoch 8/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9485 - bs: 0.0459 - f1_score: 0.6698 - loss: 0.1553 - prc: 0.7099 - precision: 0.6888 - recall: 0.6520 - tn: 35648.5508 - tp: 2208.1924 - val_auc: 0.9595 - val_bs: 0.0425 - val_f1_score: 0.6920 - val_loss: 0.1417 - val_prc: 0.7500 - val_precision: 0.7080 - val_recall: 0.6768 - val_tn: 17410.0000 - val_tp: 1101.0000
# Epoch 9/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9522 - bs: 0.0456 - f1_score: 0.6789 - loss: 0.1534 - prc: 0.7193 - precision: 0.6900 - recall: 0.6683 - tn: 35569.8203 - tp: 2330.1155 - val_auc: 0.9599 - val_bs: 0.0420 - val_f1_score: 0.6969 - val_loss: 0.1399 - val_prc: 0.7536 - val_precision: 0.7063 - val_recall: 0.6877 - val_tn: 17400.0000 - val_tp: 1137.0000
# Epoch 10/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9505 - bs: 0.0459 - f1_score: 0.6743 - loss: 0.1547 - prc: 0.7078 - precision: 0.6857 - recall: 0.6633 - tn: 35599.3203 - tp: 2305.0386 - val_auc: 0.9607 - val_bs: 0.0416 - val_f1_score: 0.6996 - val_loss: 0.1384 - val_prc: 0.7552 - val_precision: 0.6960 - val_recall: 0.7032 - val_tn: 17353.0000 - val_tp: 1187.0000
# Epoch 11/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9526 - bs: 0.0445 - f1_score: 0.6834 - loss: 0.1503 - prc: 0.7214 - precision: 0.6808 - recall: 0.6863 - tn: 35592.2578 - tp: 2340.9614 - val_auc: 0.9612 - val_bs: 0.0412 - val_f1_score: 0.7045 - val_loss: 0.1373 - val_prc: 0.7578 - val_precision: 0.6943 - val_recall: 0.7151 - val_tn: 17346.0000 - val_tp: 1218.0000
# Epoch 12/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9547 - bs: 0.0436 - f1_score: 0.6973 - loss: 0.1473 - prc: 0.7289 - precision: 0.6924 - recall: 0.7024 - tn: 35591.1406 - tp: 2412.8206 - val_auc: 0.9618 - val_bs: 0.0411 - val_f1_score: 0.7012 - val_loss: 0.1365 - val_prc: 0.7602 - val_precision: 0.6981 - val_recall: 0.7042 - val_tn: 17366.0000 - val_tp: 1191.0000
# Epoch 13/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9549 - bs: 0.0438 - f1_score: 0.6892 - loss: 0.1471 - prc: 0.7251 - precision: 0.6826 - recall: 0.6961 - tn: 35587.1172 - tp: 2432.4744 - val_auc: 0.9624 - val_bs: 0.0408 - val_f1_score: 0.7018 - val_loss: 0.1356 - val_prc: 0.7614 - val_precision: 0.6886 - val_recall: 0.7156 - val_tn: 17343.0000 - val_tp: 1232.0000
# Epoch 14/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9578 - bs: 0.0426 - f1_score: 0.7094 - loss: 0.1435 - prc: 0.7495 - precision: 0.7032 - recall: 0.7159 - tn: 35540.2930 - tp: 2505.8845 - val_auc: 0.9627 - val_bs: 0.0408 - val_f1_score: 0.7047 - val_loss: 0.1353 - val_prc: 0.7635 - val_precision: 0.7036 - val_recall: 0.7058 - val_tn: 17378.0000 - val_tp: 1182.0000
# Epoch 15/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9579 - bs: 0.0427 - f1_score: 0.7027 - loss: 0.1435 - prc: 0.7420 - precision: 0.6985 - recall: 0.7069 - tn: 35529.5781 - tp: 2469.7949 - val_auc: 0.9633 - val_bs: 0.0408 - val_f1_score: 0.7069 - val_loss: 0.1352 - val_prc: 0.7648 - val_precision: 0.7111 - val_recall: 0.7027 - val_tn: 17413.0000 - val_tp: 1158.0000
# Epoch 16/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9599 - bs: 0.0413 - f1_score: 0.7057 - loss: 0.1387 - prc: 0.7464 - precision: 0.6935 - recall: 0.7185 - tn: 35589.5273 - tp: 2488.6155 - val_auc: 0.9637 - val_bs: 0.0404 - val_f1_score: 0.7081 - val_loss: 0.1340 - val_prc: 0.7657 - val_precision: 0.6931 - val_recall: 0.7239 - val_tn: 17337.0000 - val_tp: 1245.0000
# Epoch 17/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9594 - bs: 0.0417 - f1_score: 0.7053 - loss: 0.1394 - prc: 0.7418 - precision: 0.6911 - recall: 0.7202 - tn: 35583.3594 - tp: 2459.1667 - val_auc: 0.9641 - val_bs: 0.0405 - val_f1_score: 0.7075 - val_loss: 0.1341 - val_prc: 0.7669 - val_precision: 0.7065 - val_recall: 0.7084 - val_tn: 17387.0000 - val_tp: 1192.0000
# Epoch 18/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9574 - bs: 0.0422 - f1_score: 0.6988 - loss: 0.1424 - prc: 0.7457 - precision: 0.6961 - recall: 0.7021 - tn: 35586.1016 - tp: 2485.2307 - val_auc: 0.9642 - val_bs: 0.0403 - val_f1_score: 0.7121 - val_loss: 0.1335 - val_prc: 0.7671 - val_precision: 0.6983 - val_recall: 0.7265 - val_tn: 17346.0000 - val_tp: 1234.0000
# Epoch 19/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9598 - bs: 0.0415 - f1_score: 0.7103 - loss: 0.1400 - prc: 0.7541 - precision: 0.6992 - recall: 0.7218 - tn: 35538.0391 - tp: 2567.8076 - val_auc: 0.9645 - val_bs: 0.0405 - val_f1_score: 0.7079 - val_loss: 0.1341 - val_prc: 0.7686 - val_precision: 0.7169 - val_recall: 0.6991 - val_tn: 17401.0000 - val_tp: 1176.0000
# Epoch 20/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9587 - bs: 0.0419 - f1_score: 0.7068 - loss: 0.1418 - prc: 0.7474 - precision: 0.6983 - recall: 0.7158 - tn: 35547.8203 - tp: 2559.5642 - val_auc: 0.9649 - val_bs: 0.0403 - val_f1_score: 0.7123 - val_loss: 0.1334 - val_prc: 0.7701 - val_precision: 0.7141 - val_recall: 0.7104 - val_tn: 17399.0000 - val_tp: 1178.0000
# Epoch 21/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9588 - bs: 0.0417 - f1_score: 0.7114 - loss: 0.1406 - prc: 0.7555 - precision: 0.6937 - recall: 0.7302 - tn: 35498.8828 - tp: 2572.1282 - val_auc: 0.9649 - val_bs: 0.0400 - val_f1_score: 0.7123 - val_loss: 0.1326 - val_prc: 0.7699 - val_precision: 0.7016 - val_recall: 0.7234 - val_tn: 17358.0000 - val_tp: 1230.0000
# Epoch 22/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9608 - bs: 0.0417 - f1_score: 0.7188 - loss: 0.1399 - prc: 0.7602 - precision: 0.7050 - recall: 0.7333 - tn: 35527.7422 - tp: 2594.4231 - val_auc: 0.9650 - val_bs: 0.0401 - val_f1_score: 0.7122 - val_loss: 0.1329 - val_prc: 0.7711 - val_precision: 0.7150 - val_recall: 0.7094 - val_tn: 17398.0000 - val_tp: 1175.0000
# Epoch 23/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9588 - bs: 0.0418 - f1_score: 0.7078 - loss: 0.1404 - prc: 0.7553 - precision: 0.6932 - recall: 0.7231 - tn: 35543.0000 - tp: 2549.3589 - val_auc: 0.9649 - val_bs: 0.0400 - val_f1_score: 0.7141 - val_loss: 0.1325 - val_prc: 0.7715 - val_precision: 0.7090 - val_recall: 0.7192 - val_tn: 17392.0000 - val_tp: 1197.0000
# Epoch 24/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9584 - bs: 0.0416 - f1_score: 0.7106 - loss: 0.1400 - prc: 0.7471 - precision: 0.6879 - recall: 0.7350 - tn: 35527.6172 - tp: 2539.3975 - val_auc: 0.9653 - val_bs: 0.0398 - val_f1_score: 0.7187 - val_loss: 0.1318 - val_prc: 0.7722 - val_precision: 0.7000 - val_recall: 0.7384 - val_tn: 17351.0000 - val_tp: 1244.0000
# Epoch 25/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9616 - bs: 0.0399 - f1_score: 0.7179 - loss: 0.1347 - prc: 0.7703 - precision: 0.6961 - recall: 0.7412 - tn: 35514.3086 - tp: 2627.9231 - val_auc: 0.9656 - val_bs: 0.0398 - val_f1_score: 0.7176 - val_loss: 0.1319 - val_prc: 0.7730 - val_precision: 0.7064 - val_recall: 0.7291 - val_tn: 17369.0000 - val_tp: 1220.0000
# Epoch 26/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9621 - bs: 0.0398 - f1_score: 0.7205 - loss: 0.1349 - prc: 0.7613 - precision: 0.7015 - recall: 0.7406 - tn: 35624.5000 - tp: 2587.1538 - val_auc: 0.9657 - val_bs: 0.0396 - val_f1_score: 0.7214 - val_loss: 0.1314 - val_prc: 0.7730 - val_precision: 0.6997 - val_recall: 0.7446 - val_tn: 17340.0000 - val_tp: 1265.0000
# Epoch 27/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9616 - bs: 0.0402 - f1_score: 0.7213 - loss: 0.1358 - prc: 0.7600 - precision: 0.7011 - recall: 0.7427 - tn: 35513.5117 - tp: 2642.7051 - val_auc: 0.9658 - val_bs: 0.0397 - val_f1_score: 0.7223 - val_loss: 0.1316 - val_prc: 0.7737 - val_precision: 0.7045 - val_recall: 0.7410 - val_tn: 17368.0000 - val_tp: 1246.0000
# Epoch 28/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9603 - bs: 0.0412 - f1_score: 0.7180 - loss: 0.1390 - prc: 0.7557 - precision: 0.6953 - recall: 0.7424 - tn: 35506.1914 - tp: 2639.0769 - val_auc: 0.9655 - val_bs: 0.0397 - val_f1_score: 0.7204 - val_loss: 0.1317 - val_prc: 0.7739 - val_precision: 0.7042 - val_recall: 0.7373 - val_tn: 17366.0000 - val_tp: 1246.0000
# Epoch 29/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9614 - bs: 0.0395 - f1_score: 0.7241 - loss: 0.1343 - prc: 0.7702 - precision: 0.7037 - recall: 0.7456 - tn: 35526.1523 - tp: 2680.0513 - val_auc: 0.9656 - val_bs: 0.0400 - val_f1_score: 0.7148 - val_loss: 0.1327 - val_prc: 0.7738 - val_precision: 0.7135 - val_recall: 0.7161 - val_tn: 17416.0000 - val_tp: 1189.0000
# Epoch 30/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9603 - bs: 0.0410 - f1_score: 0.7094 - loss: 0.1386 - prc: 0.7524 - precision: 0.6870 - recall: 0.7334 - tn: 35554.3984 - tp: 2587.1025 - val_auc: 0.9651 - val_bs: 0.0395 - val_f1_score: 0.7216 - val_loss: 0.1312 - val_prc: 0.7747 - val_precision: 0.7013 - val_recall: 0.7430 - val_tn: 17357.0000 - val_tp: 1255.0000
# Epoch 31/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9618 - bs: 0.0402 - f1_score: 0.7185 - loss: 0.1362 - prc: 0.7613 - precision: 0.6953 - recall: 0.7435 - tn: 35523.3477 - tp: 2635.5129 - val_auc: 0.9656 - val_bs: 0.0396 - val_f1_score: 0.7201 - val_loss: 0.1314 - val_prc: 0.7747 - val_precision: 0.6986 - val_recall: 0.7430 - val_tn: 17360.0000 - val_tp: 1254.0000
# Epoch 32/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9631 - bs: 0.0402 - f1_score: 0.7209 - loss: 0.1349 - prc: 0.7623 - precision: 0.6967 - recall: 0.7469 - tn: 35557.5508 - tp: 2645.7437 - val_auc: 0.9658 - val_bs: 0.0397 - val_f1_score: 0.7191 - val_loss: 0.1317 - val_prc: 0.7752 - val_precision: 0.7066 - val_recall: 0.7322 - val_tn: 17383.0000 - val_tp: 1238.0000
# Epoch 33/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9626 - bs: 0.0398 - f1_score: 0.7271 - loss: 0.1341 - prc: 0.7692 - precision: 0.7016 - recall: 0.7546 - tn: 35496.3320 - tp: 2711.8845 - val_auc: 0.9655 - val_bs: 0.0397 - val_f1_score: 0.7192 - val_loss: 0.1316 - val_prc: 0.7753 - val_precision: 0.7071 - val_recall: 0.7316 - val_tn: 17383.0000 - val_tp: 1227.0000
# Epoch 34/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9616 - bs: 0.0400 - f1_score: 0.7167 - loss: 0.1350 - prc: 0.7609 - precision: 0.6926 - recall: 0.7428 - tn: 35566.5625 - tp: 2611.2820 - val_auc: 0.9658 - val_bs: 0.0395 - val_f1_score: 0.7228 - val_loss: 0.1311 - val_prc: 0.7754 - val_precision: 0.7014 - val_recall: 0.7456 - val_tn: 17351.0000 - val_tp: 1267.0000
# Epoch 35/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9631 - bs: 0.0399 - f1_score: 0.7257 - loss: 0.1346 - prc: 0.7728 - precision: 0.6993 - recall: 0.7543 - tn: 35510.8203 - tp: 2695.4102 - val_auc: 0.9655 - val_bs: 0.0395 - val_f1_score: 0.7189 - val_loss: 0.1312 - val_prc: 0.7763 - val_precision: 0.7009 - val_recall: 0.7378 - val_tn: 17370.0000 - val_tp: 1254.0000
# Epoch 36/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9628 - bs: 0.0400 - f1_score: 0.7192 - loss: 0.1346 - prc: 0.7626 - precision: 0.6936 - recall: 0.7468 - tn: 35565.6914 - tp: 2646.5898 - val_auc: 0.9658 - val_bs: 0.0394 - val_f1_score: 0.7196 - val_loss: 0.1309 - val_prc: 0.7759 - val_precision: 0.6976 - val_recall: 0.7430 - val_tn: 17351.0000 - val_tp: 1283.0000
# Epoch 37/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9642 - bs: 0.0387 - f1_score: 0.7295 - loss: 0.1305 - prc: 0.7766 - precision: 0.6990 - recall: 0.7628 - tn: 35558.2695 - tp: 2670.7820 - val_auc: 0.9656 - val_bs: 0.0394 - val_f1_score: 0.7205 - val_loss: 0.1308 - val_prc: 0.7767 - val_precision: 0.6957 - val_recall: 0.7472 - val_tn: 17359.0000 - val_tp: 1272.0000
# Epoch 38/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9628 - bs: 0.0395 - f1_score: 0.7218 - loss: 0.1341 - prc: 0.7661 - precision: 0.6952 - recall: 0.7506 - tn: 35540.9883 - tp: 2659.6025 - val_auc: 0.9661 - val_bs: 0.0395 - val_f1_score: 0.7208 - val_loss: 0.1310 - val_prc: 0.7760 - val_precision: 0.7036 - val_recall: 0.7389 - val_tn: 17379.0000 - val_tp: 1246.0000
# Epoch 39/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9626 - bs: 0.0402 - f1_score: 0.7179 - loss: 0.1350 - prc: 0.7633 - precision: 0.6904 - recall: 0.7477 - tn: 35533.2812 - tp: 2650.0256 - val_auc: 0.9659 - val_bs: 0.0394 - val_f1_score: 0.7201 - val_loss: 0.1310 - val_prc: 0.7773 - val_precision: 0.7022 - val_recall: 0.7389 - val_tn: 17373.0000 - val_tp: 1261.0000
# Epoch 40/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9628 - bs: 0.0401 - f1_score: 0.7253 - loss: 0.1346 - prc: 0.7745 - precision: 0.6947 - recall: 0.7589 - tn: 35456.1797 - tp: 2723.2051 - val_auc: 0.9660 - val_bs: 0.0394 - val_f1_score: 0.7215 - val_loss: 0.1308 - val_prc: 0.7771 - val_precision: 0.6962 - val_recall: 0.7487 - val_tn: 17351.0000 - val_tp: 1279.0000
# Epoch 41/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9624 - bs: 0.0399 - f1_score: 0.7254 - loss: 0.1348 - prc: 0.7739 - precision: 0.6946 - recall: 0.7591 - tn: 35475.8711 - tp: 2723.3975 - val_auc: 0.9659 - val_bs: 0.0394 - val_f1_score: 0.7189 - val_loss: 0.1308 - val_prc: 0.7769 - val_precision: 0.6950 - val_recall: 0.7446 - val_tn: 17357.0000 - val_tp: 1274.0000
# Epoch 42/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9636 - bs: 0.0393 - f1_score: 0.7296 - loss: 0.1327 - prc: 0.7769 - precision: 0.6992 - recall: 0.7629 - tn: 35500.2930 - tp: 2715.3718 - val_auc: 0.9662 - val_bs: 0.0395 - val_f1_score: 0.7179 - val_loss: 0.1309 - val_prc: 0.7777 - val_precision: 0.6976 - val_recall: 0.7394 - val_tn: 17378.0000 - val_tp: 1256.0000
# Epoch 43/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9637 - bs: 0.0394 - f1_score: 0.7262 - loss: 0.1326 - prc: 0.7675 - precision: 0.6976 - recall: 0.7572 - tn: 35552.0273 - tp: 2685.0513 - val_auc: 0.9662 - val_bs: 0.0395 - val_f1_score: 0.7166 - val_loss: 0.1312 - val_prc: 0.7779 - val_precision: 0.7022 - val_recall: 0.7316 - val_tn: 17381.0000 - val_tp: 1248.0000
# Epoch 44/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9649 - bs: 0.0389 - f1_score: 0.7311 - loss: 0.1312 - prc: 0.7713 - precision: 0.7002 - recall: 0.7650 - tn: 35525.1172 - tp: 2707.7307 - val_auc: 0.9662 - val_bs: 0.0394 - val_f1_score: 0.7172 - val_loss: 0.1310 - val_prc: 0.7782 - val_precision: 0.6996 - val_recall: 0.7358 - val_tn: 17365.0000 - val_tp: 1257.0000
# Epoch 45/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9613 - bs: 0.0404 - f1_score: 0.7210 - loss: 0.1368 - prc: 0.7641 - precision: 0.6952 - recall: 0.7489 - tn: 35505.9102 - tp: 2700.8589 - val_auc: 0.9662 - val_bs: 0.0393 - val_f1_score: 0.7192 - val_loss: 0.1307 - val_prc: 0.7796 - val_precision: 0.6901 - val_recall: 0.7508 - val_tn: 17349.0000 - val_tp: 1278.0000
# Epoch 46/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9632 - bs: 0.0398 - f1_score: 0.7298 - loss: 0.1341 - prc: 0.7735 - precision: 0.6966 - recall: 0.7665 - tn: 35468.1523 - tp: 2762.4102 - val_auc: 0.9662 - val_bs: 0.0394 - val_f1_score: 0.7204 - val_loss: 0.1310 - val_prc: 0.7793 - val_precision: 0.7042 - val_recall: 0.7373 - val_tn: 17388.0000 - val_tp: 1250.0000
# Epoch 47/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9637 - bs: 0.0391 - f1_score: 0.7258 - loss: 0.1324 - prc: 0.7750 - precision: 0.7021 - recall: 0.7512 - tn: 35518.0508 - tp: 2720.7949 - val_auc: 0.9662 - val_bs: 0.0397 - val_f1_score: 0.7178 - val_loss: 0.1318 - val_prc: 0.7783 - val_precision: 0.7123 - val_recall: 0.7234 - val_tn: 17400.0000 - val_tp: 1235.0000
# Epoch 48/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9642 - bs: 0.0384 - f1_score: 0.7268 - loss: 0.1298 - prc: 0.7765 - precision: 0.7002 - recall: 0.7556 - tn: 35612.6406 - tp: 2668.7693 - val_auc: 0.9662 - val_bs: 0.0392 - val_f1_score: 0.7203 - val_loss: 0.1302 - val_prc: 0.7788 - val_precision: 0.6892 - val_recall: 0.7544 - val_tn: 17335.0000 - val_tp: 1297.0000
# Epoch 49/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9633 - bs: 0.0390 - f1_score: 0.7332 - loss: 0.1325 - prc: 0.7783 - precision: 0.7052 - recall: 0.7637 - tn: 35501.6406 - tp: 2750.3076 - val_auc: 0.9658 - val_bs: 0.0397 - val_f1_score: 0.7188 - val_loss: 0.1319 - val_prc: 0.7797 - val_precision: 0.7159 - val_recall: 0.7218 - val_tn: 17412.0000 - val_tp: 1214.0000
# Epoch 50/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9632 - bs: 0.0400 - f1_score: 0.7254 - loss: 0.1349 - prc: 0.7713 - precision: 0.6984 - recall: 0.7547 - tn: 35471.4102 - tp: 2725.8333 - val_auc: 0.9659 - val_bs: 0.0392 - val_f1_score: 0.7188 - val_loss: 0.1303 - val_prc: 0.7794 - val_precision: 0.6929 - val_recall: 0.7466 - val_tn: 17353.0000 - val_tp: 1269.0000
# Epoch 51/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9634 - bs: 0.0397 - f1_score: 0.7280 - loss: 0.1341 - prc: 0.7707 - precision: 0.6960 - recall: 0.7633 - tn: 35493.5508 - tp: 2740.3845 - val_auc: 0.9655 - val_bs: 0.0394 - val_f1_score: 0.7159 - val_loss: 0.1310 - val_prc: 0.7787 - val_precision: 0.7008 - val_recall: 0.7316 - val_tn: 17381.0000 - val_tp: 1252.0000
# Epoch 52/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9633 - bs: 0.0398 - f1_score: 0.7244 - loss: 0.1342 - prc: 0.7765 - precision: 0.6996 - recall: 0.7512 - tn: 35495.0391 - tp: 2719.7949 - val_auc: 0.9662 - val_bs: 0.0393 - val_f1_score: 0.7176 - val_loss: 0.1306 - val_prc: 0.7801 - val_precision: 0.6962 - val_recall: 0.7404 - val_tn: 17380.0000 - val_tp: 1261.0000
# Epoch 53/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9655 - bs: 0.0384 - f1_score: 0.7357 - loss: 0.1294 - prc: 0.7878 - precision: 0.7062 - recall: 0.7678 - tn: 35520.4219 - tp: 2769.4358 - val_auc: 0.9662 - val_bs: 0.0393 - val_f1_score: 0.7181 - val_loss: 0.1307 - val_prc: 0.7804 - val_precision: 0.7026 - val_recall: 0.7342 - val_tn: 17378.0000 - val_tp: 1257.0000
# Epoch 54/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9631 - bs: 0.0389 - f1_score: 0.7258 - loss: 0.1316 - prc: 0.7711 - precision: 0.6957 - recall: 0.7588 - tn: 35601.7070 - tp: 2650.0000 - val_auc: 0.9665 - val_bs: 0.0392 - val_f1_score: 0.7209 - val_loss: 0.1303 - val_prc: 0.7815 - val_precision: 0.6946 - val_recall: 0.7492 - val_tn: 17350.0000 - val_tp: 1274.0000
# Epoch 55/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9648 - bs: 0.0385 - f1_score: 0.7342 - loss: 0.1308 - prc: 0.7804 - precision: 0.7027 - recall: 0.7686 - tn: 35520.7422 - tp: 2759.5256 - val_auc: 0.9663 - val_bs: 0.0394 - val_f1_score: 0.7174 - val_loss: 0.1308 - val_prc: 0.7796 - val_precision: 0.7023 - val_recall: 0.7332 - val_tn: 17394.0000 - val_tp: 1252.0000
# Epoch 56/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9644 - bs: 0.0387 - f1_score: 0.7354 - loss: 0.1315 - prc: 0.7821 - precision: 0.7107 - recall: 0.7618 - tn: 35528.7422 - tp: 2746.6025 - val_auc: 0.9665 - val_bs: 0.0392 - val_f1_score: 0.7176 - val_loss: 0.1303 - val_prc: 0.7814 - val_precision: 0.6979 - val_recall: 0.7384 - val_tn: 17373.0000 - val_tp: 1264.0000
# Epoch 57/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9645 - bs: 0.0394 - f1_score: 0.7262 - loss: 0.1323 - prc: 0.7759 - precision: 0.6970 - recall: 0.7580 - tn: 35506.6797 - tp: 2722.7051 - val_auc: 0.9657 - val_bs: 0.0393 - val_f1_score: 0.7150 - val_loss: 0.1306 - val_prc: 0.7804 - val_precision: 0.6962 - val_recall: 0.7347 - val_tn: 17376.0000 - val_tp: 1264.0000
# Epoch 58/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9640 - bs: 0.0391 - f1_score: 0.7372 - loss: 0.1328 - prc: 0.7835 - precision: 0.7098 - recall: 0.7669 - tn: 35479.0625 - tp: 2777.9871 - val_auc: 0.9660 - val_bs: 0.0393 - val_f1_score: 0.7194 - val_loss: 0.1305 - val_prc: 0.7801 - val_precision: 0.6996 - val_recall: 0.7404 - val_tn: 17378.0000 - val_tp: 1256.0000
# Epoch 59/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9646 - bs: 0.0390 - f1_score: 0.7232 - loss: 0.1311 - prc: 0.7757 - precision: 0.6937 - recall: 0.7553 - tn: 35560.1914 - tp: 2712.4871 - val_auc: 0.9663 - val_bs: 0.0391 - val_f1_score: 0.7198 - val_loss: 0.1301 - val_prc: 0.7807 - val_precision: 0.6944 - val_recall: 0.7472 - val_tn: 17341.0000 - val_tp: 1288.0000
# Epoch 60/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9652 - bs: 0.0385 - f1_score: 0.7379 - loss: 0.1306 - prc: 0.7897 - precision: 0.7139 - recall: 0.7636 - tn: 35509.2812 - tp: 2783.5256 - val_auc: 0.9665 - val_bs: 0.0392 - val_f1_score: 0.7210 - val_loss: 0.1300 - val_prc: 0.7809 - val_precision: 0.6917 - val_recall: 0.7528 - val_tn: 17351.0000 - val_tp: 1282.0000
# Epoch 61/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9627 - bs: 0.0389 - f1_score: 0.7257 - loss: 0.1327 - prc: 0.7719 - precision: 0.6952 - recall: 0.7592 - tn: 35564.4102 - tp: 2714.9744 - val_auc: 0.9664 - val_bs: 0.0391 - val_f1_score: 0.7210 - val_loss: 0.1300 - val_prc: 0.7813 - val_precision: 0.6944 - val_recall: 0.7497 - val_tn: 17346.0000 - val_tp: 1283.0000
# Epoch 62/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9662 - bs: 0.0380 - f1_score: 0.7408 - loss: 0.1289 - prc: 0.7900 - precision: 0.7133 - recall: 0.7706 - tn: 35530.8711 - tp: 2765.1282 - val_auc: 0.9665 - val_bs: 0.0392 - val_f1_score: 0.7225 - val_loss: 0.1301 - val_prc: 0.7818 - val_precision: 0.6959 - val_recall: 0.7513 - val_tn: 17360.0000 - val_tp: 1274.0000
# Epoch 63/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9649 - bs: 0.0386 - f1_score: 0.7279 - loss: 0.1304 - prc: 0.7796 - precision: 0.6978 - recall: 0.7609 - tn: 35541.6797 - tp: 2722.5000 - val_auc: 0.9667 - val_bs: 0.0392 - val_f1_score: 0.7228 - val_loss: 0.1301 - val_prc: 0.7821 - val_precision: 0.6973 - val_recall: 0.7503 - val_tn: 17366.0000 - val_tp: 1267.0000
# Epoch 64/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9654 - bs: 0.0381 - f1_score: 0.7362 - loss: 0.1290 - prc: 0.7817 - precision: 0.7089 - recall: 0.7656 - tn: 35556.3984 - tp: 2727.7437 - val_auc: 0.9664 - val_bs: 0.0393 - val_f1_score: 0.7152 - val_loss: 0.1305 - val_prc: 0.7818 - val_precision: 0.7013 - val_recall: 0.7296 - val_tn: 17377.0000 - val_tp: 1256.0000
# Epoch 65/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9645 - bs: 0.0390 - f1_score: 0.7306 - loss: 0.1316 - prc: 0.7792 - precision: 0.7019 - recall: 0.7618 - tn: 35515.5273 - tp: 2749.4487 - val_auc: 0.9664 - val_bs: 0.0394 - val_f1_score: 0.7162 - val_loss: 0.1310 - val_prc: 0.7818 - val_precision: 0.7028 - val_recall: 0.7301 - val_tn: 17388.0000 - val_tp: 1238.0000
# Epoch 66/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9654 - bs: 0.0389 - f1_score: 0.7317 - loss: 0.1304 - prc: 0.7782 - precision: 0.6998 - recall: 0.7667 - tn: 35505.7070 - tp: 2753.9487 - val_auc: 0.9668 - val_bs: 0.0392 - val_f1_score: 0.7215 - val_loss: 0.1301 - val_prc: 0.7817 - val_precision: 0.6944 - val_recall: 0.7508 - val_tn: 17344.0000 - val_tp: 1287.0000
# Epoch 67/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9637 - bs: 0.0390 - f1_score: 0.7285 - loss: 0.1322 - prc: 0.7810 - precision: 0.7015 - recall: 0.7577 - tn: 35537.5000 - tp: 2741.7307 - val_auc: 0.9666 - val_bs: 0.0392 - val_f1_score: 0.7230 - val_loss: 0.1301 - val_prc: 0.7826 - val_precision: 0.6976 - val_recall: 0.7503 - val_tn: 17366.0000 - val_tp: 1276.0000
# Epoch 68/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9654 - bs: 0.0381 - f1_score: 0.7322 - loss: 0.1288 - prc: 0.7757 - precision: 0.7050 - recall: 0.7617 - tn: 35595.1797 - tp: 2734.7949 - val_auc: 0.9666 - val_bs: 0.0391 - val_f1_score: 0.7219 - val_loss: 0.1300 - val_prc: 0.7818 - val_precision: 0.6916 - val_recall: 0.7549 - val_tn: 17346.0000 - val_tp: 1286.0000
# Epoch 69/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9645 - bs: 0.0391 - f1_score: 0.7320 - loss: 0.1321 - prc: 0.7803 - precision: 0.7003 - recall: 0.7669 - tn: 35503.9492 - tp: 2765.2820 - val_auc: 0.9664 - val_bs: 0.0390 - val_f1_score: 0.7217 - val_loss: 0.1297 - val_prc: 0.7829 - val_precision: 0.6930 - val_recall: 0.7528 - val_tn: 17332.0000 - val_tp: 1298.0000
# Epoch 70/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9641 - bs: 0.0386 - f1_score: 0.7267 - loss: 0.1305 - prc: 0.7765 - precision: 0.6981 - recall: 0.7579 - tn: 35564.6289 - tp: 2737.5898 - val_auc: 0.9666 - val_bs: 0.0394 - val_f1_score: 0.7157 - val_loss: 0.1310 - val_prc: 0.7835 - val_precision: 0.7072 - val_recall: 0.7244 - val_tn: 17396.0000 - val_tp: 1232.0000
# Epoch 71/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9648 - bs: 0.0386 - f1_score: 0.7356 - loss: 0.1309 - prc: 0.7847 - precision: 0.7100 - recall: 0.7632 - tn: 35557.7188 - tp: 2749.1667 - val_auc: 0.9665 - val_bs: 0.0392 - val_f1_score: 0.7205 - val_loss: 0.1303 - val_prc: 0.7840 - val_precision: 0.7016 - val_recall: 0.7404 - val_tn: 17378.0000 - val_tp: 1258.0000
# Epoch 72/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9652 - bs: 0.0384 - f1_score: 0.7326 - loss: 0.1300 - prc: 0.7880 - precision: 0.7039 - recall: 0.7638 - tn: 35509.0625 - tp: 2784.3076 - val_auc: 0.9667 - val_bs: 0.0391 - val_f1_score: 0.7219 - val_loss: 0.1300 - val_prc: 0.7843 - val_precision: 0.6973 - val_recall: 0.7482 - val_tn: 17363.0000 - val_tp: 1269.0000
# Epoch 73/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9638 - bs: 0.0387 - f1_score: 0.7265 - loss: 0.1312 - prc: 0.7759 - precision: 0.6951 - recall: 0.7610 - tn: 35531.8086 - tp: 2738.6025 - val_auc: 0.9662 - val_bs: 0.0393 - val_f1_score: 0.7195 - val_loss: 0.1304 - val_prc: 0.7831 - val_precision: 0.7043 - val_recall: 0.7353 - val_tn: 17382.0000 - val_tp: 1245.0000
# Epoch 74/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9648 - bs: 0.0382 - f1_score: 0.7347 - loss: 0.1302 - prc: 0.7869 - precision: 0.7080 - recall: 0.7636 - tn: 35548.2930 - tp: 2764.1667 - val_auc: 0.9666 - val_bs: 0.0392 - val_f1_score: 0.7238 - val_loss: 0.1301 - val_prc: 0.7838 - val_precision: 0.7060 - val_recall: 0.7425 - val_tn: 17380.0000 - val_tp: 1253.0000
# Epoch 75/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9647 - bs: 0.0384 - f1_score: 0.7345 - loss: 0.1300 - prc: 0.7849 - precision: 0.7038 - recall: 0.7683 - tn: 35521.4102 - tp: 2777.9358 - val_auc: 0.9666 - val_bs: 0.0392 - val_f1_score: 0.7244 - val_loss: 0.1302 - val_prc: 0.7819 - val_precision: 0.7044 - val_recall: 0.7456 - val_tn: 17373.0000 - val_tp: 1262.0000
# Epoch 76/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9650 - bs: 0.0380 - f1_score: 0.7411 - loss: 0.1296 - prc: 0.7890 - precision: 0.7133 - recall: 0.7711 - tn: 35549.0625 - tp: 2802.8076 - val_auc: 0.9666 - val_bs: 0.0391 - val_f1_score: 0.7197 - val_loss: 0.1298 - val_prc: 0.7833 - val_precision: 0.6956 - val_recall: 0.7456 - val_tn: 17356.0000 - val_tp: 1275.0000
# Epoch 77/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9655 - bs: 0.0385 - f1_score: 0.7328 - loss: 0.1298 - prc: 0.7850 - precision: 0.7044 - recall: 0.7636 - tn: 35505.6914 - tp: 2762.4231 - val_auc: 0.9667 - val_bs: 0.0392 - val_f1_score: 0.7212 - val_loss: 0.1302 - val_prc: 0.7852 - val_precision: 0.7067 - val_recall: 0.7363 - val_tn: 17386.0000 - val_tp: 1242.0000
# Epoch 78/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9643 - bs: 0.0388 - f1_score: 0.7343 - loss: 0.1313 - prc: 0.7890 - precision: 0.7075 - recall: 0.7633 - tn: 35502.7422 - tp: 2786.8975 - val_auc: 0.9668 - val_bs: 0.0391 - val_f1_score: 0.7223 - val_loss: 0.1301 - val_prc: 0.7843 - val_precision: 0.7045 - val_recall: 0.7410 - val_tn: 17381.0000 - val_tp: 1263.0000
# Epoch 79/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9641 - bs: 0.0386 - f1_score: 0.7311 - loss: 0.1312 - prc: 0.7795 - precision: 0.7061 - recall: 0.7579 - tn: 35566.5000 - tp: 2725.6025 - val_auc: 0.9667 - val_bs: 0.0389 - val_f1_score: 0.7262 - val_loss: 0.1293 - val_prc: 0.7851 - val_precision: 0.6978 - val_recall: 0.7570 - val_tn: 17348.0000 - val_tp: 1298.0000
# Epoch 80/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9656 - bs: 0.0377 - f1_score: 0.7379 - loss: 0.1277 - prc: 0.7895 - precision: 0.7040 - recall: 0.7754 - tn: 35511.1406 - tp: 2812.0386 - val_auc: 0.9672 - val_bs: 0.0389 - val_f1_score: 0.7246 - val_loss: 0.1294 - val_prc: 0.7851 - val_precision: 0.6983 - val_recall: 0.7528 - val_tn: 17354.0000 - val_tp: 1288.0000
# Epoch 81/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9655 - bs: 0.0383 - f1_score: 0.7337 - loss: 0.1294 - prc: 0.7867 - precision: 0.7053 - recall: 0.7646 - tn: 35495.5898 - tp: 2795.1924 - val_auc: 0.9665 - val_bs: 0.0390 - val_f1_score: 0.7244 - val_loss: 0.1296 - val_prc: 0.7848 - val_precision: 0.7026 - val_recall: 0.7477 - val_tn: 17361.0000 - val_tp: 1271.0000
# Epoch 82/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9663 - bs: 0.0381 - f1_score: 0.7404 - loss: 0.1285 - prc: 0.7877 - precision: 0.7088 - recall: 0.7751 - tn: 35517.8711 - tp: 2793.1538 - val_auc: 0.9672 - val_bs: 0.0389 - val_f1_score: 0.7227 - val_loss: 0.1294 - val_prc: 0.7857 - val_precision: 0.6962 - val_recall: 0.7513 - val_tn: 17358.0000 - val_tp: 1288.0000
# Epoch 83/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9656 - bs: 0.0377 - f1_score: 0.7337 - loss: 0.1283 - prc: 0.7834 - precision: 0.7024 - recall: 0.7682 - tn: 35570.1914 - tp: 2760.3845 - val_auc: 0.9671 - val_bs: 0.0390 - val_f1_score: 0.7229 - val_loss: 0.1297 - val_prc: 0.7843 - val_precision: 0.7048 - val_recall: 0.7420 - val_tn: 17372.0000 - val_tp: 1263.0000
# Epoch 84/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9651 - bs: 0.0381 - f1_score: 0.7302 - loss: 0.1287 - prc: 0.7808 - precision: 0.7068 - recall: 0.7554 - tn: 35590.5000 - tp: 2702.5898 - val_auc: 0.9672 - val_bs: 0.0390 - val_f1_score: 0.7266 - val_loss: 0.1294 - val_prc: 0.7850 - val_precision: 0.7031 - val_recall: 0.7518 - val_tn: 17358.0000 - val_tp: 1275.0000
# Epoch 85/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9645 - bs: 0.0385 - f1_score: 0.7324 - loss: 0.1311 - prc: 0.7813 - precision: 0.7057 - recall: 0.7612 - tn: 35536.0000 - tp: 2761.1155 - val_auc: 0.9669 - val_bs: 0.0391 - val_f1_score: 0.7223 - val_loss: 0.1298 - val_prc: 0.7839 - val_precision: 0.7027 - val_recall: 0.7430 - val_tn: 17371.0000 - val_tp: 1275.0000
# Epoch 86/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9663 - bs: 0.0375 - f1_score: 0.7350 - loss: 0.1267 - prc: 0.7905 - precision: 0.7052 - recall: 0.7676 - tn: 35542.9219 - tp: 2768.5000 - val_auc: 0.9671 - val_bs: 0.0389 - val_f1_score: 0.7229 - val_loss: 0.1292 - val_prc: 0.7853 - val_precision: 0.6971 - val_recall: 0.7508 - val_tn: 17350.0000 - val_tp: 1295.0000
# Epoch 87/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9641 - bs: 0.0384 - f1_score: 0.7328 - loss: 0.1302 - prc: 0.7780 - precision: 0.7047 - recall: 0.7631 - tn: 35566.3594 - tp: 2751.5000 - val_auc: 0.9668 - val_bs: 0.0389 - val_f1_score: 0.7203 - val_loss: 0.1295 - val_prc: 0.7860 - val_precision: 0.6989 - val_recall: 0.7430 - val_tn: 17362.0000 - val_tp: 1286.0000
# Epoch 88/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9645 - bs: 0.0379 - f1_score: 0.7352 - loss: 0.1292 - prc: 0.7891 - precision: 0.7090 - recall: 0.7635 - tn: 35560.0000 - tp: 2738.6794 - val_auc: 0.9670 - val_bs: 0.0388 - val_f1_score: 0.7229 - val_loss: 0.1288 - val_prc: 0.7861 - val_precision: 0.6909 - val_recall: 0.7580 - val_tn: 17324.0000 - val_tp: 1315.0000
# Epoch 89/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9648 - bs: 0.0382 - f1_score: 0.7301 - loss: 0.1292 - prc: 0.7859 - precision: 0.6992 - recall: 0.7638 - tn: 35542.3203 - tp: 2750.1025 - val_auc: 0.9665 - val_bs: 0.0389 - val_f1_score: 0.7230 - val_loss: 0.1292 - val_prc: 0.7862 - val_precision: 0.7004 - val_recall: 0.7472 - val_tn: 17364.0000 - val_tp: 1284.0000
# Epoch 90/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9663 - bs: 0.0384 - f1_score: 0.7339 - loss: 0.1287 - prc: 0.7822 - precision: 0.7067 - recall: 0.7634 - tn: 35544.6914 - tp: 2738.3975 - val_auc: 0.9665 - val_bs: 0.0390 - val_f1_score: 0.7214 - val_loss: 0.1295 - val_prc: 0.7855 - val_precision: 0.7028 - val_recall: 0.7410 - val_tn: 17367.0000 - val_tp: 1267.0000
# Epoch 91/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9623 - bs: 0.0388 - f1_score: 0.7384 - loss: 0.1334 - prc: 0.7768 - precision: 0.7144 - recall: 0.7642 - tn: 35523.8086 - tp: 2762.9231 - val_auc: 0.9667 - val_bs: 0.0389 - val_f1_score: 0.7230 - val_loss: 0.1293 - val_prc: 0.7859 - val_precision: 0.7004 - val_recall: 0.7472 - val_tn: 17359.0000 - val_tp: 1286.0000
# Epoch 92/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9658 - bs: 0.0382 - f1_score: 0.7358 - loss: 0.1288 - prc: 0.7906 - precision: 0.7058 - recall: 0.7685 - tn: 35507.6406 - tp: 2793.5129 - val_auc: 0.9672 - val_bs: 0.0389 - val_f1_score: 0.7236 - val_loss: 0.1293 - val_prc: 0.7871 - val_precision: 0.7020 - val_recall: 0.7466 - val_tn: 17369.0000 - val_tp: 1277.0000
# Epoch 93/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9637 - bs: 0.0389 - f1_score: 0.7290 - loss: 0.1318 - prc: 0.7847 - precision: 0.7039 - recall: 0.7563 - tn: 35542.2305 - tp: 2730.0642 - val_auc: 0.9667 - val_bs: 0.0388 - val_f1_score: 0.7242 - val_loss: 0.1291 - val_prc: 0.7854 - val_precision: 0.7017 - val_recall: 0.7482 - val_tn: 17347.0000 - val_tp: 1290.0000
# Epoch 94/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9647 - bs: 0.0383 - f1_score: 0.7361 - loss: 0.1299 - prc: 0.7875 - precision: 0.7041 - recall: 0.7712 - tn: 35493.4609 - tp: 2802.8589 - val_auc: 0.9671 - val_bs: 0.0390 - val_f1_score: 0.7213 - val_loss: 0.1296 - val_prc: 0.7874 - val_precision: 0.7103 - val_recall: 0.7327 - val_tn: 17396.0000 - val_tp: 1256.0000
# Epoch 95/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9643 - bs: 0.0390 - f1_score: 0.7379 - loss: 0.1328 - prc: 0.7847 - precision: 0.7113 - recall: 0.7667 - tn: 35468.8203 - tp: 2828.7051 - val_auc: 0.9669 - val_bs: 0.0388 - val_f1_score: 0.7254 - val_loss: 0.1289 - val_prc: 0.7865 - val_precision: 0.7043 - val_recall: 0.7477 - val_tn: 17365.0000 - val_tp: 1290.0000
# Epoch 96/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9658 - bs: 0.0374 - f1_score: 0.7376 - loss: 0.1271 - prc: 0.7880 - precision: 0.7101 - recall: 0.7674 - tn: 35553.1680 - tp: 2777.5513 - val_auc: 0.9671 - val_bs: 0.0389 - val_f1_score: 0.7236 - val_loss: 0.1293 - val_prc: 0.7863 - val_precision: 0.7033 - val_recall: 0.7451 - val_tn: 17376.0000 - val_tp: 1278.0000
# Epoch 97/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9654 - bs: 0.0389 - f1_score: 0.7411 - loss: 0.1314 - prc: 0.7899 - precision: 0.7135 - recall: 0.7710 - tn: 35442.6523 - tp: 2822.3206 - val_auc: 0.9669 - val_bs: 0.0389 - val_f1_score: 0.7236 - val_loss: 0.1293 - val_prc: 0.7868 - val_precision: 0.7094 - val_recall: 0.7384 - val_tn: 17375.0000 - val_tp: 1268.0000
# Epoch 98/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9646 - bs: 0.0383 - f1_score: 0.7303 - loss: 0.1295 - prc: 0.7812 - precision: 0.7032 - recall: 0.7596 - tn: 35566.4219 - tp: 2727.0386 - val_auc: 0.9674 - val_bs: 0.0387 - val_f1_score: 0.7243 - val_loss: 0.1287 - val_prc: 0.7874 - val_precision: 0.6992 - val_recall: 0.7513 - val_tn: 17349.0000 - val_tp: 1287.0000
# Epoch 99/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9651 - bs: 0.0379 - f1_score: 0.7289 - loss: 0.1280 - prc: 0.7879 - precision: 0.6979 - recall: 0.7630 - tn: 35560.9219 - tp: 2727.8975 - val_auc: 0.9674 - val_bs: 0.0389 - val_f1_score: 0.7267 - val_loss: 0.1290 - val_prc: 0.7863 - val_precision: 0.7036 - val_recall: 0.7513 - val_tn: 17366.0000 - val_tp: 1285.0000
# Epoch 100/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9654 - bs: 0.0384 - f1_score: 0.7353 - loss: 0.1304 - prc: 0.7834 - precision: 0.7032 - recall: 0.7706 - tn: 35504.0000 - tp: 2817.9487 - val_auc: 0.9672 - val_bs: 0.0388 - val_f1_score: 0.7226 - val_loss: 0.1289 - val_prc: 0.7860 - val_precision: 0.7005 - val_recall: 0.7461 - val_tn: 17354.0000 - val_tp: 1288.0000
# Epoch 101/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9653 - bs: 0.0377 - f1_score: 0.7362 - loss: 0.1276 - prc: 0.7896 - precision: 0.7058 - recall: 0.7693 - tn: 35548.4102 - tp: 2784.7180 - val_auc: 0.9679 - val_bs: 0.0388 - val_f1_score: 0.7237 - val_loss: 0.1289 - val_prc: 0.7871 - val_precision: 0.7007 - val_recall: 0.7482 - val_tn: 17372.0000 - val_tp: 1280.0000
# Epoch 102/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9648 - bs: 0.0383 - f1_score: 0.7297 - loss: 0.1296 - prc: 0.7849 - precision: 0.7028 - recall: 0.7587 - tn: 35543.4883 - tp: 2752.7820 - val_auc: 0.9672 - val_bs: 0.0388 - val_f1_score: 0.7239 - val_loss: 0.1289 - val_prc: 0.7857 - val_precision: 0.6998 - val_recall: 0.7497 - val_tn: 17364.0000 - val_tp: 1283.0000
# Epoch 103/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9673 - bs: 0.0375 - f1_score: 0.7403 - loss: 0.1270 - prc: 0.7937 - precision: 0.7122 - recall: 0.7708 - tn: 35566.9727 - tp: 2775.6155 - val_auc: 0.9678 - val_bs: 0.0388 - val_f1_score: 0.7229 - val_loss: 0.1287 - val_prc: 0.7870 - val_precision: 0.6983 - val_recall: 0.7492 - val_tn: 17374.0000 - val_tp: 1284.0000
# Epoch 104/500
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9645 - bs: 0.0381 - f1_score: 0.7389 - loss: 0.1295 - prc: 0.7850 - precision: 0.7090 - recall: 0.7714 - tn: 35532.4727 - tp: 2779.9231 - val_auc: 0.9676 - val_bs: 0.0389 - val_f1_score: 0.7208 - val_loss: 0.1292 - val_prc: 0.7868 - val_precision: 0.7054 - val_recall: 0.7368 - val_tn: 17391.0000 - val_tp: 1268.0000
# Epoch 104: early stopping
# Restoring model weights from the end of the best epoch: 94.

# %%
def class_prediction(x, y):
    y_hat = model.predict(x)      
    bs = brier_score_loss(y, y_hat)    
    auc = roc_auc_score(y, y_hat)
    return y_hat, auc, bs

# %%
def plot_cm(y, y_hat, classification_threshold):
    # compute the contingency table    
    y_hat_class = y_hat >= classification_threshold
    cm = metrics.confusion_matrix(y, y_hat_class)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, linewidths=.5, square = True, cmap = 'Blues_r', cbar=None, fmt='g')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def plot_metrics(history):
  metrics = ['loss', 'bs', 'recall', 'precision']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color="red", label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.5,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %% [markdown]
# ### Performance on training data

# %%
plot_metrics(model_history)

# %% [markdown]
# ### Performance on testing data

# %%
def cutoff_youdens_j(fpr, tpr, thresholds):
    j_scores = tpr-fpr
    j_ordered = sorted(zip(j_scores, thresholds))
    return j_ordered[-1][1]

# %%
y_hat_val, auc_val, bs_val = class_prediction(x_val, y_val)
classification_threshold_val = cutoff_youdens_j(*roc_curve(y_val, y_hat_val))
print(classification_threshold_val)
plot_cm(y_val, y_hat_val, classification_threshold=classification_threshold_val)
# Out:
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 0.057668976

# %%
average_precision_score(y_val, y_hat_val)
# Out:
# 0.7880372747882011

# %%
y_hat_test, auc_test, bs_test = class_prediction(x_test, y_test)
classification_threshold = cutoff_youdens_j(*roc_curve(y_test, y_hat_test))
plot_cm(y_test, y_hat_test, classification_threshold=classification_threshold_val)
# Out:
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
average_precision_score(y_test, y_hat_test)
# Out:
# 0.7566508073363918

# %%
def reliability_curve(y, y_pred, bin_size=0.1, count_pred_per_bin=100):
  y = np.array(y)
  y_pred = np.array(y_pred)
  bins = np.arange(0, 1+bin_size, bin_size)
  bin_centers = [(b1 + b2) / 2 for b1, b2 in zip(bins[:-1], bins[1:])]
  prop_positive = []
  bin_center_ax = []
  no_pred_per_bin = []
  for b1, b2, bc in zip(bins[:-1], bins[1:], bin_centers):
    in_bin = np.logical_and(y_pred >= b1, y_pred < b2)
    no_predictions_per_bin = np.sum(in_bin)
    no_positive_per_bin = np.sum(y[in_bin])    
    if no_predictions_per_bin > count_pred_per_bin:
      prop_pos = round(no_positive_per_bin/no_predictions_per_bin, 3)
      prop_positive.append(prop_pos)
      bin_center_ax.append(round(bc, 3))
      no_pred_per_bin.append(no_predictions_per_bin)
    else:
      continue
  return bin_center_ax, prop_positive, no_pred_per_bin

# %%
prob_pred, prob_true, no_pred_per_bin = reliability_curve(y_test, y_hat_test.flatten())
plt.figure(figsize=(5,4))
plt.plot(prob_pred, prob_true, label=f"NN0{lead_time} {city}")    
    
plt.xlabel("Predicted probability")
plt.ylabel("Obs. proportion of positive case")

no_pred_per_bin = [i/(1.1*np.max(no_pred_per_bin)) for i in no_pred_per_bin]
plt.plot(np.arange(0,1.2,0.2), np.arange(0,1.2,0.2))
plt.bar(prob_pred, no_pred_per_bin, width=0.1, linestyle="--", fill=False, edgecolor="green")

plt.xlim(0,1)
plt.ylim(0,1)
plt.legend(loc='upper center')
plt.show()

# %%
model.save(f'/home/mendrika/mendrika-phd/codes/nflics/model-ML-Dakar/Global-from-{city}-t{lead_time}.keras')

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = metrics.roc_curve(labels, predictions)
  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False alarm [%]')
  plt.ylabel('Hit [%]')
  plt.xlim([0,100])
  plt.ylim([0,100])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
y_hat_train, auc_train, bs_train = class_prediction(x_train, y_train)
plot_roc(f"Training set (AUC={auc_train:.3f})", y_train, y_hat_train, color="red")
plot_roc(f"Testing set  (AUC={auc_test:.3f})", y_test, y_hat_test, color=colors[0], linestyle='--')
plt.title(f"NN0{lead_time} {city}")
plt.legend(loc='lower right');
# Out:
#    1/2464 ━━━━━━━━━━━━━━━━━━━━ 2:09 53ms/step
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
