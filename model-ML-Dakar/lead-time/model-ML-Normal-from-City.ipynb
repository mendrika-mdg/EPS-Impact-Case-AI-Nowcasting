# %% [markdown]
# ### Specific data for specific city

# %%
import pandas as pd                                                                     # type: ignore
import matplotlib.pyplot as plt                                                         # type: ignore
import seaborn as sns                                                                   # type: ignore
import numpy as np                                                                      # type: ignore
from  sklearn import metrics                                                            # type: ignore
from sklearn.preprocessing import StandardScaler                                        # type: ignore
from sklearn.metrics import roc_auc_score, roc_curve, brier_score_loss                  # type: ignore
from sklearn.metrics import average_precision_score                  # type: ignore
import tensorflow as tf                                                                 # type: ignore
from tensorflow.keras.initializers import he_normal # type: ignore
from sklearn.model_selection import train_test_split                                    # type: ignore
import matplotlib as mpl                                                                # type: ignore
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
mpl.rcParams['figure.figsize'] = (9, 7)
from joblib import dump, load                                                           # type: ignore
import sys
sys.path.insert(1, "/home/mendrika/mendrika-phd/codes/nflics")
import nflics

# %% [markdown]
# ### Importing dataset

# %%
city = "Dakar"

# %%
lead_time = 3

# %%
data = pd.read_csv(f"train-data-{city}.csv", index_col=False)
test_data = pd.read_csv(f"test-data-{city}.csv", index_col=False)

# %% [markdown]
# ### Check if the data have outliers

# %%
variable = "lon"
for i in range(5):
    print(np.min(data[f"{variable}{i+1}"]), np.max(data[f"{variable}{i+1}"]))
# Out:
# -17.97 -8.04
# -17.97 -8.04
# -17.97 -2.4676860000000005
# -17.97 -2.4676860000000005
# -17.97 -2.4676860000000005

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def select(df):
    selection_index_lat = df["lat5"] < 30
    selection_index_lon = df["lon5"] < 30
    selection_index = selection_index_lat * selection_index_lon
    return selection_index

index_train = select(data)
index_test = select(test_data)

data = data[index_train]
test_data = test_data[index_test]

# %%
data = data.dropna()
test_data = test_data.dropna()

# %% [markdown]
# #### Choosing field to include in the data

# %%
# Presence or absence of storms in Dakar at time t+1
target_index = f"Cb_{city}_t{lead_time}"

# Input at time t
t0 = "year,month,day,hour,minute,"
location = ""
wavelet_power = ""
storm_size = ""
distance = ""
for i in range(1,6):
    location += f"lat{i},lon{i},"
    wavelet_power += f"wp{i},"
    distance += f"ds{i},"
    storm_size += f"size{i},"
features = t0 + location + wavelet_power + storm_size + distance
field =  features + target_index
field = field.split(',')
data = data[field]
test_data = test_data[field]

# %% [markdown]
# ### Exploratory data analysis

# %%
def log_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i > 0:
                transformed.append(np.log(i))
            else:
                transformed.append(np.log(i+1e-8))    
        df_copy[key] = transformed
    return df_copy

# %%
def sqrt_transform(df, keys):
    df_copy = df.copy()    
    for key in keys:
        transformed = []
        for i in df_copy[key]:
            if i >= 0:
                transformed.append(np.sqrt(i)) 
        df_copy[key] = transformed
    return df_copy

# %%
to_scale = wavelet_power + storm_size + distance

# %%
transform = True
if transform:
    data = log_transform(data, to_scale.split(',')[:-1])    
    data = sqrt_transform(data, t0.split(',')[:-1])
    test_data = log_transform(test_data, to_scale.split(',')[:-1])    
    test_data = sqrt_transform(test_data, t0.split(',')[:-1])

# %% [markdown]
# ### Splitting the data  into training and testing before oversampling the training set

# %%
train, validation = train_test_split(data, test_size=0.2, random_state=12)

# %%
neg, pos = train[target_index].value_counts()
total = neg + pos
print(f"Negative: {neg} and Positive: {pos}. That is {pos/total:.2f} of the total.")
# Out:
# Negative: 76886 and Positive: 6215. That is 0.07 of the total.

# %%
x_train = train.drop([target_index], axis=1).to_numpy()
y_train = train[target_index]

x_val = validation.drop([target_index], axis=1).to_numpy()
y_val = validation[target_index]

x_test = test_data.drop([target_index], axis=1).to_numpy()
y_test = test_data[target_index]

# %%
type = ('Train', 'Validation', 'Test')

storm_counts = {
    'No Storm': np.array([y_train.value_counts()[0], y_val.value_counts()[0], y_test.value_counts()[0]]),
    'Storm': np.array([y_train.value_counts()[1], y_val.value_counts()[1] , y_test.value_counts()[1]]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(7,5))
bottom = np.zeros(3)

for mode, count in storm_counts.items():
    p = ax.bar(type, count, width, label=mode, bottom=bottom)
    bottom += count

    ax.bar_label(p, label_type='center')

ax.legend()

plt.show()

# %% [markdown]
# ### Normalising the features

# %%
# normalise data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# %%
dump(scaler, f'Normal-{city}-t{lead_time}.bin', compress=True)
# Out:
# ['Normal-Dakar-t3.bin']

# %% [markdown]
# ### Creating the model

# %%
initial_bias = np.log(pos/neg)
output_bias = tf.keras.initializers.Constant(value=initial_bias)

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(30,)),
  tf.keras.layers.Dense(16, activation='relu', kernel_initializer=he_normal()),
  tf.keras.layers.Dropout(0.2),    
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid', bias_initializer=output_bias)
])

l1_reg = tf.keras.regularizers.L1(0.1)
for layer in model.layers[:]:
  layer.kernel_regularizer = l1_reg
 
cl_thresholds = 0.25

METRICS = [
      tf.keras.metrics.MeanSquaredError(name='bs'),
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.TrueNegatives(name='tn'),                        
      tf.keras.metrics.Recall(name='recall', thresholds = cl_thresholds),
      tf.keras.metrics.Precision(name='precision', thresholds = cl_thresholds),
      tf.keras.metrics.AUC(name='auc'),
      tf.keras.metrics.AUC(name='prc', curve='PR'), 
      tf.keras.metrics.F1Score(name = 'f1_score',  threshold = cl_thresholds),
]


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=METRICS)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 641 (2.50 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
EPOCHS = 500
BATCH_SIZE = 1024

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_prc", 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)


# train the model
model_history = model.fit(x_train, 
                          y_train, 
                          epochs=EPOCHS, 
                          callbacks = [early_stopping],
                          batch_size = BATCH_SIZE,         
                          validation_data=(x_val, y_val),
                        )
# Out:
# Epoch 1/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - auc: 0.6602 - bs: 0.0691 - f1_score: 3.9292e-05 - loss: 0.2673 - prc: 0.1370 - precision: 0.0156 - recall: 1.9672e-05 - tn: 39746.7227 - tp: 0.0000e+00 - val_auc: 0.8085 - val_bs: 0.0653 - val_f1_score: 0.0038 - val_loss: 0.2338 - val_prc: 0.2503 - val_precision: 0.3750 - val_recall: 0.0019 - val_tn: 19192.0000 - val_tp: 0.0000e+00
# Epoch 2/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7969 - bs: 0.0623 - f1_score: 0.1394 - loss: 0.2250 - prc: 0.2315 - precision: 0.3143 - recall: 0.0952 - tn: 39761.2305 - tp: 6.8916 - val_auc: 0.8332 - val_bs: 0.0617 - val_f1_score: 0.2537 - val_loss: 0.2168 - val_prc: 0.2707 - val_precision: 0.3408 - val_recall: 0.2020 - val_tn: 19187.0000 - val_tp: 2.0000
# Epoch 3/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8216 - bs: 0.0619 - f1_score: 0.2802 - loss: 0.2187 - prc: 0.2539 - precision: 0.3188 - recall: 0.2503 - tn: 39671.3633 - tp: 40.7590 - val_auc: 0.8414 - val_bs: 0.0612 - val_f1_score: 0.2775 - val_loss: 0.2133 - val_prc: 0.2757 - val_precision: 0.3391 - val_recall: 0.2348 - val_tn: 19182.0000 - val_tp: 5.0000
# Epoch 4/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8314 - bs: 0.0613 - f1_score: 0.2811 - loss: 0.2144 - prc: 0.2512 - precision: 0.3086 - recall: 0.2582 - tn: 39649.8203 - tp: 43.8916 - val_auc: 0.8461 - val_bs: 0.0610 - val_f1_score: 0.2722 - val_loss: 0.2114 - val_prc: 0.2790 - val_precision: 0.3436 - val_recall: 0.2254 - val_tn: 19184.0000 - val_tp: 2.0000
# Epoch 5/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.8373 - bs: 0.0604 - f1_score: 0.2915 - loss: 0.2112 - prc: 0.2662 - precision: 0.3314 - recall: 0.2604 - tn: 39705.8438 - tp: 42.4217 - val_auc: 0.8492 - val_bs: 0.0609 - val_f1_score: 0.2655 - val_loss: 0.2103 - val_prc: 0.2807 - val_precision: 0.3462 - val_recall: 0.2153 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 6/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8419 - bs: 0.0594 - f1_score: 0.2915 - loss: 0.2072 - prc: 0.2628 - precision: 0.3221 - recall: 0.2664 - tn: 39727.6641 - tp: 33.7952 - val_auc: 0.8514 - val_bs: 0.0606 - val_f1_score: 0.2786 - val_loss: 0.2086 - val_prc: 0.2836 - val_precision: 0.3384 - val_recall: 0.2367 - val_tn: 19187.0000 - val_tp: 2.0000
# Epoch 7/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8479 - bs: 0.0596 - f1_score: 0.3142 - loss: 0.2061 - prc: 0.2754 - precision: 0.3309 - recall: 0.2992 - tn: 39692.9648 - tp: 35.8313 - val_auc: 0.8537 - val_bs: 0.0604 - val_f1_score: 0.2873 - val_loss: 0.2075 - val_prc: 0.2872 - val_precision: 0.3474 - val_recall: 0.2449 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 8/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.8485 - bs: 0.0601 - f1_score: 0.3098 - loss: 0.2072 - prc: 0.2751 - precision: 0.3236 - recall: 0.2975 - tn: 39702.6641 - tp: 31.4458 - val_auc: 0.8553 - val_bs: 0.0602 - val_f1_score: 0.3018 - val_loss: 0.2064 - val_prc: 0.2897 - val_precision: 0.3450 - val_recall: 0.2683 - val_tn: 19187.0000 - val_tp: 2.0000
# Epoch 9/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8506 - bs: 0.0601 - f1_score: 0.3308 - loss: 0.2071 - prc: 0.2825 - precision: 0.3317 - recall: 0.3299 - tn: 39684.9766 - tp: 37.8795 - val_auc: 0.8565 - val_bs: 0.0600 - val_f1_score: 0.3232 - val_loss: 0.2054 - val_prc: 0.2919 - val_precision: 0.3463 - val_recall: 0.3030 - val_tn: 19181.0000 - val_tp: 5.0000
# Epoch 10/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8521 - bs: 0.0594 - f1_score: 0.3316 - loss: 0.2047 - prc: 0.2871 - precision: 0.3316 - recall: 0.3318 - tn: 39697.5898 - tp: 42.5060 - val_auc: 0.8575 - val_bs: 0.0600 - val_f1_score: 0.3129 - val_loss: 0.2050 - val_prc: 0.2938 - val_precision: 0.3472 - val_recall: 0.2847 - val_tn: 19186.0000 - val_tp: 2.0000
# Epoch 11/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8531 - bs: 0.0592 - f1_score: 0.3354 - loss: 0.2034 - prc: 0.2838 - precision: 0.3270 - recall: 0.3444 - tn: 39701.0000 - tp: 45.9277 - val_auc: 0.8587 - val_bs: 0.0599 - val_f1_score: 0.3216 - val_loss: 0.2044 - val_prc: 0.2959 - val_precision: 0.3518 - val_recall: 0.2961 - val_tn: 19185.0000 - val_tp: 2.0000
# Epoch 12/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8558 - bs: 0.0594 - f1_score: 0.3524 - loss: 0.2036 - prc: 0.2929 - precision: 0.3398 - recall: 0.3662 - tn: 39669.8555 - tp: 54.1928 - val_auc: 0.8597 - val_bs: 0.0599 - val_f1_score: 0.3106 - val_loss: 0.2042 - val_prc: 0.2982 - val_precision: 0.3652 - val_recall: 0.2702 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 13/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8561 - bs: 0.0578 - f1_score: 0.3452 - loss: 0.1993 - prc: 0.2900 - precision: 0.3392 - recall: 0.3518 - tn: 39714.9883 - tp: 50.1807 - val_auc: 0.8604 - val_bs: 0.0597 - val_f1_score: 0.3178 - val_loss: 0.2035 - val_prc: 0.2994 - val_precision: 0.3517 - val_recall: 0.2898 - val_tn: 19187.0000 - val_tp: 2.0000
# Epoch 14/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8583 - bs: 0.0585 - f1_score: 0.3489 - loss: 0.2005 - prc: 0.2931 - precision: 0.3368 - recall: 0.3622 - tn: 39696.1914 - tp: 38.5904 - val_auc: 0.8612 - val_bs: 0.0596 - val_f1_score: 0.3267 - val_loss: 0.2030 - val_prc: 0.3011 - val_precision: 0.3518 - val_recall: 0.3049 - val_tn: 19187.0000 - val_tp: 2.0000
# Epoch 15/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8556 - bs: 0.0589 - f1_score: 0.3325 - loss: 0.2021 - prc: 0.2899 - precision: 0.3227 - recall: 0.3431 - tn: 39714.6758 - tp: 42.9157 - val_auc: 0.8620 - val_bs: 0.0595 - val_f1_score: 0.3356 - val_loss: 0.2024 - val_prc: 0.3030 - val_precision: 0.3557 - val_recall: 0.3176 - val_tn: 19186.0000 - val_tp: 3.0000
# Epoch 16/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8586 - bs: 0.0583 - f1_score: 0.3425 - loss: 0.1997 - prc: 0.2883 - precision: 0.3270 - recall: 0.3601 - tn: 39704.5898 - tp: 39.0843 - val_auc: 0.8628 - val_bs: 0.0596 - val_f1_score: 0.3244 - val_loss: 0.2026 - val_prc: 0.3045 - val_precision: 0.3674 - val_recall: 0.2904 - val_tn: 19189.0000 - val_tp: 2.0000
# Epoch 17/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8584 - bs: 0.0591 - f1_score: 0.3546 - loss: 0.2020 - prc: 0.2934 - precision: 0.3328 - recall: 0.3796 - tn: 39666.6992 - tp: 51.7108 - val_auc: 0.8638 - val_bs: 0.0593 - val_f1_score: 0.3406 - val_loss: 0.2017 - val_prc: 0.3058 - val_precision: 0.3614 - val_recall: 0.3220 - val_tn: 19187.0000 - val_tp: 3.0000
# Epoch 18/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8635 - bs: 0.0580 - f1_score: 0.3535 - loss: 0.1975 - prc: 0.2951 - precision: 0.3275 - recall: 0.3841 - tn: 39707.1211 - tp: 48.5060 - val_auc: 0.8644 - val_bs: 0.0592 - val_f1_score: 0.3433 - val_loss: 0.2013 - val_prc: 0.3079 - val_precision: 0.3599 - val_recall: 0.3283 - val_tn: 19185.0000 - val_tp: 4.0000
# Epoch 19/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8647 - bs: 0.0589 - f1_score: 0.3684 - loss: 0.2000 - prc: 0.3089 - precision: 0.3368 - recall: 0.4069 - tn: 39647.6992 - tp: 71.7952 - val_auc: 0.8653 - val_bs: 0.0595 - val_f1_score: 0.3154 - val_loss: 0.2020 - val_prc: 0.3097 - val_precision: 0.3877 - val_recall: 0.2658 - val_tn: 19189.0000 - val_tp: 1.0000
# Epoch 20/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8600 - bs: 0.0588 - f1_score: 0.3447 - loss: 0.2009 - prc: 0.2970 - precision: 0.3363 - recall: 0.3543 - tn: 39705.0742 - tp: 43.5904 - val_auc: 0.8655 - val_bs: 0.0593 - val_f1_score: 0.3335 - val_loss: 0.2013 - val_prc: 0.3100 - val_precision: 0.3745 - val_recall: 0.3005 - val_tn: 19188.0000 - val_tp: 1.0000
# Epoch 21/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8619 - bs: 0.0579 - f1_score: 0.3687 - loss: 0.1983 - prc: 0.3072 - precision: 0.3406 - recall: 0.4022 - tn: 39704.7969 - tp: 58.8916 - val_auc: 0.8657 - val_bs: 0.0592 - val_f1_score: 0.3424 - val_loss: 0.2008 - val_prc: 0.3110 - val_precision: 0.3673 - val_recall: 0.3207 - val_tn: 19188.0000 - val_tp: 2.0000
# Epoch 22/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8589 - bs: 0.0589 - f1_score: 0.3527 - loss: 0.2015 - prc: 0.3024 - precision: 0.3305 - recall: 0.3782 - tn: 39698.0234 - tp: 53.5904 - val_auc: 0.8659 - val_bs: 0.0589 - val_f1_score: 0.3574 - val_loss: 0.2000 - val_prc: 0.3116 - val_precision: 0.3468 - val_recall: 0.3687 - val_tn: 19182.0000 - val_tp: 7.0000
# Epoch 23/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8650 - bs: 0.0577 - f1_score: 0.3678 - loss: 0.1968 - prc: 0.3083 - precision: 0.3327 - recall: 0.4114 - tn: 39697.1797 - tp: 64.1928 - val_auc: 0.8666 - val_bs: 0.0589 - val_f1_score: 0.3587 - val_loss: 0.1998 - val_prc: 0.3135 - val_precision: 0.3545 - val_recall: 0.3630 - val_tn: 19183.0000 - val_tp: 7.0000
# Epoch 24/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8690 - bs: 0.0576 - f1_score: 0.3650 - loss: 0.1953 - prc: 0.3096 - precision: 0.3319 - recall: 0.4057 - tn: 39733.1680 - tp: 42.5422 - val_auc: 0.8669 - val_bs: 0.0589 - val_f1_score: 0.3547 - val_loss: 0.1997 - val_prc: 0.3134 - val_precision: 0.3534 - val_recall: 0.3561 - val_tn: 19185.0000 - val_tp: 6.0000
# Epoch 25/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8624 - bs: 0.0590 - f1_score: 0.3718 - loss: 0.2011 - prc: 0.3079 - precision: 0.3304 - recall: 0.4253 - tn: 39661.8672 - tp: 63.1928 - val_auc: 0.8673 - val_bs: 0.0589 - val_f1_score: 0.3532 - val_loss: 0.1996 - val_prc: 0.3156 - val_precision: 0.3580 - val_recall: 0.3485 - val_tn: 19186.0000 - val_tp: 4.0000
# Epoch 26/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8694 - bs: 0.0580 - f1_score: 0.3786 - loss: 0.1963 - prc: 0.3144 - precision: 0.3382 - recall: 0.4301 - tn: 39663.3242 - tp: 59.0482 - val_auc: 0.8676 - val_bs: 0.0589 - val_f1_score: 0.3489 - val_loss: 0.1994 - val_prc: 0.3175 - val_precision: 0.3579 - val_recall: 0.3403 - val_tn: 19188.0000 - val_tp: 4.0000
# Epoch 27/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8634 - bs: 0.0578 - f1_score: 0.3716 - loss: 0.1974 - prc: 0.3061 - precision: 0.3391 - recall: 0.4111 - tn: 39712.4453 - tp: 48.6386 - val_auc: 0.8681 - val_bs: 0.0587 - val_f1_score: 0.3542 - val_loss: 0.1989 - val_prc: 0.3179 - val_precision: 0.3493 - val_recall: 0.3592 - val_tn: 19186.0000 - val_tp: 5.0000
# Epoch 28/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8637 - bs: 0.0586 - f1_score: 0.3762 - loss: 0.1997 - prc: 0.3133 - precision: 0.3366 - recall: 0.4263 - tn: 39671.9141 - tp: 69.4699 - val_auc: 0.8686 - val_bs: 0.0586 - val_f1_score: 0.3579 - val_loss: 0.1986 - val_prc: 0.3194 - val_precision: 0.3483 - val_recall: 0.3681 - val_tn: 19186.0000 - val_tp: 5.0000
# Epoch 29/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8687 - bs: 0.0583 - f1_score: 0.3813 - loss: 0.1978 - prc: 0.3229 - precision: 0.3416 - recall: 0.4315 - tn: 39673.0117 - tp: 57.7590 - val_auc: 0.8691 - val_bs: 0.0587 - val_f1_score: 0.3511 - val_loss: 0.1988 - val_prc: 0.3223 - val_precision: 0.3633 - val_recall: 0.3396 - val_tn: 19191.0000 - val_tp: 4.0000
# Epoch 30/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8689 - bs: 0.0585 - f1_score: 0.3805 - loss: 0.1981 - prc: 0.3215 - precision: 0.3412 - recall: 0.4306 - tn: 39683.3984 - tp: 62.7349 - val_auc: 0.8693 - val_bs: 0.0585 - val_f1_score: 0.3657 - val_loss: 0.1980 - val_prc: 0.3213 - val_precision: 0.3447 - val_recall: 0.3895 - val_tn: 19185.0000 - val_tp: 9.0000
# Epoch 31/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8667 - bs: 0.0572 - f1_score: 0.3752 - loss: 0.1953 - prc: 0.3188 - precision: 0.3300 - recall: 0.4352 - tn: 39720.1328 - tp: 67.3133 - val_auc: 0.8693 - val_bs: 0.0585 - val_f1_score: 0.3680 - val_loss: 0.1979 - val_prc: 0.3211 - val_precision: 0.3438 - val_recall: 0.3958 - val_tn: 19181.0000 - val_tp: 10.0000
# Epoch 32/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8613 - bs: 0.0583 - f1_score: 0.3774 - loss: 0.1994 - prc: 0.3125 - precision: 0.3276 - recall: 0.4455 - tn: 39694.6875 - tp: 78.7349 - val_auc: 0.8701 - val_bs: 0.0585 - val_f1_score: 0.3618 - val_loss: 0.1978 - val_prc: 0.3230 - val_precision: 0.3442 - val_recall: 0.3813 - val_tn: 19185.0000 - val_tp: 8.0000
# Epoch 33/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8702 - bs: 0.0578 - f1_score: 0.3859 - loss: 0.1957 - prc: 0.3205 - precision: 0.3335 - recall: 0.4585 - tn: 39681.9648 - tp: 77.6988 - val_auc: 0.8698 - val_bs: 0.0584 - val_f1_score: 0.3725 - val_loss: 0.1977 - val_prc: 0.3221 - val_precision: 0.3442 - val_recall: 0.4059 - val_tn: 19183.0000 - val_tp: 11.0000
# Epoch 34/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8652 - bs: 0.0580 - f1_score: 0.3836 - loss: 0.1977 - prc: 0.3150 - precision: 0.3386 - recall: 0.4428 - tn: 39708.2188 - tp: 52.4940 - val_auc: 0.8706 - val_bs: 0.0585 - val_f1_score: 0.3521 - val_loss: 0.1978 - val_prc: 0.3258 - val_precision: 0.3525 - val_recall: 0.3516 - val_tn: 19190.0000 - val_tp: 6.0000
# Epoch 35/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8689 - bs: 0.0575 - f1_score: 0.3802 - loss: 0.1956 - prc: 0.3237 - precision: 0.3390 - recall: 0.4329 - tn: 39738.3867 - tp: 51.0843 - val_auc: 0.8710 - val_bs: 0.0583 - val_f1_score: 0.3715 - val_loss: 0.1971 - val_prc: 0.3254 - val_precision: 0.3476 - val_recall: 0.3990 - val_tn: 19182.0000 - val_tp: 12.0000
# Epoch 36/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8631 - bs: 0.0581 - f1_score: 0.3704 - loss: 0.1983 - prc: 0.3126 - precision: 0.3303 - recall: 0.4217 - tn: 39708.8320 - tp: 66.2048 - val_auc: 0.8710 - val_bs: 0.0585 - val_f1_score: 0.3559 - val_loss: 0.1976 - val_prc: 0.3259 - val_precision: 0.3563 - val_recall: 0.3554 - val_tn: 19189.0000 - val_tp: 6.0000
# Epoch 37/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8706 - bs: 0.0567 - f1_score: 0.3795 - loss: 0.1929 - prc: 0.3217 - precision: 0.3417 - recall: 0.4269 - tn: 39729.8789 - tp: 65.3012 - val_auc: 0.8708 - val_bs: 0.0583 - val_f1_score: 0.3691 - val_loss: 0.1971 - val_prc: 0.3259 - val_precision: 0.3523 - val_recall: 0.3876 - val_tn: 19184.0000 - val_tp: 12.0000
# Epoch 38/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8697 - bs: 0.0576 - f1_score: 0.3873 - loss: 0.1958 - prc: 0.3282 - precision: 0.3387 - recall: 0.4523 - tn: 39680.8789 - tp: 75.8313 - val_auc: 0.8711 - val_bs: 0.0586 - val_f1_score: 0.3436 - val_loss: 0.1978 - val_prc: 0.3264 - val_precision: 0.3612 - val_recall: 0.3277 - val_tn: 19188.0000 - val_tp: 6.0000
# Epoch 39/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8681 - bs: 0.0575 - f1_score: 0.3747 - loss: 0.1952 - prc: 0.3155 - precision: 0.3345 - recall: 0.4266 - tn: 39710.1914 - tp: 59.0843 - val_auc: 0.8717 - val_bs: 0.0582 - val_f1_score: 0.3855 - val_loss: 0.1966 - val_prc: 0.3270 - val_precision: 0.3494 - val_recall: 0.4299 - val_tn: 19175.0000 - val_tp: 18.0000
# Epoch 40/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8704 - bs: 0.0576 - f1_score: 0.3791 - loss: 0.1947 - prc: 0.3206 - precision: 0.3319 - recall: 0.4422 - tn: 39681.3867 - tp: 87.5422 - val_auc: 0.8718 - val_bs: 0.0583 - val_f1_score: 0.3690 - val_loss: 0.1968 - val_prc: 0.3286 - val_precision: 0.3553 - val_recall: 0.3838 - val_tn: 19184.0000 - val_tp: 15.0000
# Epoch 41/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8701 - bs: 0.0573 - f1_score: 0.3806 - loss: 0.1946 - prc: 0.3278 - precision: 0.3390 - recall: 0.4338 - tn: 39723.6875 - tp: 68.5422 - val_auc: 0.8722 - val_bs: 0.0580 - val_f1_score: 0.3897 - val_loss: 0.1962 - val_prc: 0.3294 - val_precision: 0.3414 - val_recall: 0.4539 - val_tn: 19166.0000 - val_tp: 24.0000
# Epoch 42/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8742 - bs: 0.0576 - f1_score: 0.3930 - loss: 0.1942 - prc: 0.3323 - precision: 0.3403 - recall: 0.4651 - tn: 39685.8906 - tp: 82.4940 - val_auc: 0.8722 - val_bs: 0.0582 - val_f1_score: 0.3775 - val_loss: 0.1964 - val_prc: 0.3308 - val_precision: 0.3567 - val_recall: 0.4009 - val_tn: 19186.0000 - val_tp: 9.0000
# Epoch 43/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8705 - bs: 0.0570 - f1_score: 0.3874 - loss: 0.1936 - prc: 0.3312 - precision: 0.3451 - recall: 0.4417 - tn: 39716.0859 - tp: 78.3614 - val_auc: 0.8721 - val_bs: 0.0581 - val_f1_score: 0.3786 - val_loss: 0.1964 - val_prc: 0.3313 - val_precision: 0.3557 - val_recall: 0.4047 - val_tn: 19181.0000 - val_tp: 15.0000
# Epoch 44/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8678 - bs: 0.0581 - f1_score: 0.3789 - loss: 0.1973 - prc: 0.3213 - precision: 0.3349 - recall: 0.4364 - tn: 39661.9883 - tp: 68.6506 - val_auc: 0.8719 - val_bs: 0.0581 - val_f1_score: 0.3818 - val_loss: 0.1964 - val_prc: 0.3292 - val_precision: 0.3467 - val_recall: 0.4249 - val_tn: 19179.0000 - val_tp: 17.0000
# Epoch 45/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8720 - bs: 0.0565 - f1_score: 0.3876 - loss: 0.1918 - prc: 0.3250 - precision: 0.3370 - recall: 0.4569 - tn: 39749.4219 - tp: 69.8554 - val_auc: 0.8724 - val_bs: 0.0580 - val_f1_score: 0.3935 - val_loss: 0.1958 - val_prc: 0.3310 - val_precision: 0.3382 - val_recall: 0.4703 - val_tn: 19156.0000 - val_tp: 26.0000
# Epoch 46/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8716 - bs: 0.0569 - f1_score: 0.3934 - loss: 0.1930 - prc: 0.3244 - precision: 0.3379 - recall: 0.4721 - tn: 39677.1797 - tp: 97.6145 - val_auc: 0.8725 - val_bs: 0.0581 - val_f1_score: 0.3818 - val_loss: 0.1961 - val_prc: 0.3326 - val_precision: 0.3555 - val_recall: 0.4122 - val_tn: 19182.0000 - val_tp: 16.0000
# Epoch 47/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8727 - bs: 0.0576 - f1_score: 0.3863 - loss: 0.1943 - prc: 0.3293 - precision: 0.3333 - recall: 0.4594 - tn: 39674.4805 - tp: 82.3855 - val_auc: 0.8726 - val_bs: 0.0582 - val_f1_score: 0.3695 - val_loss: 0.1964 - val_prc: 0.3326 - val_precision: 0.3635 - val_recall: 0.3756 - val_tn: 19186.0000 - val_tp: 10.0000
# Epoch 48/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8715 - bs: 0.0573 - f1_score: 0.3929 - loss: 0.1947 - prc: 0.3338 - precision: 0.3506 - recall: 0.4473 - tn: 39693.7344 - tp: 84.0843 - val_auc: 0.8729 - val_bs: 0.0580 - val_f1_score: 0.3806 - val_loss: 0.1959 - val_prc: 0.3321 - val_precision: 0.3544 - val_recall: 0.4110 - val_tn: 19177.0000 - val_tp: 17.0000
# Epoch 49/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8704 - bs: 0.0565 - f1_score: 0.3743 - loss: 0.1923 - prc: 0.3262 - precision: 0.3301 - recall: 0.4325 - tn: 39714.3008 - tp: 95.9759 - val_auc: 0.8734 - val_bs: 0.0580 - val_f1_score: 0.3779 - val_loss: 0.1959 - val_prc: 0.3329 - val_precision: 0.3531 - val_recall: 0.4066 - val_tn: 19174.0000 - val_tp: 20.0000
# Epoch 50/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8734 - bs: 0.0561 - f1_score: 0.3866 - loss: 0.1903 - prc: 0.3232 - precision: 0.3394 - recall: 0.4491 - tn: 39707.0000 - tp: 97.2048 - val_auc: 0.8734 - val_bs: 0.0581 - val_f1_score: 0.3762 - val_loss: 0.1960 - val_prc: 0.3342 - val_precision: 0.3610 - val_recall: 0.3927 - val_tn: 19184.0000 - val_tp: 12.0000
# Epoch 51/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8716 - bs: 0.0574 - f1_score: 0.3869 - loss: 0.1947 - prc: 0.3314 - precision: 0.3449 - recall: 0.4407 - tn: 39677.5430 - tp: 90.5060 - val_auc: 0.8731 - val_bs: 0.0579 - val_f1_score: 0.3881 - val_loss: 0.1955 - val_prc: 0.3339 - val_precision: 0.3441 - val_recall: 0.4451 - val_tn: 19163.0000 - val_tp: 21.0000
# Epoch 52/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8766 - bs: 0.0555 - f1_score: 0.3922 - loss: 0.1881 - prc: 0.3361 - precision: 0.3372 - recall: 0.4694 - tn: 39720.1562 - tp: 113.5301 - val_auc: 0.8732 - val_bs: 0.0579 - val_f1_score: 0.3888 - val_loss: 0.1955 - val_prc: 0.3341 - val_precision: 0.3467 - val_recall: 0.4426 - val_tn: 19170.0000 - val_tp: 21.0000
# Epoch 53/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8718 - bs: 0.0566 - f1_score: 0.3879 - loss: 0.1924 - prc: 0.3345 - precision: 0.3350 - recall: 0.4611 - tn: 39685.9648 - tp: 98.8072 - val_auc: 0.8732 - val_bs: 0.0580 - val_f1_score: 0.3761 - val_loss: 0.1959 - val_prc: 0.3347 - val_precision: 0.3567 - val_recall: 0.3977 - val_tn: 19177.0000 - val_tp: 20.0000
# Epoch 54/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8725 - bs: 0.0575 - f1_score: 0.3829 - loss: 0.1942 - prc: 0.3322 - precision: 0.3363 - recall: 0.4451 - tn: 39705.3750 - tp: 97.5783 - val_auc: 0.8740 - val_bs: 0.0580 - val_f1_score: 0.3765 - val_loss: 0.1957 - val_prc: 0.3368 - val_precision: 0.3580 - val_recall: 0.3971 - val_tn: 19180.0000 - val_tp: 15.0000
# Epoch 55/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8726 - bs: 0.0579 - f1_score: 0.3894 - loss: 0.1955 - prc: 0.3311 - precision: 0.3373 - recall: 0.4607 - tn: 39620.0000 - tp: 110.7108 - val_auc: 0.8737 - val_bs: 0.0581 - val_f1_score: 0.3716 - val_loss: 0.1959 - val_prc: 0.3367 - val_precision: 0.3727 - val_recall: 0.3706 - val_tn: 19185.0000 - val_tp: 12.0000
# Epoch 56/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8750 - bs: 0.0568 - f1_score: 0.3908 - loss: 0.1922 - prc: 0.3369 - precision: 0.3542 - recall: 0.4367 - tn: 39694.6641 - tp: 90.1687 - val_auc: 0.8741 - val_bs: 0.0578 - val_f1_score: 0.3895 - val_loss: 0.1951 - val_prc: 0.3365 - val_precision: 0.3490 - val_recall: 0.4407 - val_tn: 19169.0000 - val_tp: 21.0000
# Epoch 57/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8749 - bs: 0.0568 - f1_score: 0.3885 - loss: 0.1921 - prc: 0.3455 - precision: 0.3350 - recall: 0.4628 - tn: 39658.8438 - tp: 142.8313 - val_auc: 0.8745 - val_bs: 0.0579 - val_f1_score: 0.3802 - val_loss: 0.1952 - val_prc: 0.3369 - val_precision: 0.3514 - val_recall: 0.4141 - val_tn: 19172.0000 - val_tp: 20.0000
# Epoch 58/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8722 - bs: 0.0571 - f1_score: 0.3806 - loss: 0.1934 - prc: 0.3396 - precision: 0.3396 - recall: 0.4330 - tn: 39678.8438 - tp: 108.8193 - val_auc: 0.8745 - val_bs: 0.0579 - val_f1_score: 0.3773 - val_loss: 0.1954 - val_prc: 0.3383 - val_precision: 0.3636 - val_recall: 0.3920 - val_tn: 19176.0000 - val_tp: 17.0000
# Epoch 59/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8738 - bs: 0.0567 - f1_score: 0.3867 - loss: 0.1920 - prc: 0.3314 - precision: 0.3458 - recall: 0.4389 - tn: 39689.9648 - tp: 98.7711 - val_auc: 0.8745 - val_bs: 0.0578 - val_f1_score: 0.3905 - val_loss: 0.1950 - val_prc: 0.3379 - val_precision: 0.3538 - val_recall: 0.4356 - val_tn: 19167.0000 - val_tp: 22.0000
# Epoch 60/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8748 - bs: 0.0567 - f1_score: 0.3970 - loss: 0.1924 - prc: 0.3439 - precision: 0.3481 - recall: 0.4621 - tn: 39627.1914 - tp: 130.3976 - val_auc: 0.8747 - val_bs: 0.0579 - val_f1_score: 0.3723 - val_loss: 0.1953 - val_prc: 0.3388 - val_precision: 0.3696 - val_recall: 0.3750 - val_tn: 19174.0000 - val_tp: 17.0000
# Epoch 61/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8734 - bs: 0.0568 - f1_score: 0.3886 - loss: 0.1930 - prc: 0.3401 - precision: 0.3587 - recall: 0.4251 - tn: 39660.6367 - tp: 100.3253 - val_auc: 0.8747 - val_bs: 0.0579 - val_f1_score: 0.3850 - val_loss: 0.1952 - val_prc: 0.3377 - val_precision: 0.3662 - val_recall: 0.4059 - val_tn: 19175.0000 - val_tp: 19.0000
# Epoch 62/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8725 - bs: 0.0562 - f1_score: 0.3846 - loss: 0.1909 - prc: 0.3315 - precision: 0.3417 - recall: 0.4400 - tn: 39719.7227 - tp: 95.9036 - val_auc: 0.8748 - val_bs: 0.0577 - val_f1_score: 0.3886 - val_loss: 0.1948 - val_prc: 0.3386 - val_precision: 0.3508 - val_recall: 0.4356 - val_tn: 19158.0000 - val_tp: 27.0000
# Epoch 63/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8750 - bs: 0.0564 - f1_score: 0.3900 - loss: 0.1911 - prc: 0.3387 - precision: 0.3422 - recall: 0.4534 - tn: 39683.7461 - tp: 121.3012 - val_auc: 0.8752 - val_bs: 0.0577 - val_f1_score: 0.3850 - val_loss: 0.1948 - val_prc: 0.3389 - val_precision: 0.3560 - val_recall: 0.4192 - val_tn: 19173.0000 - val_tp: 20.0000
# Epoch 64/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8720 - bs: 0.0566 - f1_score: 0.3924 - loss: 0.1925 - prc: 0.3315 - precision: 0.3473 - recall: 0.4517 - tn: 39700.1094 - tp: 100.1084 - val_auc: 0.8755 - val_bs: 0.0577 - val_f1_score: 0.3902 - val_loss: 0.1946 - val_prc: 0.3380 - val_precision: 0.3493 - val_recall: 0.4419 - val_tn: 19152.0000 - val_tp: 32.0000
# Epoch 65/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8704 - bs: 0.0565 - f1_score: 0.3839 - loss: 0.1920 - prc: 0.3200 - precision: 0.3354 - recall: 0.4499 - tn: 39675.6641 - tp: 123.0000 - val_auc: 0.8754 - val_bs: 0.0577 - val_f1_score: 0.3879 - val_loss: 0.1946 - val_prc: 0.3397 - val_precision: 0.3509 - val_recall: 0.4337 - val_tn: 19159.0000 - val_tp: 25.0000
# Epoch 66/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8748 - bs: 0.0569 - f1_score: 0.3896 - loss: 0.1923 - prc: 0.3346 - precision: 0.3387 - recall: 0.4586 - tn: 39639.4102 - tp: 127.6024 - val_auc: 0.8755 - val_bs: 0.0579 - val_f1_score: 0.3807 - val_loss: 0.1950 - val_prc: 0.3389 - val_precision: 0.3694 - val_recall: 0.3927 - val_tn: 19174.0000 - val_tp: 17.0000
# Epoch 67/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8756 - bs: 0.0572 - f1_score: 0.3922 - loss: 0.1930 - prc: 0.3392 - precision: 0.3517 - recall: 0.4434 - tn: 39655.1211 - tp: 106.1566 - val_auc: 0.8756 - val_bs: 0.0577 - val_f1_score: 0.3876 - val_loss: 0.1947 - val_prc: 0.3407 - val_precision: 0.3622 - val_recall: 0.4167 - val_tn: 19168.0000 - val_tp: 19.0000
# Epoch 68/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8755 - bs: 0.0571 - f1_score: 0.3981 - loss: 0.1931 - prc: 0.3423 - precision: 0.3534 - recall: 0.4558 - tn: 39673.0000 - tp: 119.6506 - val_auc: 0.8756 - val_bs: 0.0576 - val_f1_score: 0.3909 - val_loss: 0.1944 - val_prc: 0.3408 - val_precision: 0.3554 - val_recall: 0.4343 - val_tn: 19156.0000 - val_tp: 34.0000
# Epoch 69/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8725 - bs: 0.0576 - f1_score: 0.3840 - loss: 0.1947 - prc: 0.3354 - precision: 0.3409 - recall: 0.4398 - tn: 39638.1328 - tp: 122.5663 - val_auc: 0.8752 - val_bs: 0.0578 - val_f1_score: 0.3831 - val_loss: 0.1950 - val_prc: 0.3411 - val_precision: 0.3735 - val_recall: 0.3933 - val_tn: 19173.0000 - val_tp: 18.0000
# Epoch 70/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8737 - bs: 0.0574 - f1_score: 0.3814 - loss: 0.1943 - prc: 0.3485 - precision: 0.3525 - recall: 0.4159 - tn: 39656.1445 - tp: 115.1807 - val_auc: 0.8761 - val_bs: 0.0576 - val_f1_score: 0.3877 - val_loss: 0.1944 - val_prc: 0.3415 - val_precision: 0.3552 - val_recall: 0.4268 - val_tn: 19158.0000 - val_tp: 27.0000
# Epoch 71/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8767 - bs: 0.0572 - f1_score: 0.3982 - loss: 0.1929 - prc: 0.3463 - precision: 0.3494 - recall: 0.4630 - tn: 39652.3750 - tp: 117.1566 - val_auc: 0.8762 - val_bs: 0.0576 - val_f1_score: 0.3920 - val_loss: 0.1943 - val_prc: 0.3411 - val_precision: 0.3542 - val_recall: 0.4388 - val_tn: 19162.0000 - val_tp: 29.0000
# Epoch 72/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.8740 - bs: 0.0571 - f1_score: 0.3906 - loss: 0.1931 - prc: 0.3405 - precision: 0.3426 - recall: 0.4543 - tn: 39655.4922 - tp: 127.2771 - val_auc: 0.8762 - val_bs: 0.0578 - val_f1_score: 0.3795 - val_loss: 0.1947 - val_prc: 0.3423 - val_precision: 0.3740 - val_recall: 0.3851 - val_tn: 19177.0000 - val_tp: 18.0000
# Epoch 73/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8777 - bs: 0.0564 - f1_score: 0.3873 - loss: 0.1902 - prc: 0.3376 - precision: 0.3488 - recall: 0.4359 - tn: 39688.3477 - tp: 121.9639 - val_auc: 0.8768 - val_bs: 0.0576 - val_f1_score: 0.3969 - val_loss: 0.1940 - val_prc: 0.3423 - val_precision: 0.3565 - val_recall: 0.4476 - val_tn: 19161.0000 - val_tp: 30.0000
# Epoch 74/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8740 - bs: 0.0563 - f1_score: 0.3967 - loss: 0.1914 - prc: 0.3434 - precision: 0.3469 - recall: 0.4636 - tn: 39681.4336 - tp: 126.6867 - val_auc: 0.8766 - val_bs: 0.0575 - val_f1_score: 0.3994 - val_loss: 0.1939 - val_prc: 0.3411 - val_precision: 0.3547 - val_recall: 0.4571 - val_tn: 19149.0000 - val_tp: 37.0000
# Epoch 75/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.8756 - bs: 0.0564 - f1_score: 0.4013 - loss: 0.1916 - prc: 0.3468 - precision: 0.3562 - recall: 0.4594 - tn: 39661.9766 - tp: 132.9277 - val_auc: 0.8768 - val_bs: 0.0576 - val_f1_score: 0.3940 - val_loss: 0.1941 - val_prc: 0.3428 - val_precision: 0.3669 - val_recall: 0.4255 - val_tn: 19167.0000 - val_tp: 22.0000
# Epoch 76/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8782 - bs: 0.0566 - f1_score: 0.3973 - loss: 0.1908 - prc: 0.3473 - precision: 0.3469 - recall: 0.4649 - tn: 39653.1445 - tp: 140.4096 - val_auc: 0.8772 - val_bs: 0.0575 - val_f1_score: 0.3975 - val_loss: 0.1939 - val_prc: 0.3429 - val_precision: 0.3608 - val_recall: 0.4426 - val_tn: 19154.0000 - val_tp: 33.0000
# Epoch 77/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8761 - bs: 0.0554 - f1_score: 0.3940 - loss: 0.1883 - prc: 0.3404 - precision: 0.3488 - recall: 0.4530 - tn: 39721.7812 - tp: 120.2048 - val_auc: 0.8769 - val_bs: 0.0575 - val_f1_score: 0.3933 - val_loss: 0.1939 - val_prc: 0.3433 - val_precision: 0.3527 - val_recall: 0.4444 - val_tn: 19159.0000 - val_tp: 36.0000
# Epoch 78/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8741 - bs: 0.0569 - f1_score: 0.3933 - loss: 0.1931 - prc: 0.3423 - precision: 0.3453 - recall: 0.4570 - tn: 39639.9141 - tp: 137.3374 - val_auc: 0.8765 - val_bs: 0.0576 - val_f1_score: 0.3900 - val_loss: 0.1941 - val_prc: 0.3436 - val_precision: 0.3681 - val_recall: 0.4148 - val_tn: 19164.0000 - val_tp: 21.0000
# Epoch 79/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8778 - bs: 0.0565 - f1_score: 0.4031 - loss: 0.1908 - prc: 0.3499 - precision: 0.3531 - recall: 0.4699 - tn: 39631.9648 - tp: 171.9277 - val_auc: 0.8766 - val_bs: 0.0576 - val_f1_score: 0.3864 - val_loss: 0.1942 - val_prc: 0.3442 - val_precision: 0.3719 - val_recall: 0.4021 - val_tn: 19166.0000 - val_tp: 21.0000
# Epoch 80/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8720 - bs: 0.0578 - f1_score: 0.3976 - loss: 0.1962 - prc: 0.3489 - precision: 0.3563 - recall: 0.4501 - tn: 39591.6016 - tp: 128.2530 - val_auc: 0.8763 - val_bs: 0.0576 - val_f1_score: 0.3854 - val_loss: 0.1944 - val_prc: 0.3433 - val_precision: 0.3689 - val_recall: 0.4034 - val_tn: 19164.0000 - val_tp: 23.0000
# Epoch 81/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8747 - bs: 0.0568 - f1_score: 0.3864 - loss: 0.1919 - prc: 0.3378 - precision: 0.3452 - recall: 0.4389 - tn: 39646.2188 - tp: 142.3615 - val_auc: 0.8770 - val_bs: 0.0575 - val_f1_score: 0.3892 - val_loss: 0.1938 - val_prc: 0.3438 - val_precision: 0.3624 - val_recall: 0.4205 - val_tn: 19156.0000 - val_tp: 29.0000
# Epoch 82/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8747 - bs: 0.0566 - f1_score: 0.3902 - loss: 0.1919 - prc: 0.3478 - precision: 0.3469 - recall: 0.4458 - tn: 39658.0352 - tp: 150.5663 - val_auc: 0.8772 - val_bs: 0.0576 - val_f1_score: 0.3898 - val_loss: 0.1939 - val_prc: 0.3441 - val_precision: 0.3638 - val_recall: 0.4198 - val_tn: 19161.0000 - val_tp: 27.0000
# Epoch 83/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8779 - bs: 0.0566 - f1_score: 0.3998 - loss: 0.1912 - prc: 0.3488 - precision: 0.3542 - recall: 0.4591 - tn: 39643.2031 - tp: 146.7470 - val_auc: 0.8771 - val_bs: 0.0575 - val_f1_score: 0.3916 - val_loss: 0.1938 - val_prc: 0.3437 - val_precision: 0.3623 - val_recall: 0.4261 - val_tn: 19163.0000 - val_tp: 24.0000
# Epoch 84/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8767 - bs: 0.0575 - f1_score: 0.4008 - loss: 0.1938 - prc: 0.3443 - precision: 0.3589 - recall: 0.4540 - tn: 39644.8320 - tp: 134.0241 - val_auc: 0.8771 - val_bs: 0.0576 - val_f1_score: 0.3813 - val_loss: 0.1942 - val_prc: 0.3447 - val_precision: 0.3712 - val_recall: 0.3920 - val_tn: 19165.0000 - val_tp: 21.0000
# Epoch 85/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8809 - bs: 0.0555 - f1_score: 0.3995 - loss: 0.1873 - prc: 0.3492 - precision: 0.3555 - recall: 0.4560 - tn: 39680.3867 - tp: 157.9036 - val_auc: 0.8772 - val_bs: 0.0575 - val_f1_score: 0.3994 - val_loss: 0.1936 - val_prc: 0.3432 - val_precision: 0.3540 - val_recall: 0.4583 - val_tn: 19142.0000 - val_tp: 51.0000
# Epoch 86/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8740 - bs: 0.0570 - f1_score: 0.3899 - loss: 0.1930 - prc: 0.3417 - precision: 0.3428 - recall: 0.4523 - tn: 39637.3477 - tp: 160.3374 - val_auc: 0.8770 - val_bs: 0.0575 - val_f1_score: 0.3941 - val_loss: 0.1937 - val_prc: 0.3452 - val_precision: 0.3647 - val_recall: 0.4287 - val_tn: 19154.0000 - val_tp: 37.0000
# Epoch 87/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8786 - bs: 0.0553 - f1_score: 0.3967 - loss: 0.1876 - prc: 0.3509 - precision: 0.3477 - recall: 0.4618 - tn: 39691.3242 - tp: 167.7349 - val_auc: 0.8772 - val_bs: 0.0575 - val_f1_score: 0.3981 - val_loss: 0.1937 - val_prc: 0.3425 - val_precision: 0.3549 - val_recall: 0.4533 - val_tn: 19139.0000 - val_tp: 47.0000
# Epoch 88/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8759 - bs: 0.0570 - f1_score: 0.3890 - loss: 0.1924 - prc: 0.3434 - precision: 0.3445 - recall: 0.4470 - tn: 39661.7812 - tp: 139.2289 - val_auc: 0.8773 - val_bs: 0.0574 - val_f1_score: 0.4002 - val_loss: 0.1935 - val_prc: 0.3443 - val_precision: 0.3591 - val_recall: 0.4520 - val_tn: 19139.0000 - val_tp: 49.0000
# Epoch 89/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8804 - bs: 0.0564 - f1_score: 0.4059 - loss: 0.1901 - prc: 0.3581 - precision: 0.3547 - recall: 0.4745 - tn: 39623.6641 - tp: 163.2892 - val_auc: 0.8773 - val_bs: 0.0575 - val_f1_score: 0.3992 - val_loss: 0.1937 - val_prc: 0.3432 - val_precision: 0.3684 - val_recall: 0.4356 - val_tn: 19152.0000 - val_tp: 40.0000
# Epoch 90/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8747 - bs: 0.0553 - f1_score: 0.3792 - loss: 0.1878 - prc: 0.3353 - precision: 0.3400 - recall: 0.4294 - tn: 39696.0742 - tp: 157.5542 - val_auc: 0.8774 - val_bs: 0.0575 - val_f1_score: 0.3935 - val_loss: 0.1938 - val_prc: 0.3435 - val_precision: 0.3659 - val_recall: 0.4255 - val_tn: 19156.0000 - val_tp: 34.0000
# Epoch 91/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8772 - bs: 0.0567 - f1_score: 0.3938 - loss: 0.1914 - prc: 0.3472 - precision: 0.3498 - recall: 0.4505 - tn: 39640.4219 - tp: 168.6988 - val_auc: 0.8775 - val_bs: 0.0576 - val_f1_score: 0.3880 - val_loss: 0.1940 - val_prc: 0.3429 - val_precision: 0.3695 - val_recall: 0.4085 - val_tn: 19164.0000 - val_tp: 28.0000
# Epoch 92/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.8754 - bs: 0.0569 - f1_score: 0.3895 - loss: 0.1923 - prc: 0.3442 - precision: 0.3483 - recall: 0.4419 - tn: 39665.5664 - tp: 155.4096 - val_auc: 0.8772 - val_bs: 0.0575 - val_f1_score: 0.4010 - val_loss: 0.1936 - val_prc: 0.3435 - val_precision: 0.3607 - val_recall: 0.4514 - val_tn: 19141.0000 - val_tp: 49.0000
# Epoch 93/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.8757 - bs: 0.0561 - f1_score: 0.3941 - loss: 0.1904 - prc: 0.3490 - precision: 0.3489 - recall: 0.4534 - tn: 39683.4219 - tp: 152.1084 - val_auc: 0.8774 - val_bs: 0.0575 - val_f1_score: 0.4010 - val_loss: 0.1936 - val_prc: 0.3435 - val_precision: 0.3595 - val_recall: 0.4533 - val_tn: 19144.0000 - val_tp: 48.0000
# Epoch 94/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8771 - bs: 0.0565 - f1_score: 0.3902 - loss: 0.1906 - prc: 0.3427 - precision: 0.3408 - recall: 0.4567 - tn: 39643.3867 - tp: 170.7349 - val_auc: 0.8775 - val_bs: 0.0576 - val_f1_score: 0.3830 - val_loss: 0.1939 - val_prc: 0.3437 - val_precision: 0.3698 - val_recall: 0.3971 - val_tn: 19161.0000 - val_tp: 27.0000
# Epoch 95/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8816 - bs: 0.0555 - f1_score: 0.3951 - loss: 0.1873 - prc: 0.3567 - precision: 0.3576 - recall: 0.4418 - tn: 39650.2031 - tp: 165.6385 - val_auc: 0.8778 - val_bs: 0.0575 - val_f1_score: 0.3964 - val_loss: 0.1936 - val_prc: 0.3436 - val_precision: 0.3650 - val_recall: 0.4337 - val_tn: 19152.0000 - val_tp: 39.0000
# Epoch 96/500
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.8759 - bs: 0.0577 - f1_score: 0.4000 - loss: 0.1949 - prc: 0.3507 - precision: 0.3541 - recall: 0.4598 - tn: 39600.5898 - tp: 157.0482 - val_auc: 0.8774 - val_bs: 0.0575 - val_f1_score: 0.3877 - val_loss: 0.1937 - val_prc: 0.3451 - val_precision: 0.3654 - val_recall: 0.4129 - val_tn: 19162.0000 - val_tp: 26.0000
# Epoch 96: early stopping
# Restoring model weights from the end of the best epoch: 86.

# %%
def class_prediction(x, y):
    y_hat = model.predict(x)      
    bs = brier_score_loss(y, y_hat)    
    auc = roc_auc_score(y, y_hat)
    return y_hat, auc, bs

# %%
def plot_cm(y, y_hat, classification_threshold):
    # compute the contingency table    
    y_hat_class = y_hat >= classification_threshold
    cm = metrics.confusion_matrix(y, y_hat_class)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, linewidths=.5, square = True, cmap = 'Blues_r', cbar=None, fmt='g')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def plot_metrics(history):
  metrics = ['loss', 'bs', 'recall', 'precision']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color="red", label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.5,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %% [markdown]
# ### Performance on training data

# %%
plot_metrics(model_history)

# %% [markdown]
# ### Performance on testing data

# %%
def cutoff_youdens_j(fpr, tpr, thresholds):
    j_scores = tpr-fpr
    j_ordered = sorted(zip(j_scores, thresholds))
    return j_ordered[-1][1]

# %%
y_hat_val, auc_val, bs_val = class_prediction(x_val, y_val)
classification_threshold_val = cutoff_youdens_j(*roc_curve(y_val, y_hat_val))
print(classification_threshold_val)
plot_cm(y_val, y_hat_val, classification_threshold=classification_threshold_val)
# Out:
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 0.07257999

# %%
average_precision_score(y_val, y_hat_val)
# Out:
# 0.3459173074133466

# %%
y_hat_test, auc_test, bs_test = class_prediction(x_test, y_test)
classification_threshold = cutoff_youdens_j(*roc_curve(y_test, y_hat_test))
plot_cm(y_test, y_hat_test, classification_threshold=classification_threshold_val)
# Out:
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
average_precision_score(y_test, y_hat_test)
# Out:
# 0.3383701987235436

# %%
def reliability_curve(y, y_pred, bin_size=0.1, count_pred_per_bin=100):
  y = np.array(y)
  y_pred = np.array(y_pred)
  bins = np.arange(0, 1+bin_size, bin_size)
  bin_centers = [(b1 + b2) / 2 for b1, b2 in zip(bins[:-1], bins[1:])]
  prop_positive = []
  bin_center_ax = []
  no_pred_per_bin = []
  for b1, b2, bc in zip(bins[:-1], bins[1:], bin_centers):
    in_bin = np.logical_and(y_pred >= b1, y_pred < b2)
    no_predictions_per_bin = np.sum(in_bin)
    no_positive_per_bin = np.sum(y[in_bin])    
    if no_predictions_per_bin > count_pred_per_bin:
      prop_pos = round(no_positive_per_bin/no_predictions_per_bin, 3)
      prop_positive.append(prop_pos)
      bin_center_ax.append(round(bc, 3))
      no_pred_per_bin.append(no_predictions_per_bin)
    else:
      continue
  return bin_center_ax, prop_positive, no_pred_per_bin

# %%
prob_pred, prob_true, no_pred_per_bin = reliability_curve(y_test, y_hat_test.flatten())
plt.figure(figsize=(5,4))
plt.plot(prob_pred, prob_true, label=f"NN0{lead_time} {city}")    
    
plt.xlabel("Predicted probability")
plt.ylabel("Obs. proportion of positive case")

no_pred_per_bin = [i/(1.1*np.max(no_pred_per_bin)) for i in no_pred_per_bin]
plt.plot(np.arange(0,1.2,0.2), np.arange(0,1.2,0.2))
plt.bar(prob_pred, no_pred_per_bin, width=0.1, linestyle="--", fill=False, edgecolor="green")

plt.xlim(0,1)
plt.ylim(0,1)
plt.legend(loc='upper center')
plt.show()

# %%
model.save(f'/home/mendrika/mendrika-phd/codes/nflics/model-ML-Dakar/Normal-{city}-t{lead_time}.keras')

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = metrics.roc_curve(labels, predictions)
  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False alarm [%]')
  plt.ylabel('Hit [%]')
  plt.xlim([0,100])
  plt.ylim([0,100])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
y_hat_train, auc_train, bs_train = class_prediction(x_train, y_train)
plot_roc(f"Training set (AUC={auc_train:.3f})", y_train, y_hat_train, color="red")
plot_roc(f"Testing set  (AUC={auc_test:.3f})", y_test, y_hat_test, color=colors[0], linestyle='--')
plt.title(f"NN0{lead_time} {city}")
plt.legend(loc='lower right');
# Out:
#   40/2597 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step
# 2597/2597 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
