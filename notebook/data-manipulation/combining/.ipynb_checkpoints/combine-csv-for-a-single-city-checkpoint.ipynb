# %%
import pandas as pd
import sys
sys.path.insert(1, "../../../module")
import snflics

# %%
partition = "test"
path = f"../../../output/data/dakar/{partition}"
all_files = snflics.all_files_in(path)

# %%
data = pd.concat([pd.read_csv(file) for file in all_files])

# %%
data.to_csv(f"../../../output/data/dakar/data-{partition}-eps-dakar.csv", index=False)
